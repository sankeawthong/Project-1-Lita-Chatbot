# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/Hybrid%20RF-LSTM%20for%2010%20class%20classifications%20based%20on%20UNSW-NB15%20ver.3%20with%20dropout150ep(13112023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hybrid RF-LSTM for 10 class classifications based on UNSW-NB15 dataset ver.2.2 (150 epochs with dropout)**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils import np_utils
#from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
# Load dataset
dataset = pd.read_csv("dataset_P2.2.csv")
dataset.isnull().sum()
# Out:
# id                   0
# dur                  0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# Class                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 175341 non-null  int64
#  1   dur                175341 non-null  float64
#  2   spkts              175341 non-null  int64
#  3   dpkts              175341 non-null  int64
#  4   sbytes             175341 non-null  int64
#  5   dbytes             175341 non-null  int64
#  6   rate               175341 non-null  float64
#  7   sttl               175341 non-null  int64
#  8   dttl               175341 non-null  int64
#  9   sload              175341 non-null  float64
#  10  dload              175341 non-null  float64
#  11  sloss              175341 non-null  int64
#  12  dloss              175341 non-null  int64
#  13  sinpkt             175341 non-null  float64
#  14  dinpkt             175341 non-null  float64
#  15  sjit               175341 non-null  float64
#  16  djit               175341 non-null  float64
#  17  swin               175341 non-null  int64
#  18  stcpb              175341 non-null  int64
#  19  dtcpb              175341 non-null  int64
#  20  dwin               175341 non-null  int64
#  21  tcprtt             175341 non-null  float64
#  22  synack             175341 non-null  float64
#  23  ackdat             175341 non-null  float64
#  24  smean              175341 non-null  int64
#  25  dmean              175341 non-null  int64
#  26  trans_depth        175341 non-null  int64
#  27  response_body_len  175341 non-null  int64
#  28  ct_srv_src         175341 non-null  int64
#  29  ct_state_ttl       175341 non-null  int64
#  30  ct_dst_ltm         175341 non-null  int64
#  31  ct_src_dport_ltm   175341 non-null  int64
#  32  ct_dst_sport_ltm   175341 non-null  int64
#  33  ct_dst_src_ltm     175341 non-null  int64
#  34  is_ftp_login       175341 non-null  int64
#  35  ct_ftp_cmd         175341 non-null  int64
#  36  ct_flw_http_mthd   175341 non-null  int64
#  37  ct_src_ltm         175341 non-null  int64
#  38  ct_srv_dst         175341 non-null  int64
#  39  is_sm_ips_ports    175341 non-null  int64
#  40  Class              175341 non-null  int64
# dtypes: float64(11), int64(30)
# memory usage: 54.8 MB

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])
y = np_utils.to_categorical(y, num_classes=10)  # update to 10 classes
X = dataset.drop(['Class'], axis=1)
X = X.values
print(X.shape)
print(y.shape)
# Out:
# (175341, 40)
# (175341, 10)

# %% [markdown]
# **Data Preprocessing**

# %%
# Data preprocessing
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Hybrid RF-LSTM for 10 class Ver.2.2**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))

# %%
# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
lstm_model.add(Dropout(0.5))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.001)))
lstm_model.add(Dropout(0.5))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.001)))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(10, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = lstm_model.fit(train_rf_features, y_train, epochs=150, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)

print(confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions))
print(classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions))

# Plot training/validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# 5600/5600 [==============================] - 54s 7ms/step - loss: 0.8329 - accuracy: 0.7047 - val_loss: 0.1291 - val_accuracy: 0.9999
# Epoch 2/150
# 5600/5600 [==============================] - 41s 7ms/step - loss: 0.2694 - accuracy: 0.9401 - val_loss: 0.0844 - val_accuracy: 0.9999
# Epoch 3/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.1998 - accuracy: 0.9593 - val_loss: 0.0733 - val_accuracy: 0.9999
# Epoch 4/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.1759 - accuracy: 0.9631 - val_loss: 0.0679 - val_accuracy: 0.9999
# Epoch 5/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.1613 - accuracy: 0.9669 - val_loss: 0.0630 - val_accuracy: 0.9999
# Epoch 6/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.1509 - accuracy: 0.9697 - val_loss: 0.0604 - val_accuracy: 0.9999
# Epoch 7/150
# 5600/5600 [==============================] - 36s 7ms/step - loss: 0.1368 - accuracy: 0.9728 - val_loss: 0.0532 - val_accuracy: 0.9999
# Epoch 8/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.1272 - accuracy: 0.9738 - val_loss: 0.0507 - val_accuracy: 0.9999
# Epoch 9/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.1212 - accuracy: 0.9750 - val_loss: 0.0480 - val_accuracy: 0.9999
# Epoch 10/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.1105 - accuracy: 0.9777 - val_loss: 0.0441 - val_accuracy: 0.9999
# Epoch 11/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.1006 - accuracy: 0.9794 - val_loss: 0.0405 - val_accuracy: 0.9999
# Epoch 12/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0954 - accuracy: 0.9806 - val_loss: 0.0398 - val_accuracy: 0.9999
# Epoch 13/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0923 - accuracy: 0.9806 - val_loss: 0.0372 - val_accuracy: 0.9999
# Epoch 14/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0891 - accuracy: 0.9812 - val_loss: 0.0370 - val_accuracy: 0.9999
# Epoch 15/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0861 - accuracy: 0.9821 - val_loss: 0.0357 - val_accuracy: 0.9999
# Epoch 16/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0824 - accuracy: 0.9828 - val_loss: 0.0346 - val_accuracy: 0.9999
# Epoch 17/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0793 - accuracy: 0.9835 - val_loss: 0.0331 - val_accuracy: 0.9999
# Epoch 18/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0770 - accuracy: 0.9839 - val_loss: 0.0330 - val_accuracy: 0.9999
# Epoch 19/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0748 - accuracy: 0.9843 - val_loss: 0.0325 - val_accuracy: 0.9999
# Epoch 20/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0730 - accuracy: 0.9848 - val_loss: 0.0311 - val_accuracy: 0.9999
# Epoch 21/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0716 - accuracy: 0.9851 - val_loss: 0.0303 - val_accuracy: 0.9999
# Epoch 22/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0699 - accuracy: 0.9861 - val_loss: 0.0303 - val_accuracy: 0.9999
# Epoch 23/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0690 - accuracy: 0.9865 - val_loss: 0.0294 - val_accuracy: 0.9999
# Epoch 24/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0692 - accuracy: 0.9862 - val_loss: 0.0307 - val_accuracy: 0.9999
# Epoch 25/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0681 - accuracy: 0.9865 - val_loss: 0.0298 - val_accuracy: 0.9999
# Epoch 26/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0678 - accuracy: 0.9865 - val_loss: 0.0298 - val_accuracy: 0.9999
# Epoch 27/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0675 - accuracy: 0.9866 - val_loss: 0.0298 - val_accuracy: 0.9999
# Epoch 28/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0668 - accuracy: 0.9868 - val_loss: 0.0293 - val_accuracy: 0.9999
# Epoch 29/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0665 - accuracy: 0.9868 - val_loss: 0.0286 - val_accuracy: 0.9999
# Epoch 30/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0661 - accuracy: 0.9868 - val_loss: 0.0290 - val_accuracy: 0.9999
# Epoch 31/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0660 - accuracy: 0.9868 - val_loss: 0.0288 - val_accuracy: 0.9999
# Epoch 32/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0661 - accuracy: 0.9867 - val_loss: 0.0282 - val_accuracy: 0.9999
# Epoch 33/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0648 - accuracy: 0.9871 - val_loss: 0.0285 - val_accuracy: 0.9999
# Epoch 34/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0649 - accuracy: 0.9870 - val_loss: 0.0284 - val_accuracy: 0.9999
# Epoch 35/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0638 - accuracy: 0.9873 - val_loss: 0.0280 - val_accuracy: 0.9999
# Epoch 36/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0638 - accuracy: 0.9875 - val_loss: 0.0281 - val_accuracy: 0.9999
# Epoch 37/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0637 - accuracy: 0.9876 - val_loss: 0.0277 - val_accuracy: 0.9999
# Epoch 38/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0632 - accuracy: 0.9875 - val_loss: 0.0278 - val_accuracy: 0.9999
# Epoch 39/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0631 - accuracy: 0.9874 - val_loss: 0.0268 - val_accuracy: 0.9999
# Epoch 40/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0629 - accuracy: 0.9875 - val_loss: 0.0280 - val_accuracy: 0.9999
# Epoch 41/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0617 - accuracy: 0.9879 - val_loss: 0.0265 - val_accuracy: 0.9999
# Epoch 42/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0627 - accuracy: 0.9877 - val_loss: 0.0274 - val_accuracy: 0.9999
# Epoch 43/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0621 - accuracy: 0.9878 - val_loss: 0.0268 - val_accuracy: 0.9999
# Epoch 44/150
# 5600/5600 [==============================] - 36s 7ms/step - loss: 0.0622 - accuracy: 0.9878 - val_loss: 0.0270 - val_accuracy: 0.9999
# Epoch 45/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0617 - accuracy: 0.9879 - val_loss: 0.0268 - val_accuracy: 0.9999
# Epoch 46/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0614 - accuracy: 0.9879 - val_loss: 0.0270 - val_accuracy: 0.9999
# Epoch 47/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0614 - accuracy: 0.9878 - val_loss: 0.0269 - val_accuracy: 0.9999
# Epoch 48/150
# 5600/5600 [==============================] - 36s 7ms/step - loss: 0.0612 - accuracy: 0.9877 - val_loss: 0.0257 - val_accuracy: 0.9999
# Epoch 49/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0606 - accuracy: 0.9879 - val_loss: 0.0258 - val_accuracy: 0.9999
# Epoch 50/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0610 - accuracy: 0.9878 - val_loss: 0.0258 - val_accuracy: 0.9999
# Epoch 51/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0612 - accuracy: 0.9880 - val_loss: 0.0261 - val_accuracy: 0.9999
# Epoch 52/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0604 - accuracy: 0.9880 - val_loss: 0.0258 - val_accuracy: 0.9999
# Epoch 53/150
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0603 - accuracy: 0.9880 - val_loss: 0.0260 - val_accuracy: 0.9999
# Epoch 54/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0603 - accuracy: 0.9880 - val_loss: 0.0250 - val_accuracy: 0.9999
# Epoch 55/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0597 - accuracy: 0.9882 - val_loss: 0.0259 - val_accuracy: 0.9999
# Epoch 56/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0596 - accuracy: 0.9881 - val_loss: 0.0257 - val_accuracy: 0.9999
# Epoch 57/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0591 - accuracy: 0.9884 - val_loss: 0.0253 - val_accuracy: 0.9999
# Epoch 58/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0602 - accuracy: 0.9880 - val_loss: 0.0252 - val_accuracy: 0.9999
# Epoch 59/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0595 - accuracy: 0.9882 - val_loss: 0.0247 - val_accuracy: 0.9999
# Epoch 60/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0596 - accuracy: 0.9882 - val_loss: 0.0251 - val_accuracy: 0.9999
# Epoch 61/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0587 - accuracy: 0.9884 - val_loss: 0.0246 - val_accuracy: 0.9999
# Epoch 62/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0593 - accuracy: 0.9884 - val_loss: 0.0257 - val_accuracy: 0.9999
# Epoch 63/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0581 - accuracy: 0.9885 - val_loss: 0.0251 - val_accuracy: 0.9999
# Epoch 64/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0587 - accuracy: 0.9885 - val_loss: 0.0250 - val_accuracy: 0.9999
# Epoch 65/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0588 - accuracy: 0.9883 - val_loss: 0.0248 - val_accuracy: 0.9999
# Epoch 66/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0579 - accuracy: 0.9887 - val_loss: 0.0244 - val_accuracy: 0.9999
# Epoch 67/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0587 - accuracy: 0.9881 - val_loss: 0.0241 - val_accuracy: 0.9999
# Epoch 68/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0586 - accuracy: 0.9882 - val_loss: 0.0242 - val_accuracy: 0.9999
# Epoch 69/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0586 - accuracy: 0.9884 - val_loss: 0.0243 - val_accuracy: 0.9999
# Epoch 70/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0577 - accuracy: 0.9886 - val_loss: 0.0239 - val_accuracy: 0.9999
# Epoch 71/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0576 - accuracy: 0.9887 - val_loss: 0.0241 - val_accuracy: 0.9999
# Epoch 72/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0570 - accuracy: 0.9889 - val_loss: 0.0246 - val_accuracy: 0.9999
# Epoch 73/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0575 - accuracy: 0.9886 - val_loss: 0.0239 - val_accuracy: 0.9999
# Epoch 74/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0571 - accuracy: 0.9887 - val_loss: 0.0241 - val_accuracy: 0.9999
# Epoch 75/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0572 - accuracy: 0.9887 - val_loss: 0.0240 - val_accuracy: 0.9999
# Epoch 76/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0574 - accuracy: 0.9886 - val_loss: 0.0236 - val_accuracy: 0.9999
# Epoch 77/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0575 - accuracy: 0.9887 - val_loss: 0.0241 - val_accuracy: 0.9999
# Epoch 78/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0567 - accuracy: 0.9889 - val_loss: 0.0243 - val_accuracy: 0.9999
# Epoch 79/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0563 - accuracy: 0.9890 - val_loss: 0.0240 - val_accuracy: 0.9999
# Epoch 80/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0572 - accuracy: 0.9886 - val_loss: 0.0236 - val_accuracy: 0.9999
# Epoch 81/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0568 - accuracy: 0.9885 - val_loss: 0.0234 - val_accuracy: 0.9999
# Epoch 82/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0573 - accuracy: 0.9886 - val_loss: 0.0234 - val_accuracy: 0.9999
# Epoch 83/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0570 - accuracy: 0.9887 - val_loss: 0.0234 - val_accuracy: 0.9999
# Epoch 84/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0573 - accuracy: 0.9885 - val_loss: 0.0237 - val_accuracy: 0.9999
# Epoch 85/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0570 - accuracy: 0.9886 - val_loss: 0.0227 - val_accuracy: 0.9999
# Epoch 86/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0575 - accuracy: 0.9884 - val_loss: 0.0241 - val_accuracy: 0.9999
# Epoch 87/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0562 - accuracy: 0.9889 - val_loss: 0.0234 - val_accuracy: 0.9999
# Epoch 88/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0564 - accuracy: 0.9889 - val_loss: 0.0232 - val_accuracy: 0.9999
# Epoch 89/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0567 - accuracy: 0.9886 - val_loss: 0.0233 - val_accuracy: 0.9999
# Epoch 90/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0560 - accuracy: 0.9888 - val_loss: 0.0233 - val_accuracy: 0.9999
# Epoch 91/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0564 - accuracy: 0.9889 - val_loss: 0.0228 - val_accuracy: 0.9999
# Epoch 92/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0553 - accuracy: 0.9889 - val_loss: 0.0236 - val_accuracy: 0.9999
# Epoch 93/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0559 - accuracy: 0.9888 - val_loss: 0.0234 - val_accuracy: 0.9999
# Epoch 94/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0554 - accuracy: 0.9891 - val_loss: 0.0224 - val_accuracy: 0.9999
# Epoch 95/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0559 - accuracy: 0.9889 - val_loss: 0.0231 - val_accuracy: 0.9999
# Epoch 96/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0557 - accuracy: 0.9888 - val_loss: 0.0233 - val_accuracy: 0.9999
# Epoch 97/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0552 - accuracy: 0.9892 - val_loss: 0.0232 - val_accuracy: 0.9999
# Epoch 98/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0557 - accuracy: 0.9887 - val_loss: 0.0232 - val_accuracy: 0.9999
# Epoch 99/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0553 - accuracy: 0.9890 - val_loss: 0.0226 - val_accuracy: 0.9999
# Epoch 100/150
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0554 - accuracy: 0.9889 - val_loss: 0.0231 - val_accuracy: 0.9999
# Epoch 101/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0553 - accuracy: 0.9891 - val_loss: 0.0227 - val_accuracy: 0.9999
# Epoch 102/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0546 - accuracy: 0.9892 - val_loss: 0.0230 - val_accuracy: 0.9999
# Epoch 103/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0554 - accuracy: 0.9889 - val_loss: 0.0227 - val_accuracy: 0.9999
# Epoch 104/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0552 - accuracy: 0.9890 - val_loss: 0.0230 - val_accuracy: 0.9999
# Epoch 105/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0549 - accuracy: 0.9892 - val_loss: 0.0226 - val_accuracy: 0.9999
# Epoch 106/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0550 - accuracy: 0.9890 - val_loss: 0.0222 - val_accuracy: 0.9999
# Epoch 107/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0552 - accuracy: 0.9890 - val_loss: 0.0229 - val_accuracy: 0.9999
# Epoch 108/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0549 - accuracy: 0.9891 - val_loss: 0.0225 - val_accuracy: 0.9999
# Epoch 109/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0548 - accuracy: 0.9892 - val_loss: 0.0225 - val_accuracy: 0.9999
# Epoch 110/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0552 - accuracy: 0.9890 - val_loss: 0.0231 - val_accuracy: 0.9999
# Epoch 111/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0553 - accuracy: 0.9890 - val_loss: 0.0227 - val_accuracy: 0.9999
# Epoch 112/150
# 5600/5600 [==============================] - 41s 7ms/step - loss: 0.0553 - accuracy: 0.9891 - val_loss: 0.0227 - val_accuracy: 0.9999
# Epoch 113/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0542 - accuracy: 0.9894 - val_loss: 0.0221 - val_accuracy: 0.9999
# Epoch 114/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0548 - accuracy: 0.9890 - val_loss: 0.0223 - val_accuracy: 0.9999
# Epoch 115/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0548 - accuracy: 0.9890 - val_loss: 0.0223 - val_accuracy: 0.9999
# Epoch 116/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0553 - accuracy: 0.9888 - val_loss: 0.0224 - val_accuracy: 0.9999
# Epoch 117/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0538 - accuracy: 0.9896 - val_loss: 0.0223 - val_accuracy: 0.9999
# Epoch 118/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0544 - accuracy: 0.9893 - val_loss: 0.0220 - val_accuracy: 0.9999
# Epoch 119/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0543 - accuracy: 0.9893 - val_loss: 0.0218 - val_accuracy: 0.9999
# Epoch 120/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0538 - accuracy: 0.9893 - val_loss: 0.0223 - val_accuracy: 0.9999
# Epoch 121/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0545 - accuracy: 0.9891 - val_loss: 0.0227 - val_accuracy: 0.9999
# Epoch 122/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0545 - accuracy: 0.9890 - val_loss: 0.0220 - val_accuracy: 0.9999
# Epoch 123/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0541 - accuracy: 0.9893 - val_loss: 0.0216 - val_accuracy: 0.9999
# Epoch 124/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0544 - accuracy: 0.9892 - val_loss: 0.0229 - val_accuracy: 0.9999
# Epoch 125/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0542 - accuracy: 0.9895 - val_loss: 0.0219 - val_accuracy: 0.9999
# Epoch 126/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0542 - accuracy: 0.9893 - val_loss: 0.0212 - val_accuracy: 0.9999
# Epoch 127/150
# 5600/5600 [==============================] - ETA: 0s - loss: 0.0542 - accuracy: 0.9892Epoch 128/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0541 - accuracy: 0.9890 - val_loss: 0.0223 - val_accuracy: 0.9999
# Epoch 129/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0541 - accuracy: 0.9891 - val_loss: 0.0224 - val_accuracy: 0.9999
# Epoch 130/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0541 - accuracy: 0.9892 - val_loss: 0.0214 - val_accuracy: 0.9999
# Epoch 131/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0538 - accuracy: 0.9893 - val_loss: 0.0215 - val_accuracy: 0.9999
# Epoch 132/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0541 - accuracy: 0.9892 - val_loss: 0.0218 - val_accuracy: 0.9999
# Epoch 133/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0538 - accuracy: 0.9891 - val_loss: 0.0225 - val_accuracy: 0.9999
# Epoch 134/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0539 - accuracy: 0.9891 - val_loss: 0.0221 - val_accuracy: 0.9999
# Epoch 135/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0539 - accuracy: 0.9892 - val_loss: 0.0221 - val_accuracy: 0.9999
# Epoch 136/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0541 - accuracy: 0.9891 - val_loss: 0.0221 - val_accuracy: 0.9999
# Epoch 137/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0535 - accuracy: 0.9894 - val_loss: 0.0218 - val_accuracy: 0.9999
# Epoch 138/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0532 - accuracy: 0.9897 - val_loss: 0.0219 - val_accuracy: 0.9999
# Epoch 139/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0536 - accuracy: 0.9892 - val_loss: 0.0220 - val_accuracy: 0.9999
# Epoch 140/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0547 - accuracy: 0.9891 - val_loss: 0.0213 - val_accuracy: 0.9999
# Epoch 141/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0535 - accuracy: 0.9896 - val_loss: 0.0212 - val_accuracy: 0.9999
# Epoch 142/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0537 - accuracy: 0.9892 - val_loss: 0.0213 - val_accuracy: 0.9999
# Epoch 143/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0530 - accuracy: 0.9897 - val_loss: 0.0216 - val_accuracy: 0.9999
# Epoch 144/150
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0535 - accuracy: 0.9892 - val_loss: 0.0214 - val_accuracy: 0.9999
# Epoch 145/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0534 - accuracy: 0.9892 - val_loss: 0.0219 - val_accuracy: 0.9999
# Epoch 146/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0522 - accuracy: 0.9897 - val_loss: 0.0216 - val_accuracy: 0.9999
# Epoch 147/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0531 - accuracy: 0.9895 - val_loss: 0.0222 - val_accuracy: 0.9999
# Epoch 148/150
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0537 - accuracy: 0.9893 - val_loss: 0.0217 - val_accuracy: 0.9999
# Epoch 149/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0533 - accuracy: 0.9894 - val_loss: 0.0212 - val_accuracy: 0.9999
# Epoch 150/150
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0534 - accuracy: 0.9893 - val_loss: 0.0220 - val_accuracy: 0.9999
# 3500/3500 [==============================] - 12s 3ms/step
# [[10844     8     0     0   105   314     0     1     5     0]
#  [    0  7946   477   445  2403    47     0    24     1     0]
#  [    0   295  8115   284  2347    24     2   146    11     1]
#  [    0   586   528  5312  4429   107    18   169    67     3]
#  [    2   218   172  1352  9138   125     9   200    61    20]
#  [   31   122   101   180   733  9867     1    65    74     0]
#  [    0     4    10    32   159     9 10854     3     1     2]
#  [    0   126   349   306  1127    41     2  9067   110     1]
#  [    0     0     0     1    18     6     1     0 11086     0]
#  [    0     0     0     0     9     0     0     0     0 11141]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     11277
#            1       0.85      0.70      0.77     11343
#            2       0.83      0.72      0.77     11225
#            3       0.67      0.47      0.56     11219
#            4       0.45      0.81      0.58     11297
#            5       0.94      0.88      0.91     11174
#            6       1.00      0.98      0.99     11074
#            7       0.94      0.81      0.87     11129
#            8       0.97      1.00      0.98     11112
#            9       1.00      1.00      1.00     11150
#
#     accuracy                           0.83    112000
#    macro avg       0.86      0.83      0.84    112000
# weighted avg       0.86      0.83      0.84    112000

# %%
# Plot training/validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
# Calculate evaluation metrics
accuracy = accuracy_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
recall = recall_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
precision = precision_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
f1score = f1_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
classification_rep = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.8336607142857143
# Recall: 0.8336607142857143
# Precision: 0.8633047606050583
# F1-Score: 0.8397813480200178
# Confusion Matrix:
#  [[10844     8     0     0   105   314     0     1     5     0]
#  [    0  7946   477   445  2403    47     0    24     1     0]
#  [    0   295  8115   284  2347    24     2   146    11     1]
#  [    0   586   528  5312  4429   107    18   169    67     3]
#  [    2   218   172  1352  9138   125     9   200    61    20]
#  [   31   122   101   180   733  9867     1    65    74     0]
#  [    0     4    10    32   159     9 10854     3     1     2]
#  [    0   126   349   306  1127    41     2  9067   110     1]
#  [    0     0     0     1    18     6     1     0 11086     0]
#  [    0     0     0     0     9     0     0     0     0 11141]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     11277
#            1       0.85      0.70      0.77     11343
#            2       0.83      0.72      0.77     11225
#            3       0.67      0.47      0.56     11219
#            4       0.45      0.81      0.58     11297
#            5       0.94      0.88      0.91     11174
#            6       1.00      0.98      0.99     11074
#            7       0.94      0.81      0.87     11129
#            8       0.97      1.00      0.98     11112
#            9       1.00      1.00      1.00     11150
#
#     accuracy                           0.83    112000
#    macro avg       0.86      0.83      0.84    112000
# weighted avg       0.86      0.83      0.84    112000

# %%
# Plot training loss and validation/test loss over each epoch of training
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy and Training Loss')
plt.xlabel('Accuracy')
plt.ylabel('Loss')
plt.legend()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  plt.figure(figsize=(8,6.5))
  ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='twilight_shifted')
  sns.set(font_scale=1)

  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n');
  ax.xaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])
  ax.yaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])

  plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees

  plt.tight_layout()
  # plt.savefig("F1.eps", format = 'eps')
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model")
conf_mat(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']
print("Detection rates of Hybrid RF-LSTM Model:", detection_rates)
# Out:
# Detection rates of Hybrid RF-LSTM Model: {0: 0.961603263279241, 1: 0.700520144582562, 2: 0.7229398663697104, 3: 0.4734824850699706, 4: 0.8088873152164291, 5: 0.8830320386611777, 6: 0.9801336463789055, 7: 0.8147183035313146, 8: 0.9976601871850252, 9: 0.9991928251121076}

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']

# Plot detection rates
labels = detection_rates.keys()
rates = detection_rates.values()

plt.bar(labels, rates)
plt.xlabel('Class')
plt.ylabel('Detection Rate')
plt.title('Detection Rates of Hybrid RF-LSTM Model')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']

# Extract the class labels and detection rates
labels = list(detection_rates.keys())
rates = list(detection_rates.values())

# Plot the line graph with filled area and labels
plt.figure(figsize=(8, 4))
plt.plot(labels, rates, marker='s', linestyle='-', linewidth=2.5)
plt.fill_between(labels, rates, color='mediumslateblue', alpha=0.4)

# Add labels to each data point
for i in range(len(labels)):
    plt.text(labels[i], rates[i], "{:.4f}".format(rates[i]), ha='center', va='bottom')

plt.xlabel('Class')
plt.ylabel('Detection Rate')
plt.title('Detection Rates of Hybrid RF-LSTM Model')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
#from keras.utils import np_utils
from tensorflow.python.keras.utils import np_utils

# Convert y_test and test_rf_lstm_predictions to one-hot encoded format
y_test_onehot = np_utils.to_categorical(np.argmax(y_test, axis=1))
test_rf_lstm_predictions_onehot = np_utils.to_categorical(test_rf_lstm_predictions, num_classes=10)  # Convert to one-hot encoded format with 10 classes

# Compute the AUC and ROC curves for each class
n_classes = y_test_onehot.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_onehot[:, i], test_rf_lstm_predictions_onehot[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_onehot.ravel(), test_rf_lstm_predictions_onehot.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta']  # Adjust the colors as needed
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='Class {0} (AUC = {1:0.6f})'.format(i, roc_auc[i]))

# Plot the micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='black', lw=2, linestyle='--', label='Micro-average (AUC = {0:0.6f})'.format(roc_auc["micro"]))

plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.05])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Print confusion matrix and classification report
##print(confusion_matrix(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))
##print(classification_report(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))

# %%
import matplotlib.pyplot as plt

# Extract the labels and rates from the detection rates dictionary
labels = list(detection_rates.keys())
rates = list(detection_rates.values())

# Plot the bar chart
plt.bar(labels, rates)

# Add labels and units to each bar
for i in range(len(labels)):
    plt.text(labels[i], rates[i], "{:.5f}".format(rates[i]), ha='center', va='bottom', color='black')

# Add axis labels and title
plt.xlabel('Class')
plt.ylabel('Detection Rates')
plt.title('Detection Rates of Hybrid RF-LSTM Model')

# Display the plot
plt.show()
