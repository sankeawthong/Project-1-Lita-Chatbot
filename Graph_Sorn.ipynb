# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/Graph_Sorn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Create a 2D array
data_1 = np.array([[77.556, 0.001, 22.443, 0.000, 0.000, 0.000],
                  [0.000, 99.108, 0.230, 0.224, 0.438, 0.000],
                  [0.000, 0.000, 99.995, 0.000, 0.005, 0.000],
                  [0.000, 16.241, 0.024, 83.736, 0.000, 0.000],
                  [0.001, 0.000, 0.001, 0.000, 94.615, 5.384],
                  [0.000, 8.353, 0.000, 0.000, 3.032, 88.614]])

# Convert NumPy array to Pandas DataFrame
df_1 = pd.DataFrame(data_1)
# Heat map
fig, ax = plt.subplots()
ax.imshow(data_1)

# Add the labels
ax.set_xticks(np.arange(len(xlabs)), labels = xlabs)
ax.set_yticks(np.arange(len(ylabs)), labels = ylabs)

# Labels
xlabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
ylabs = ["BL", "AL", "BUL", "V", "WB", "WL"]

# Create a heatmap
plt.imshow(df_1, cmap="YlGnBu")
plt.colorbar()
plt.xticks(range(len(xlabs)), labels = xlabs)  #, rotation=45 , , fontsize=12, fontname="Times New Roman"
plt.yticks(range(len(ylabs)), labels = ylabs)  # , fontsize=12, fontname="Times New Roman"
plt.title("Percent change from 2001 to 2005")

# Show the values on the heatmap
for i in range(len(df_1)):
    for j in range(len(df_1.columns)):
        value = df_1.iloc[i, j]
        plt.text(j, i, value, ha="center", va="center", color="black")

#plt.tight_layout()
##plt.xticks(fontsize=12, fontname="Times New Roman")
##plt.yticks(fontsize=12, fontname="Times New Roman")
#plt.xlabs(fontsize=12, fontname="Times New Roman")
#plt.ylabs(fontsize=12, fontname="Times New Roman")
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#Graph 2
# Create a NumPy array
data_2 = np.array([[28.116,	32.195,	31.340,	0.000,	8.349,	0.000],
                  [4.471,	76.698,	3.639,	0.016,	0.472,	14.703],
                  [1.743,	26.011,	67.782,	0.000,	3.375,	1.089],
                  [4.425,	4.665,	8.818,	81.845,	0.247,	0.000],
                  [0.131,	8.865,	10.243,	0.086,	70.770,	9.904],
                  [0.012,	32.866,	0.860,	0.000,	15.297,	50.966]])

# Convert NumPy array to Pandas DataFrame
df_2 = pd.DataFrame(data_2)

# Heat map
fig, ax = plt.subplots()
ax.imshow(data_2)

# Labels
xlabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
ylabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
# Add the labels
ax.set_xticks(np.arange(len(xlabs)), labels = xlabs)
ax.set_yticks(np.arange(len(ylabs)), labels = ylabs)

# Create a heatmap
#plt.imshow(df, cmap="YlGnBu")
#plt.colorbar()
#plt.xticks(range(len(df.columns)), df.columns, rotation=45)
#plt.yticks(range(len(df)), df.columns)
#plt.title("Heatmap of the Data")


# Create a heatmap
plt.imshow(df_2, cmap="YlGnBu")
plt.colorbar()
plt.xticks(range(len(xlabs)), labels = xlabs)  #, rotation=45
plt.yticks(range(len(ylabs)), labels = ylabs)
plt.title("Percent change from 2005 to 2010")

# Show the values on the heatmap
for i in range(len(df_2)):
    for j in range(len(df_2.columns)):
        value = df_2.iloc[i, j]
        plt.text(j, i, value, ha="center", va="center", color="black")

plt.show()

# %%
#Graph 3
# Create a NumPy array
data_3 = np.array([[31.134,	7.600,	21.947,	0.000,	0.290,	39.028],
                  [31.704,	35.667,	10.503,	0.031, 2.738, 19.357],
                  [2.134,	2.163,	70.521,	0.000,	21.453,	3.729],
                  [2.967,	0.000,	0.000,	96.904,	0.129,	0.000],
                  [4.941,	1.062,	5.449,	0.000,	49.893,	38.656],
                  [20.608,	1.707, 2.635,	0.090,	17.369,	57.590]])

# Convert NumPy array to Pandas DataFrame
df_3 = pd.DataFrame(data_3)

# Heat map
fig, ax = plt.subplots()
ax.imshow(data_3)

# Labels
xlabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
ylabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
# Add the labels
ax.set_xticks(np.arange(len(xlabs)), labels = xlabs)
ax.set_yticks(np.arange(len(ylabs)), labels = ylabs)

# Create a heatmap
#plt.imshow(df, cmap="YlGnBu")
#plt.colorbar()
#plt.xticks(range(len(df.columns)), df.columns, rotation=45)
#plt.yticks(range(len(df)), df.columns)
#plt.title("Heatmap of the Data")


# Create a heatmap
plt.imshow(df_3, cmap="YlGnBu")
plt.colorbar()
plt.xticks(range(len(xlabs)), labels = xlabs)  #, rotation=45
plt.yticks(range(len(ylabs)), labels = ylabs)
plt.title("Percent change from 2010 to 2015")

# Show the values on the heatmap
for i in range(len(df_3)):
    for j in range(len(df_3.columns)):
        value = df_3.iloc[i, j]
        plt.text(j, i, value, ha="center", va="center", color="black")

plt.show()

# %%
#Graph 4
# Create a NumPy array
data_4 = np.array([[73.465,	0.927,	7.951,	1.023,	3.458,	13.176],
                  [30.695,	56.960,	6.980,	0.069,	1.785,	3.511],
                  [15.797,	0.286,	71.996,	0.001,	8.402,	3.517],
                  [25.364,	14.850,	46.059,	10.095,	0.716,	2.915],
                  [11.674,	0.195,	5.255,	0.000,	77.271,	5.605],
                  [26.781,	2.428,	4.033,	0.076,	7.722,	58.959]])

# Convert NumPy array to Pandas DataFrame
df_4 = pd.DataFrame(data_4)

# Heat map
fig, ax = plt.subplots()
ax.imshow(data_4)

# Labels
xlabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
ylabs = ["BL", "AL", "BUL", "V", "WB", "WL"]
# Add the labels
ax.set_xticks(np.arange(len(xlabs)), labels = xlabs)
ax.set_yticks(np.arange(len(ylabs)), labels = ylabs)

# Create a heatmap
#plt.imshow(df, cmap="YlGnBu")
#plt.colorbar()
#plt.xticks(range(len(df.columns)), df.columns, rotation=45)
#plt.yticks(range(len(df)), df.columns)
#plt.title("Heatmap of the Data")


# Create a heatmap
plt.imshow(df_4, cmap="YlGnBu")
plt.colorbar()
plt.xticks(range(len(xlabs)), labels = xlabs)  #, rotation=45
plt.yticks(range(len(ylabs)), labels = ylabs)
plt.title("Percent change from 2015 to 2020")

# Show the values on the heatmap
for i in range(len(df_4)):
    for j in range(len(df_4.columns)):
        value = df_4.iloc[i, j]
        plt.text(j, i, value, ha="center", va="center", color="black")

plt.show()
