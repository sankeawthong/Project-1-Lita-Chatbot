# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/%5B20250313%5D%20Thesis%20hybrid%20RF-LSTM%20model%20with%20Adversarial%20Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Imports various Python libraries necessary
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils import np_utils
#from keras.utils import np_utils
#from tensorflow.keras import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification

# %%
# Load dataset
dataset = pd.read_csv("dataset.csv")

# Preprocessing: Handle missing values (if any)
dataset = dataset.dropna() # Remove missing values

# %%
dataset
# Out:
#         Event        Time  S_Node  Node_id  Rest_Energy  Trace_Level  \
# 0           1    0.100000      79       79   600.000000            5
# 1           2    0.100963      78       78   599.979723            5
# 2           2    0.100963      76       76   599.979722            5
# 3           2    0.100964      75       75   599.979722            5
# 4           2    0.100964     118      118   599.979722            5
# ...       ...         ...     ...      ...          ...          ...
# 312101      4  656.526536     140      140   465.332078            5
# 312102      4  657.209643     140      140   465.191806            5
# 312103      4  657.891729     140      140   465.051737            5
# 312104      4  658.574656     140      140   464.911501            5
# 312105      4  679.054956     140      140   460.705905            5
#
#         Mac_Type_Pckt  Source_IP_Port  Des_IP_Port  Packet_Size  TTL  \
# 0                   0          79.255        1.255           48   30
# 1                 800          79.255        1.255           48   30
# 2                 800          79.255        1.255           48   30
# 3                 800          79.255        1.255           48   30
# 4                 800          79.255        1.255           48   30
# ...               ...             ...          ...          ...  ...
# 312101            800         140.255        1.255           48   30
# 312102            800         140.255        1.255           48   30
# 312103            800         140.255        1.255           48   30
# 312104            800         140.255        1.255           48   30
# 312105            800         140.255        1.255           48   30
#
#         Hop_Count  Broadcast_ID  Dest_Node_Num  Dest_Seq_Num  Src_Node_ID  \
# 0               1             1            100             0           79
# 1               1             1            100             0           79
# 2               1             1            100             0           79
# 3               1             1            100             0           79
# 4               1             1            100             0           79
# ...           ...           ...            ...           ...          ...
# 312101          1            31            100            16          140
# 312102          1            33            100            16          140
# 312103          1            35            100            16          140
# 312104          1            37            100            16          140
# 312105          1            42            100            16          140
#
#         Src_Seq_Num  Class
# 0                 4      0
# 1                 4      0
# 2                 4      0
# 3                 4      0
# 4                 4      0
# ...             ...    ...
# 312101           68      1
# 312102           72      1
# 312103           76      1
# 312104           80      1
# 312105           90      1
#
# [312106 rows x 18 columns]

# %%
# Encode non-numeric columns (if any)
for column in dataset.columns:
    if dataset[column].dtype == 'object':  # Identify categorical columns
        dataset[column] = LabelEncoder().fit_transform(dataset[column])

# Separate features (X) and target (y)
X = dataset.drop(['Class'], axis=1)  # Assuming 'Class' is the target column
y = dataset['Class']

print("Original Class Distribution:", np.bincount(y))
# Out:
# Original Class Distribution: [262851  11766   7645  29844]

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler # Import StandardScaler here
# Standardize the features
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# !pip install -U imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scipy<2,>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.14.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (3.5.0)

# %%
from imblearn.over_sampling import SMOTE

# Apply SMOTE to balance the data
smote = SMOTE(random_state=42)
X, y = smote.fit_resample(X, y)

# Verify the balanced dataset distribution
print("Balanced Class Distribution:", np.bincount(y))
# Out:
# Balanced Class Distribution: [262851 262851 262851 262851]

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101, stratify=y)

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input - Adding a new axis to create a 2D array before reshaping
train_rf_features = train_rf_features[:, np.newaxis]  # Reshape to (n_samples, 1)
test_rf_features = test_rf_features[:, np.newaxis]    # Reshape to (n_samples, 1)

# Reshape for LSTM input - Using the correct shape for 3D input
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))

# %%
# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(4, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Convert y_train and y_test to one-hot encoded format
from tensorflow.keras.utils import to_categorical
y_train = to_categorical(y_train, num_classes=4)  # Assuming you have 4 classes
y_test = to_categorical(y_test, num_classes=4)
history = lstm_model.fit(train_rf_features, y_train, epochs=100, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 77s 7ms/step - accuracy: 0.9592 - loss: 0.1314 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 2/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 83s 7ms/step - accuracy: 0.9999 - loss: 0.0032 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 3/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 7ms/step - accuracy: 0.9999 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 4/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 72s 7ms/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 5/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 68s 6ms/step - accuracy: 0.9999 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 6/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 80s 6ms/step - accuracy: 0.9999 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 7/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 6ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 8/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 9/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 69s 7ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 10/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 6ms/step - accuracy: 0.9999 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 11/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 12/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 79s 6ms/step - accuracy: 0.9999 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 13/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 84s 6ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 9.6676e-04
# Epoch 14/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 6ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 9.9393e-04
# Epoch 15/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 6ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 8.5457e-04
# Epoch 16/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 83s 6ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 9.9974e-04
# Epoch 17/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 70s 7ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 18/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 66s 6ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 8.8637e-04
# Epoch 19/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 69s 7ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 8.4449e-04
# Epoch 20/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 6ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 8.5083e-04
# Epoch 21/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 66s 6ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 9.4087e-04
# Epoch 22/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 6ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 8.3924e-04
# Epoch 23/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 7.3814e-04
# Epoch 24/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 66s 6ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 7.9754e-04
# Epoch 25/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 67s 6ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 7.4734e-04
# Epoch 26/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 9.7242e-04
# Epoch 27/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 76s 6ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.3802e-04
# Epoch 28/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 0.9999 - loss: 9.5518e-04 - val_accuracy: 1.0000 - val_loss: 6.4017e-04
# Epoch 29/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 67s 6ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 7.2050e-04
# Epoch 30/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 6ms/step - accuracy: 0.9999 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 7.6664e-04
# Epoch 31/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 71s 7ms/step - accuracy: 0.9999 - loss: 9.0786e-04 - val_accuracy: 1.0000 - val_loss: 8.8763e-04
# Epoch 32/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 79s 7ms/step - accuracy: 1.0000 - loss: 8.9727e-04 - val_accuracy: 1.0000 - val_loss: 5.8806e-04
# Epoch 33/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - accuracy: 0.9999 - loss: 9.1437e-04 - val_accuracy: 1.0000 - val_loss: 7.6914e-04
# Epoch 34/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 76s 6ms/step - accuracy: 0.9999 - loss: 8.9641e-04 - val_accuracy: 1.0000 - val_loss: 6.6521e-04
# Epoch 35/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 68s 6ms/step - accuracy: 0.9999 - loss: 9.1873e-04 - val_accuracy: 1.0000 - val_loss: 5.8543e-04
# Epoch 36/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 86s 7ms/step - accuracy: 0.9999 - loss: 9.4584e-04 - val_accuracy: 1.0000 - val_loss: 7.0430e-04
# Epoch 37/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 7ms/step - accuracy: 0.9999 - loss: 8.6748e-04 - val_accuracy: 1.0000 - val_loss: 7.7733e-04
# Epoch 38/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 67s 6ms/step - accuracy: 0.9999 - loss: 9.7440e-04 - val_accuracy: 1.0000 - val_loss: 8.1395e-04
# Epoch 39/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 85s 7ms/step - accuracy: 0.9999 - loss: 9.0708e-04 - val_accuracy: 1.0000 - val_loss: 8.1611e-04
# Epoch 40/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 76s 6ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 6.1417e-04
# Epoch 41/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 0.9999 - loss: 8.9411e-04 - val_accuracy: 1.0000 - val_loss: 7.0679e-04
# Epoch 42/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 6ms/step - accuracy: 0.9999 - loss: 8.5094e-04 - val_accuracy: 1.0000 - val_loss: 6.7091e-04
# Epoch 43/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 65s 6ms/step - accuracy: 0.9999 - loss: 8.5766e-04 - val_accuracy: 1.0000 - val_loss: 7.1004e-04
# Epoch 44/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 85s 6ms/step - accuracy: 0.9999 - loss: 9.7914e-04 - val_accuracy: 1.0000 - val_loss: 7.4375e-04
# Epoch 45/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 70s 7ms/step - accuracy: 1.0000 - loss: 7.9354e-04 - val_accuracy: 1.0000 - val_loss: 5.6088e-04
# Epoch 46/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 66s 6ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 7.0431e-04
# Epoch 47/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 66s 6ms/step - accuracy: 0.9999 - loss: 9.3644e-04 - val_accuracy: 1.0000 - val_loss: 7.9098e-04
# Epoch 48/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 65s 6ms/step - accuracy: 0.9999 - loss: 9.2624e-04 - val_accuracy: 1.0000 - val_loss: 6.2999e-04
# Epoch 49/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 0.9999 - loss: 8.1683e-04 - val_accuracy: 1.0000 - val_loss: 6.7925e-04
# Epoch 50/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 7ms/step - accuracy: 0.9999 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 5.5293e-04
# Epoch 51/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 70s 7ms/step - accuracy: 0.9999 - loss: 8.9518e-04 - val_accuracy: 1.0000 - val_loss: 7.3245e-04
# Epoch 52/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 66s 6ms/step - accuracy: 0.9999 - loss: 9.6557e-04 - val_accuracy: 1.0000 - val_loss: 6.7782e-04
# Epoch 53/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 70s 7ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 6.2048e-04
# Epoch 54/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 83s 7ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.1044e-04
# Epoch 55/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 77s 6ms/step - accuracy: 0.9999 - loss: 8.9204e-04 - val_accuracy: 1.0000 - val_loss: 6.5064e-04
# Epoch 56/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 0.9999 - loss: 9.2560e-04 - val_accuracy: 1.0000 - val_loss: 5.8497e-04
# Epoch 57/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 7ms/step - accuracy: 0.9999 - loss: 9.6067e-04 - val_accuracy: 1.0000 - val_loss: 6.7616e-04
# Epoch 58/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 84s 7ms/step - accuracy: 1.0000 - loss: 7.1416e-04 - val_accuracy: 1.0000 - val_loss: 5.3096e-04
# Epoch 59/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 74s 7ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 4.9801e-04
# Epoch 60/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 7ms/step - accuracy: 0.9999 - loss: 7.9917e-04 - val_accuracy: 1.0000 - val_loss: 7.4792e-04
# Epoch 61/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 76s 6ms/step - accuracy: 1.0000 - loss: 8.0133e-04 - val_accuracy: 1.0000 - val_loss: 5.7737e-04
# Epoch 62/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 0.9999 - loss: 9.6936e-04 - val_accuracy: 1.0000 - val_loss: 7.5530e-04
# Epoch 63/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 77s 6ms/step - accuracy: 0.9999 - loss: 9.3331e-04 - val_accuracy: 1.0000 - val_loss: 7.3972e-04
# Epoch 64/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 73s 7ms/step - accuracy: 1.0000 - loss: 7.8998e-04 - val_accuracy: 1.0000 - val_loss: 7.5662e-04
# Epoch 65/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 7ms/step - accuracy: 1.0000 - loss: 8.6641e-04 - val_accuracy: 1.0000 - val_loss: 4.8316e-04
# Epoch 66/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 80s 7ms/step - accuracy: 0.9999 - loss: 8.8371e-04 - val_accuracy: 1.0000 - val_loss: 6.2749e-04
# Epoch 67/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 77s 6ms/step - accuracy: 0.9999 - loss: 8.2086e-04 - val_accuracy: 1.0000 - val_loss: 4.5101e-04
# Epoch 68/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 68s 6ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.6757e-04
# Epoch 69/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 85s 7ms/step - accuracy: 0.9999 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 5.0664e-04
# Epoch 70/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 83s 7ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 5.5516e-04
# Epoch 71/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 79s 6ms/step - accuracy: 0.9999 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 5.6267e-04
# Epoch 72/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 69s 7ms/step - accuracy: 0.9999 - loss: 7.3613e-04 - val_accuracy: 1.0000 - val_loss: 6.4648e-04
# Epoch 73/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 7ms/step - accuracy: 0.9999 - loss: 7.8451e-04 - val_accuracy: 1.0000 - val_loss: 5.7277e-04
# Epoch 74/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 7ms/step - accuracy: 0.9999 - loss: 0.0010 - val_accuracy: 1.0000 - val_loss: 6.6602e-04
# Epoch 75/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 72s 7ms/step - accuracy: 0.9999 - loss: 8.2787e-04 - val_accuracy: 1.0000 - val_loss: 6.8223e-04
# Epoch 76/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 68s 6ms/step - accuracy: 1.0000 - loss: 7.9545e-04 - val_accuracy: 1.0000 - val_loss: 4.6392e-04
# Epoch 77/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 83s 7ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.1238e-04
# Epoch 78/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 69s 7ms/step - accuracy: 0.9999 - loss: 8.7280e-04 - val_accuracy: 1.0000 - val_loss: 5.9457e-04
# Epoch 79/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 6ms/step - accuracy: 0.9999 - loss: 8.1751e-04 - val_accuracy: 1.0000 - val_loss: 6.0233e-04
# Epoch 80/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 82s 6ms/step - accuracy: 0.9999 - loss: 7.8662e-04 - val_accuracy: 1.0000 - val_loss: 5.0680e-04
# Epoch 81/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 80s 6ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 5.0370e-04
# Epoch 82/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 67s 6ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 7.2398e-04
# Epoch 83/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 87s 7ms/step - accuracy: 1.0000 - loss: 7.9912e-04 - val_accuracy: 1.0000 - val_loss: 6.6447e-04
# Epoch 84/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 68s 6ms/step - accuracy: 0.9999 - loss: 9.6282e-04 - val_accuracy: 1.0000 - val_loss: 7.3039e-04
# Epoch 85/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 84s 7ms/step - accuracy: 0.9999 - loss: 8.6814e-04 - val_accuracy: 1.0000 - val_loss: 5.9196e-04
# Epoch 86/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 7ms/step - accuracy: 0.9999 - loss: 9.2085e-04 - val_accuracy: 1.0000 - val_loss: 6.7016e-04
# Epoch 87/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 85s 7ms/step - accuracy: 1.0000 - loss: 7.5893e-04 - val_accuracy: 1.0000 - val_loss: 6.5825e-04
# Epoch 88/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 7ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.7425e-04
# Epoch 89/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 6ms/step - accuracy: 0.9999 - loss: 9.6542e-04 - val_accuracy: 1.0000 - val_loss: 7.3600e-04
# Epoch 90/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 72s 7ms/step - accuracy: 0.9999 - loss: 9.1285e-04 - val_accuracy: 1.0000 - val_loss: 5.4311e-04
# Epoch 91/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 81s 7ms/step - accuracy: 0.9999 - loss: 9.8313e-04 - val_accuracy: 1.0000 - val_loss: 7.8391e-04
# Epoch 92/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 68s 6ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 7.6103e-04
# Epoch 93/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 84s 7ms/step - accuracy: 1.0000 - loss: 8.3270e-04 - val_accuracy: 1.0000 - val_loss: 6.4632e-04
# Epoch 94/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 72s 7ms/step - accuracy: 0.9999 - loss: 9.1528e-04 - val_accuracy: 1.0000 - val_loss: 8.8835e-04
# Epoch 95/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 67s 6ms/step - accuracy: 0.9999 - loss: 9.0532e-04 - val_accuracy: 1.0000 - val_loss: 7.2565e-04
# Epoch 96/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 73s 7ms/step - accuracy: 1.0000 - loss: 8.0854e-04 - val_accuracy: 1.0000 - val_loss: 5.5123e-04
# Epoch 97/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 77s 7ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 6.0884e-04
# Epoch 98/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 84s 7ms/step - accuracy: 0.9999 - loss: 8.2645e-04 - val_accuracy: 1.0000 - val_loss: 6.1631e-04
# Epoch 99/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 84s 7ms/step - accuracy: 0.9998 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 8.5775e-04
# Epoch 100/100
# 10515/10515 ━━━━━━━━━━━━━━━━━━━━ 78s 7ms/step - accuracy: 0.9999 - loss: 9.2717e-04 - val_accuracy: 1.0000 - val_loss: 6.5970e-04
# 6572/6572 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step

# %%
# Plot training/validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
# Calculate evaluation metrics
accuracy = accuracy_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
recall = recall_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
precision = precision_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
f1score = f1_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
classification_rep = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.99926764662523
# Recall: 0.99926764662523
# Precision: 0.9992676373194184
# F1-Score: 0.9992675779151672
# Confusion Matrix:
#  [[52559     5     6     0]
#  [   25 52514     0    31]
#  [    7     0 52559     4]
#  [    0    45    31 52495]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     52570
#            1       1.00      1.00      1.00     52570
#            2       1.00      1.00      1.00     52570
#            3       1.00      1.00      1.00     52571
#
#     accuracy                           1.00    210281
#    macro avg       1.00      1.00      1.00    210281
# weighted avg       1.00      1.00      1.00    210281

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# prompt: Display confusion matrix in heatmap

import seaborn as sns

# Assuming 'confusion_mat' is your confusion matrix from the previous code

plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mat, annot=True, fmt="d", cmap="bone",
            xticklabels=['Normal','Flooding','Blackhole','Forwarding'], # Replace with your actual class labels
            yticklabels=['Normal','Flooding','Blackhole','Forwarding']) # Replace with your actual class labels
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix Heatmap")
plt.show()

# %%
# prompt: Display AUC and ROC curves with also show micro avg.

from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Binarize the output
y_test_bin = label_binarize(np.argmax(y_test, axis=1), classes=[0, 1, 2, 3])
n_classes = y_test_bin.shape[1]

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], test_lstm_features[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), test_lstm_features.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot ROC curves for the multiclass problem
plt.figure()
lw = 2
plt.plot(fpr[0], tpr[0], color='darkorange',
         lw=lw, label='ROC curve (area = %0.10f) for class 0' % roc_auc[0])
plt.plot(fpr[1], tpr[1], color='darkgreen',
         lw=lw, label='ROC curve (area = %0.10f) for class 1' % roc_auc[1])
plt.plot(fpr[2], tpr[2], color='darkblue',
         lw=lw, label='ROC curve (area = %0.10f) for class 2' % roc_auc[2])
plt.plot(fpr[3], tpr[3], color='darkred',
         lw=lw, label='ROC curve (area = %0.10f) for class 3' % roc_auc[3])

plt.plot(fpr["micro"], tpr["micro"],
         label='micro-average ROC curve (area = {0:0.10f})'
               ''.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)


plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic Example')
plt.legend(loc="lower right")
plt.show()

# Print AUC scores for each class and the micro average
print("AUC Score for class 0:", roc_auc[0])
print("AUC Score for class 1:", roc_auc[1])
print("AUC Score for class 2:", roc_auc[2])
print("AUC Score for class 3:", roc_auc[3])
print("Micro-average AUC Score:", roc_auc["micro"])
# Out:
# AUC Score for class 0: 0.9998066052744805
# AUC Score for class 1: 0.99911383191158
# AUC Score for class 2: 0.9997345090774803
# AUC Score for class 3: 0.9992200595804418
# Micro-average AUC Score: 0.9994593893399227

# %%
# prompt: Display detection rates in each class

from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Assuming 'confusion_mat' is your confusion matrix from the previous code
# and test_lstm_features and y_test are available

# ... (Your existing code)

# Binarize the output
y_test_bin = label_binarize(np.argmax(y_test, axis=1), classes=[0, 1, 2, 3])
n_classes = y_test_bin.shape[1]

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], test_lstm_features[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
    print(f"Detection Rate for Class {i}: {roc_auc[i]}")
# Out:
# Detection Rate for Class 0: 0.9998066052744805
# Detection Rate for Class 1: 0.99911383191158
# Detection Rate for Class 2: 0.9997345090774803
# Detection Rate for Class 3: 0.9992200595804418
