# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/SMOTE-NearMiss%20with%20Hybrid%20RF-LSTM%20(100%20ep%20%26%20Dp%3D0.3%2C%20l2%3D0.000001)%20with%20K-folds_4%20classes%20(05052024).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SMOTE-MissNear Hybrid RF-LSTM for 4 class classifications with k-folds, kernel=0.0001, Dropout=0.2(100ep)**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
#from keras.utils import np_utils
from tensorflow.python.keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from collections import Counter

# %%
# Load dataset
dataset = pd.read_csv("dataset.csv")
dataset.isnull().sum()
# Out:
# Event             0
# Time              0
# S_Node            0
# Node_id           0
# Rest_Energy       0
# Trace_Level       0
# Mac_Type_Pckt     0
# Source_IP_Port    0
# Des_IP_Port       0
# Packet_Size       0
# TTL               0
# Hop_Count         0
# Broadcast_ID      0
# Dest_Node_Num     0
# Dest_Seq_Num      0
# Src_Node_ID       0
# Src_Seq_Num       0
# Class             0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312106 entries, 0 to 312105
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Event           312106 non-null  int64
#  1   Time            312106 non-null  float64
#  2   S_Node          312106 non-null  int64
#  3   Node_id         312106 non-null  int64
#  4   Rest_Energy     312106 non-null  float64
#  5   Trace_Level     312106 non-null  int64
#  6   Mac_Type_Pckt   312106 non-null  int64
#  7   Source_IP_Port  312106 non-null  float64
#  8   Des_IP_Port     312106 non-null  float64
#  9   Packet_Size     312106 non-null  int64
#  10  TTL             312106 non-null  int64
#  11  Hop_Count       312106 non-null  int64
#  12  Broadcast_ID    312106 non-null  int64
#  13  Dest_Node_Num   312106 non-null  int64
#  14  Dest_Seq_Num    312106 non-null  int64
#  15  Src_Node_ID     312106 non-null  int64
#  16  Src_Seq_Num     312106 non-null  int64
#  17  Class           312106 non-null  int64
# dtypes: float64(4), int64(14)
# memory usage: 42.9 MB

# %%
print(dataset["Class"].unique())
# Out:
# [0 1 2 3]

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras.utils import np_utils

encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])
y = np_utils.to_categorical(y, num_classes=4)  # update to 4 classes
X = dataset.drop(['Class'], axis=1)
X = X.values
print(X.shape)
print(y.shape)
# Out:
# (312106, 17)
# (312106, 4)

# %%
# Data preprocessing
y = dataset['Class'].values
X = dataset.drop(['Class'],axis=1)
X=X.values
print(X)
print(y)
# Out:
# [[1.00000000e+00 1.00000000e-01 7.90000000e+01 ... 0.00000000e+00
#   7.90000000e+01 4.00000000e+00]
#  [2.00000000e+00 1.00963167e-01 7.80000000e+01 ... 0.00000000e+00
#   7.90000000e+01 4.00000000e+00]
#  [2.00000000e+00 1.00963500e-01 7.60000000e+01 ... 0.00000000e+00
#   7.90000000e+01 4.00000000e+00]
#  ...
#  [4.00000000e+00 6.57891729e+02 1.40000000e+02 ... 1.60000000e+01
#   1.40000000e+02 7.60000000e+01]
#  [4.00000000e+00 6.58574656e+02 1.40000000e+02 ... 1.60000000e+01
#   1.40000000e+02 8.00000000e+01]
#  [4.00000000e+00 6.79054956e+02 1.40000000e+02 ... 1.60000000e+01
#   1.40000000e+02 9.00000000e+01]]
# [0 0 0 ... 1 1 1]

# %%
import collections as c
counter = c.Counter(y)
print(counter)
# Out:
# Counter({0: 262851, 3: 29844, 1: 11766, 2: 7645})

# %% [markdown]
# **SMOTE-NearMiss Databalancing**

# %%
# Check class distribution
counter = Counter(y)
print("Before SMOTE:", counter)
# Out:
# Before SMOTE: Counter({0: 262851, 3: 29844, 1: 11766, 2: 7645})

# %%
# Data preprocessing
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)
counter = c.Counter(y)
print(counter)
# Out:
# Counter({0: 262851, 1: 262851, 2: 262851, 3: 262851})

# %%
# Apply NearMiss for undersampling
nm = NearMiss()
X_res, y_res = nm.fit_resample(X, y)
print("After NearMiss:", Counter(y_res))
# Out:
# After NearMiss: Counter({0: 262851, 1: 262851, 2: 262851, 3: 262851})

# %% [markdown]
# **Data Splitting (Train 80/Test 20)**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Utilized K-Fold Cross Validation**

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
# Define the number of classes
num_classes = 4

# Define the number of folds
num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Initialize lists to store evaluation metrics for each fold
accuracies = []
recalls = []
precisions = []
f1scores = []
confusion_matrices = []
classification_reports = []

# %%
# Iterate through the folds
#for fold, (train_index, test_index) in enumerate(skf.split(X, y.argmax(axis=1))):
for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# **Hybrid RF-LSTM for 4 class Ver.2.2**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input
#train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
#test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, 1))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, 1))

# %%
train_rf_features = train_rf_features[:y_train.shape[0]]
#y_train = np.concatenate((y_train, np.zeros((train_rf_features.shape[0] - y_train.shape[0], 4))))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.000001)))
lstm_model.add(Dropout(0.3))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.000001)))
lstm_model.add(Dropout(0.3))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.000001)))
lstm_model.add(Dropout(0.3))
lstm_model.add(Dense(4, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train = to_categorical(y_train, num_classes=4)  # One-hot encode y_train

history = lstm_model.fit(train_rf_features, y_train, epochs=100, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)
# Out:
# Epoch 1/100
# 11829/11829 [==============================] - 106s 8ms/step - loss: 0.0256 - accuracy: 0.9920 - val_loss: 4.9341e-04 - val_accuracy: 1.0000
# Epoch 2/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 9.8221e-04 - accuracy: 0.9999 - val_loss: 3.6073e-04 - val_accuracy: 1.0000
# Epoch 3/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 7.0060e-04 - accuracy: 0.9999 - val_loss: 2.9194e-04 - val_accuracy: 1.0000
# Epoch 4/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 5.3443e-04 - accuracy: 0.9999 - val_loss: 2.4069e-04 - val_accuracy: 1.0000
# Epoch 5/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 4.6625e-04 - accuracy: 0.9999 - val_loss: 2.1453e-04 - val_accuracy: 1.0000
# Epoch 6/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 4.0452e-04 - accuracy: 0.9999 - val_loss: 1.9466e-04 - val_accuracy: 1.0000
# Epoch 7/100
# 11829/11829 [==============================] - 95s 8ms/step - loss: 3.1391e-04 - accuracy: 1.0000 - val_loss: 1.5754e-04 - val_accuracy: 1.0000
# Epoch 8/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 3.7300e-04 - accuracy: 0.9999 - val_loss: 1.5739e-04 - val_accuracy: 1.0000
# Epoch 9/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 3.0409e-04 - accuracy: 0.9999 - val_loss: 1.3456e-04 - val_accuracy: 1.0000
# Epoch 10/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 3.2251e-04 - accuracy: 0.9999 - val_loss: 1.3930e-04 - val_accuracy: 1.0000
# Epoch 11/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 2.8885e-04 - accuracy: 1.0000 - val_loss: 1.2853e-04 - val_accuracy: 1.0000
# Epoch 12/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 2.6723e-04 - accuracy: 1.0000 - val_loss: 1.2485e-04 - val_accuracy: 1.0000
# Epoch 13/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 2.4931e-04 - accuracy: 1.0000 - val_loss: 1.2343e-04 - val_accuracy: 1.0000
# Epoch 14/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 2.8393e-04 - accuracy: 1.0000 - val_loss: 1.1020e-04 - val_accuracy: 1.0000
# Epoch 15/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 2.5703e-04 - accuracy: 0.9999 - val_loss: 1.2303e-04 - val_accuracy: 1.0000
# Epoch 16/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 2.3531e-04 - accuracy: 1.0000 - val_loss: 1.1731e-04 - val_accuracy: 1.0000
# Epoch 17/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 1.9611e-04 - accuracy: 1.0000 - val_loss: 1.0885e-04 - val_accuracy: 1.0000
# Epoch 18/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.9739e-04 - accuracy: 1.0000 - val_loss: 1.0255e-04 - val_accuracy: 1.0000
# Epoch 19/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.9670e-04 - accuracy: 1.0000 - val_loss: 1.0015e-04 - val_accuracy: 1.0000
# Epoch 20/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.7148e-04 - accuracy: 1.0000 - val_loss: 9.7136e-05 - val_accuracy: 1.0000
# Epoch 21/100
# 11829/11829 [==============================] - 107s 9ms/step - loss: 2.5216e-04 - accuracy: 1.0000 - val_loss: 9.3639e-05 - val_accuracy: 1.0000
# Epoch 22/100
# 11829/11829 [==============================] - 104s 9ms/step - loss: 1.7473e-04 - accuracy: 1.0000 - val_loss: 9.9529e-05 - val_accuracy: 1.0000
# Epoch 23/100
# 11829/11829 [==============================] - 103s 9ms/step - loss: 1.5763e-04 - accuracy: 1.0000 - val_loss: 8.5637e-05 - val_accuracy: 1.0000
# Epoch 24/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.4524e-04 - accuracy: 1.0000 - val_loss: 8.1789e-05 - val_accuracy: 1.0000
# Epoch 25/100
# 11829/11829 [==============================] - 103s 9ms/step - loss: 1.8643e-04 - accuracy: 1.0000 - val_loss: 9.5893e-05 - val_accuracy: 1.0000
# Epoch 26/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.7908e-04 - accuracy: 1.0000 - val_loss: 9.6288e-05 - val_accuracy: 1.0000
# Epoch 27/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.4309e-04 - accuracy: 1.0000 - val_loss: 8.2612e-05 - val_accuracy: 1.0000
# Epoch 28/100
# 11829/11829 [==============================] - 103s 9ms/step - loss: 1.6606e-04 - accuracy: 1.0000 - val_loss: 9.6944e-05 - val_accuracy: 1.0000
# Epoch 29/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.5483e-04 - accuracy: 1.0000 - val_loss: 8.5446e-05 - val_accuracy: 1.0000
# Epoch 30/100
# 11829/11829 [==============================] - 118s 10ms/step - loss: 1.8710e-04 - accuracy: 1.0000 - val_loss: 9.1120e-05 - val_accuracy: 1.0000
# Epoch 31/100
# 11829/11829 [==============================] - 117s 10ms/step - loss: 1.8230e-04 - accuracy: 1.0000 - val_loss: 8.8516e-05 - val_accuracy: 1.0000
# Epoch 32/100
# 11829/11829 [==============================] - 115s 10ms/step - loss: 1.3869e-04 - accuracy: 1.0000 - val_loss: 8.1313e-05 - val_accuracy: 1.0000
# Epoch 33/100
# 11829/11829 [==============================] - 112s 9ms/step - loss: 1.4786e-04 - accuracy: 1.0000 - val_loss: 8.6858e-05 - val_accuracy: 1.0000
# Epoch 34/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.3836e-04 - accuracy: 1.0000 - val_loss: 8.4382e-05 - val_accuracy: 1.0000
# Epoch 35/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.7209e-04 - accuracy: 1.0000 - val_loss: 8.6744e-05 - val_accuracy: 1.0000
# Epoch 36/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 1.7936e-04 - accuracy: 1.0000 - val_loss: 8.2191e-05 - val_accuracy: 1.0000
# Epoch 37/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.4696e-04 - accuracy: 1.0000 - val_loss: 8.5157e-05 - val_accuracy: 1.0000
# Epoch 38/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.3861e-04 - accuracy: 1.0000 - val_loss: 8.0124e-05 - val_accuracy: 1.0000
# Epoch 39/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.4321e-04 - accuracy: 1.0000 - val_loss: 7.4062e-05 - val_accuracy: 1.0000
# Epoch 40/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.6474e-04 - accuracy: 1.0000 - val_loss: 7.9799e-05 - val_accuracy: 1.0000
# Epoch 41/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.3658e-04 - accuracy: 1.0000 - val_loss: 7.2419e-05 - val_accuracy: 1.0000
# Epoch 42/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.9152e-04 - accuracy: 1.0000 - val_loss: 7.6263e-05 - val_accuracy: 1.0000
# Epoch 43/100
# 11829/11829 [==============================] - 94s 8ms/step - loss: 1.6697e-04 - accuracy: 1.0000 - val_loss: 8.1878e-05 - val_accuracy: 1.0000
# Epoch 44/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.4570e-04 - accuracy: 1.0000 - val_loss: 8.8661e-05 - val_accuracy: 1.0000
# Epoch 45/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.4860e-04 - accuracy: 1.0000 - val_loss: 7.5210e-05 - val_accuracy: 1.0000
# Epoch 46/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 1.3596e-04 - accuracy: 1.0000 - val_loss: 7.2810e-05 - val_accuracy: 1.0000
# Epoch 47/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.4852e-04 - accuracy: 1.0000 - val_loss: 7.5503e-05 - val_accuracy: 1.0000
# Epoch 48/100
# 11829/11829 [==============================] - 103s 9ms/step - loss: 1.3893e-04 - accuracy: 1.0000 - val_loss: 7.4055e-05 - val_accuracy: 1.0000
# Epoch 49/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 1.3711e-04 - accuracy: 1.0000 - val_loss: 7.0066e-05 - val_accuracy: 1.0000
# Epoch 50/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.2676e-04 - accuracy: 1.0000 - val_loss: 7.7051e-05 - val_accuracy: 1.0000
# Epoch 51/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.3675e-04 - accuracy: 1.0000 - val_loss: 7.9304e-05 - val_accuracy: 1.0000
# Epoch 52/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.4435e-04 - accuracy: 1.0000 - val_loss: 8.2735e-05 - val_accuracy: 1.0000
# Epoch 53/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.5214e-04 - accuracy: 1.0000 - val_loss: 7.2706e-05 - val_accuracy: 1.0000
# Epoch 54/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 1.5703e-04 - accuracy: 1.0000 - val_loss: 7.3280e-05 - val_accuracy: 1.0000
# Epoch 55/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.4619e-04 - accuracy: 1.0000 - val_loss: 8.1225e-05 - val_accuracy: 1.0000
# Epoch 56/100
# 11829/11829 [==============================] - 95s 8ms/step - loss: 1.7902e-04 - accuracy: 1.0000 - val_loss: 8.8456e-05 - val_accuracy: 1.0000
# Epoch 57/100
# 11829/11829 [==============================] - 94s 8ms/step - loss: 1.3664e-04 - accuracy: 1.0000 - val_loss: 7.4267e-05 - val_accuracy: 1.0000
# Epoch 58/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.4193e-04 - accuracy: 1.0000 - val_loss: 7.4163e-05 - val_accuracy: 1.0000
# Epoch 59/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.2779e-04 - accuracy: 1.0000 - val_loss: 6.8545e-05 - val_accuracy: 1.0000
# Epoch 60/100
# 11829/11829 [==============================] - 95s 8ms/step - loss: 1.6483e-04 - accuracy: 1.0000 - val_loss: 8.3831e-05 - val_accuracy: 1.0000
# Epoch 61/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.2461e-04 - accuracy: 1.0000 - val_loss: 8.3701e-05 - val_accuracy: 1.0000
# Epoch 62/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 1.5919e-04 - accuracy: 1.0000 - val_loss: 7.6816e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 2.1053e-04 - accuracy: 1.0000 - val_loss: 8.0913e-05 - val_accuracy: 1.0000
# Epoch 64/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.8409e-04 - accuracy: 1.0000 - val_loss: 8.5104e-05 - val_accuracy: 1.0000
# Epoch 65/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.4259e-04 - accuracy: 1.0000 - val_loss: 8.1796e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 11829/11829 [==============================] - 111s 9ms/step - loss: 1.3315e-04 - accuracy: 1.0000 - val_loss: 7.4040e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 1.4329e-04 - accuracy: 1.0000 - val_loss: 7.9606e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.2137e-04 - accuracy: 1.0000 - val_loss: 7.4979e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.9744e-04 - accuracy: 1.0000 - val_loss: 8.1481e-05 - val_accuracy: 1.0000
# Epoch 70/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.3565e-04 - accuracy: 1.0000 - val_loss: 8.1312e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.9896e-04 - accuracy: 1.0000 - val_loss: 7.3655e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 2.0059e-04 - accuracy: 1.0000 - val_loss: 8.9987e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.2601e-04 - accuracy: 1.0000 - val_loss: 7.5188e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.1869e-04 - accuracy: 1.0000 - val_loss: 6.8517e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.4215e-04 - accuracy: 1.0000 - val_loss: 6.5059e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.3748e-04 - accuracy: 1.0000 - val_loss: 7.3283e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.3382e-04 - accuracy: 1.0000 - val_loss: 6.8504e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.8391e-04 - accuracy: 1.0000 - val_loss: 7.7068e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.9631e-04 - accuracy: 1.0000 - val_loss: 8.6191e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.4557e-04 - accuracy: 1.0000 - val_loss: 6.9380e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 11829/11829 [==============================] - 104s 9ms/step - loss: 1.3126e-04 - accuracy: 1.0000 - val_loss: 7.1202e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 11829/11829 [==============================] - 103s 9ms/step - loss: 1.7645e-04 - accuracy: 1.0000 - val_loss: 7.2151e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 1.8218e-04 - accuracy: 1.0000 - val_loss: 8.3015e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 1.4447e-04 - accuracy: 1.0000 - val_loss: 8.3417e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 11829/11829 [==============================] - 101s 9ms/step - loss: 1.9672e-04 - accuracy: 1.0000 - val_loss: 7.6022e-05 - val_accuracy: 1.0000
# Epoch 86/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.6754e-04 - accuracy: 1.0000 - val_loss: 7.5564e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.5013e-04 - accuracy: 1.0000 - val_loss: 7.6414e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.3793e-04 - accuracy: 1.0000 - val_loss: 7.5314e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.3648e-04 - accuracy: 1.0000 - val_loss: 6.9112e-05 - val_accuracy: 1.0000
# Epoch 90/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.5666e-04 - accuracy: 1.0000 - val_loss: 8.1569e-05 - val_accuracy: 1.0000
# Epoch 91/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.0971e-04 - accuracy: 1.0000 - val_loss: 6.8218e-05 - val_accuracy: 1.0000
# Epoch 92/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.3592e-04 - accuracy: 1.0000 - val_loss: 7.0200e-05 - val_accuracy: 1.0000
# Epoch 93/100
# 11829/11829 [==============================] - 102s 9ms/step - loss: 1.1447e-04 - accuracy: 1.0000 - val_loss: 6.8699e-05 - val_accuracy: 1.0000
# Epoch 94/100
# 11829/11829 [==============================] - 96s 8ms/step - loss: 1.6520e-04 - accuracy: 1.0000 - val_loss: 7.1843e-05 - val_accuracy: 1.0000
# Epoch 95/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.5161e-04 - accuracy: 1.0000 - val_loss: 7.9975e-05 - val_accuracy: 1.0000
# Epoch 96/100
# 11829/11829 [==============================] - 100s 8ms/step - loss: 1.5038e-04 - accuracy: 1.0000 - val_loss: 7.2316e-05 - val_accuracy: 1.0000
# Epoch 97/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.9015e-04 - accuracy: 1.0000 - val_loss: 7.7516e-05 - val_accuracy: 1.0000
# Epoch 98/100
# 11829/11829 [==============================] - 99s 8ms/step - loss: 1.1517e-04 - accuracy: 1.0000 - val_loss: 6.8423e-05 - val_accuracy: 1.0000
# Epoch 99/100
# 11829/11829 [==============================] - 97s 8ms/step - loss: 1.6695e-04 - accuracy: 1.0000 - val_loss: 7.6044e-05 - val_accuracy: 1.0000
# Epoch 100/100
# 11829/11829 [==============================] - 98s 8ms/step - loss: 1.5542e-04 - accuracy: 1.0000 - val_loss: 7.5579e-05 - val_accuracy: 1.0000
# 3286/3286 [==============================] - 11s 3ms/step

# %%
import collections as c

# Calculate the confusion matrix and classification report
# Ensure that y_test and test_rf_lstm_predictions are 2D arrays
confusion = confusion_matrix(y_test, test_rf_lstm_predictions)
classification_report_result = classification_report(y_test, test_rf_lstm_predictions)

# Print the confusion matrix and classification report
print("Confusion Matrix:")
print(confusion)
print("\nClassification Report:")
print(classification_report_result)

# Plot the training and validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Confusion Matrix:
# [[26280     4     1     0]
#  [    5 26277     0     3]
#  [    1     0 26283     1]
#  [    0     7     3 26275]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     26285
#            1       1.00      1.00      1.00     26285
#            2       1.00      1.00      1.00     26285
#            3       1.00      1.00      1.00     26285
#
#     accuracy                           1.00    105140
#    macro avg       1.00      1.00      1.00    105140
# weighted avg       1.00      1.00      1.00    105140

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, test_rf_lstm_predictions)
recall = recall_score(y_test, test_rf_lstm_predictions, average='weighted')
precision = precision_score(y_test, test_rf_lstm_predictions, average='weighted')
f1score = f1_score(y_test, test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(y_test, test_rf_lstm_predictions)
classification_rep = classification_report(y_test, test_rf_lstm_predictions)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.9997622217995055
# Recall: 0.9997622217995055
# Precision: 0.9997622301183203
# F1-Score: 0.9997622214364373
# Confusion Matrix:
#  [[26280     4     1     0]
#  [    5 26277     0     3]
#  [    1     0 26283     1]
#  [    0     7     3 26275]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     26285
#            1       1.00      1.00      1.00     26285
#            2       1.00      1.00      1.00     26285
#            3       1.00      1.00      1.00     26285
#
#     accuracy                           1.00    105140
#    macro avg       1.00      1.00      1.00    105140
# weighted avg       1.00      1.00      1.00    105140

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot training loss and validation/test loss over each epoch of training
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy and Training Loss')
plt.xlabel('Accuracy')
plt.ylabel('Loss')
plt.legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  #plt.figure(figsize=(6,5.5))
  plt.figure(figsize=(8,6.5))
  #ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='tab20c')
  ax = sns.heatmap(cm, annot=True, fmt=".0f", cmap="PuBu",
                 vmin=0, vmax=27000, center=0, square=True, linewidths=1.5)
  sns.set(font_scale=1)
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n');
  ax.xaxis.set_ticklabels(['Normal','Flooding','Blackhole','Forwarding'])
  ax.yaxis.set_ticklabels(['Normal','Flooding','Blackhole','Forwarding'])
  ##plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  ##plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.tight_layout()
  # plt.savefig("F1.eps", format = 'eps')
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model")
conf_mat(y_test, test_rf_lstm_predictions)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
# Compute TP, TN, FP, FN for each class
cm = confusion_matrix(y_test, test_rf_lstm_predictions)
FP = cm.sum(axis=0) - np.diag(cm)
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

# Compute False Positive Rate (FPR) and True Positive Rate (TPR) for each class
FPR = FP / (FP + TN)
TPR = TP / (TP + FN)

# Print FPR and TPR for each class
for i in range(4):
    print(f"Class {i} - FPR: {FPR[i]}, TPR: {TPR[i]}")
# Out:
# Class 0 - FPR: 7.608902415826517e-05, TPR: 0.9998097774396043
# Class 1 - FPR: 0.00013949654429015282, TPR: 0.999695643903367
# Class 2 - FPR: 5.0726016105510116e-05, TPR: 0.9999239109758418
# Class 3 - FPR: 5.0726016105510116e-05, TPR: 0.9996195548792087

# %%
# prompt: Show the detection rates of the model in 8 digits numerical

# Calculate detection rates and format them to 8 digits
detection_rates = TP / (TP + FN)
detection_rates_formatted = ["{:.10f}".format(rate) for rate in detection_rates]

# Print detection rates
for i, rate in enumerate(detection_rates_formatted):
    print(f"Class {i} Detection Rate: {rate}")
# Out:
# Class 0 Detection Rate: 0.9998097774
# Class 1 Detection Rate: 0.9996956439
# Class 2 Detection Rate: 0.9999239110
# Class 3 Detection Rate: 0.9996195549

# %%
# prompt: Create Discrete distribution as horizontal bar chart of the detection rates of class 0-3

import numpy as np
import matplotlib.pyplot as plt

# Create a list of class labels
class_labels = ['Normal', 'Flooding', 'Blackhole', 'Forwarding']

# Create a list of detection rates
detection_rates = [0.9998097774, 0.9996956439, 0.9999239110, 0.9996195549]

# Set the bar width
bar_width = 0.5

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(class_labels, detection_rates, bar_width, align='center', color='grey')

# Set the axis labels and title
plt.xlabel('Detection Rate')
plt.ylabel('Class')
plt.title('Discrete Distribution of Detection Rates')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Assuming that y_test is not one-hot encoded
# Binarize the output labels for each class
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])
n_classes = y_test_bin.shape[1]

# Predict class probabilities for LSTM model
test_lstm_probs = lstm_model.predict(test_rf_features)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], test_lstm_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), test_lstm_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot all ROC curves
plt.figure(figsize=(10, 8))

# Plot micro-average ROC curve
plt.plot(fpr['micro'], tpr['micro'],
         label='micro-average ROC curve (area = {0:0.10f})'.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

# Plot ROC curve for each class
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.10f})'.format(i, roc_auc[i]))

# Plot chance level
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Multiclass')
plt.legend(loc="lower right")
plt.show()
# Out:
# 3286/3286 [==============================] - 11s 3ms/step
