# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/Project%232_Hybrid%20RF-LSTM%20for%2010%20class%20classifications(UNSW-NB15)_35%20epoch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Hybrid RF-LSTM for 10 class classifications**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from imblearn.over_sampling import SMOTE

# %%
# Load dataset
dataset = pd.read_csv("dataset_P2.2.csv")
dataset.isnull().sum()
# Out:
# id                   0
# dur                  0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# Class                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 175341 non-null  int64
#  1   dur                175341 non-null  float64
#  2   spkts              175341 non-null  int64
#  3   dpkts              175341 non-null  int64
#  4   sbytes             175341 non-null  int64
#  5   dbytes             175341 non-null  int64
#  6   rate               175341 non-null  float64
#  7   sttl               175341 non-null  int64
#  8   dttl               175341 non-null  int64
#  9   sload              175341 non-null  float64
#  10  dload              175341 non-null  float64
#  11  sloss              175341 non-null  int64
#  12  dloss              175341 non-null  int64
#  13  sinpkt             175341 non-null  float64
#  14  dinpkt             175341 non-null  float64
#  15  sjit               175341 non-null  float64
#  16  djit               175341 non-null  float64
#  17  swin               175341 non-null  int64
#  18  stcpb              175341 non-null  int64
#  19  dtcpb              175341 non-null  int64
#  20  dwin               175341 non-null  int64
#  21  tcprtt             175341 non-null  float64
#  22  synack             175341 non-null  float64
#  23  ackdat             175341 non-null  float64
#  24  smean              175341 non-null  int64
#  25  dmean              175341 non-null  int64
#  26  trans_depth        175341 non-null  int64
#  27  response_body_len  175341 non-null  int64
#  28  ct_srv_src         175341 non-null  int64
#  29  ct_state_ttl       175341 non-null  int64
#  30  ct_dst_ltm         175341 non-null  int64
#  31  ct_src_dport_ltm   175341 non-null  int64
#  32  ct_dst_sport_ltm   175341 non-null  int64
#  33  ct_dst_src_ltm     175341 non-null  int64
#  34  is_ftp_login       175341 non-null  int64
#  35  ct_ftp_cmd         175341 non-null  int64
#  36  ct_flw_http_mthd   175341 non-null  int64
#  37  ct_src_ltm         175341 non-null  int64
#  38  ct_srv_dst         175341 non-null  int64
#  39  is_sm_ips_ports    175341 non-null  int64
#  40  Class              175341 non-null  int64
# dtypes: float64(11), int64(30)
# memory usage: 54.8 MB

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])
y = np_utils.to_categorical(y, num_classes=10)
X = dataset.drop(['Class'],axis=1)
X=X.values
print(X.shape)
print(y.shape)
# Out:
# (175341, 40)
# (175341, 10)

# %%
# Data preprocessing
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Hybrid RF-LSTM Model**

# %%
# LSTM model
model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.summary()

X_train_lstm = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test_lstm = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

history = model.fit(X_train_lstm, y_train, epochs=35, batch_size=64, validation_data=(X_test_lstm, y_test), verbose=1)

# Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# Combine models
y_pred_lstm = model.predict(X_test_lstm)
y_pred_lstm = np.argmax(y_pred_lstm, axis=1)
y_pred_lstm = np_utils.to_categorical(y_pred_lstm, num_classes=10)

y_pred = y_pred_lstm * 0.5 + y_pred_rf * 0.5
y_pred = np.argmax(y_pred, axis=1)

# Calculate accuracy and other evaluation metrics
accuracy = accuracy_score(np.argmax(y_test, axis=1), y_pred)
report = classification_report(np.argmax(y_test, axis=1), y_pred)
confusion_matrix = confusion_matrix(np.argmax(y_test, axis=1), y_pred)

# Print the results
print("Accuracy:", accuracy)
print("Classification Report:\n", report)
print("Confusion Matrix:\n", confusion_matrix)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 17,546
# Trainable params: 17,546
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/35
# 7000/7000 [==============================] - 231s 33ms/step - loss: 0.9730 - accuracy: 0.6302 - val_loss: 0.8325 - val_accuracy: 0.6764
# Epoch 2/35
# 7000/7000 [==============================] - 209s 30ms/step - loss: 0.8119 - accuracy: 0.6854 - val_loss: 0.7786 - val_accuracy: 0.6935
# Epoch 3/35
# 7000/7000 [==============================] - 228s 33ms/step - loss: 0.7770 - accuracy: 0.6961 - val_loss: 0.7575 - val_accuracy: 0.7032
# Epoch 4/35
# 7000/7000 [==============================] - 209s 30ms/step - loss: 0.7539 - accuracy: 0.7024 - val_loss: 0.7488 - val_accuracy: 0.7013
# Epoch 5/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.7407 - accuracy: 0.7063 - val_loss: 0.7370 - val_accuracy: 0.7021
# Epoch 6/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.7252 - accuracy: 0.7113 - val_loss: 0.7031 - val_accuracy: 0.7184
# Epoch 7/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.7163 - accuracy: 0.7138 - val_loss: 0.7066 - val_accuracy: 0.7179
# Epoch 8/35
# 7000/7000 [==============================] - 209s 30ms/step - loss: 0.7074 - accuracy: 0.7166 - val_loss: 0.7092 - val_accuracy: 0.7136
# Epoch 9/35
# 7000/7000 [==============================] - 231s 33ms/step - loss: 0.7031 - accuracy: 0.7185 - val_loss: 0.6838 - val_accuracy: 0.7223
# Epoch 10/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.6957 - accuracy: 0.7202 - val_loss: 0.6859 - val_accuracy: 0.7216
# Epoch 11/35
# 7000/7000 [==============================] - 211s 30ms/step - loss: 0.6922 - accuracy: 0.7217 - val_loss: 0.6791 - val_accuracy: 0.7238
# Epoch 12/35
# 7000/7000 [==============================] - 230s 33ms/step - loss: 0.6869 - accuracy: 0.7230 - val_loss: 0.6736 - val_accuracy: 0.7267
# Epoch 13/35
# 7000/7000 [==============================] - 232s 33ms/step - loss: 0.6825 - accuracy: 0.7252 - val_loss: 0.7004 - val_accuracy: 0.7196
# Epoch 14/35
# 7000/7000 [==============================] - 211s 30ms/step - loss: 0.6792 - accuracy: 0.7263 - val_loss: 0.6702 - val_accuracy: 0.7298
# Epoch 15/35
# 7000/7000 [==============================] - 213s 30ms/step - loss: 0.6742 - accuracy: 0.7279 - val_loss: 0.6742 - val_accuracy: 0.7272
# Epoch 16/35
# 7000/7000 [==============================] - 211s 30ms/step - loss: 0.6737 - accuracy: 0.7282 - val_loss: 0.6729 - val_accuracy: 0.7292
# Epoch 17/35
# 7000/7000 [==============================] - 230s 33ms/step - loss: 0.6691 - accuracy: 0.7304 - val_loss: 0.6629 - val_accuracy: 0.7322
# Epoch 18/35
# 7000/7000 [==============================] - 211s 30ms/step - loss: 0.6660 - accuracy: 0.7313 - val_loss: 0.6689 - val_accuracy: 0.7290
# Epoch 19/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.6648 - accuracy: 0.7318 - val_loss: 0.6585 - val_accuracy: 0.7339
# Epoch 20/35
# 7000/7000 [==============================] - 212s 30ms/step - loss: 0.6612 - accuracy: 0.7333 - val_loss: 0.6622 - val_accuracy: 0.7305
# Epoch 21/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.6611 - accuracy: 0.7333 - val_loss: 0.6554 - val_accuracy: 0.7352
# Epoch 22/35
# 7000/7000 [==============================] - 209s 30ms/step - loss: 0.6583 - accuracy: 0.7340 - val_loss: 0.6570 - val_accuracy: 0.7323
# Epoch 23/35
# 7000/7000 [==============================] - 230s 33ms/step - loss: 0.6570 - accuracy: 0.7349 - val_loss: 0.6774 - val_accuracy: 0.7281
# Epoch 24/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.6561 - accuracy: 0.7346 - val_loss: 0.6613 - val_accuracy: 0.7325
# Epoch 25/35
# 7000/7000 [==============================] - 210s 30ms/step - loss: 0.6555 - accuracy: 0.7351 - val_loss: 0.6604 - val_accuracy: 0.7349
# Epoch 26/35
# 7000/7000 [==============================] - 230s 33ms/step - loss: 0.6528 - accuracy: 0.7364 - val_loss: 0.6493 - val_accuracy: 0.7369
# Epoch 27/35
# 7000/7000 [==============================] - 209s 30ms/step - loss: 0.6512 - accuracy: 0.7376 - val_loss: 0.6557 - val_accuracy: 0.7369
# Epoch 28/35
# 7000/7000 [==============================] - 211s 30ms/step - loss: 0.6519 - accuracy: 0.7367 - val_loss: 0.6528 - val_accuracy: 0.7386
# Epoch 29/35
# 7000/7000 [==============================] - 212s 30ms/step - loss: 0.6482 - accuracy: 0.7381 - val_loss: 0.6613 - val_accuracy: 0.7356
# Epoch 30/35
# 7000/7000 [==============================] - 231s 33ms/step - loss: 0.6528 - accuracy: 0.7368 - val_loss: 0.6518 - val_accuracy: 0.7352
# Epoch 31/35
# 7000/7000 [==============================] - 230s 33ms/step - loss: 0.6472 - accuracy: 0.7386 - val_loss: 0.6460 - val_accuracy: 0.7400
# Epoch 32/35
# 7000/7000 [==============================] - 212s 30ms/step - loss: 0.6470 - accuracy: 0.7384 - val_loss: 0.6489 - val_accuracy: 0.7378
# Epoch 33/35
# 7000/7000 [==============================] - 232s 33ms/step - loss: 0.6478 - accuracy: 0.7382 - val_loss: 0.6567 - val_accuracy: 0.7352
# Epoch 34/35
# 7000/7000 [==============================] - 232s 33ms/step - loss: 0.6486 - accuracy: 0.7384 - val_loss: 0.6443 - val_accuracy: 0.7396
# Epoch 35/35
# 7000/7000 [==============================] - 227s 32ms/step - loss: 0.6448 - accuracy: 0.7396 - val_loss: 0.6489 - val_accuracy: 0.7383
# 3500/3500 [==============================] - 32s 9ms/step
# Accuracy: 0.8162232142857143
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     11277
#            1       0.76      0.72      0.74     11343
#            2       0.57      0.83      0.68     11225
#            3       0.47      0.57      0.51     11219
#            4       0.82      0.52      0.63     11297
#            5       0.94      0.85      0.89     11174
#            6       1.00      0.98      0.99     11074
#            7       0.95      0.80      0.87     11129
#            8       0.93      0.97      0.95     11112
#            9       0.99      0.98      0.98     11150
#
#     accuracy                           0.82    112000
#    macro avg       0.84      0.82      0.82    112000
# weighted avg       0.84      0.82      0.82    112000
#
# Confusion Matrix:
#  [[10860    25     1     2    43   327     0     5    13     1]
#  [    3  8146  1836  1321    22     1     0     2    12     0]
#  [    0   733  9289  1090    30    10     0    21    45     7]
#  [    4   978  2828  6372   783    64     0    43   128    19]
#  [   15   374   990  3541  5864   104     1   196   149    63]
#  [  395   168   351   431   163  9510     0    34   114     8]
#  [    0     5    38    89   100    19 10812     1     6     4]
#  [    3   228   927   759   121    34     0  8876   171    10]
#  [    2     2    15    40    23    77     1   158 10793     1]
#  [    0     0     0     4    27     1     0     1   222 10895]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics 
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  plt.figure(figsize=(8,6.5))
  ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='YlGnBu')
  sns.set(font_scale=1)
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n')
  ax.xaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])
  ax.yaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])

  plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees

  plt.tight_layout()
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model") 
conf_mat(np.argmax(y_test, axis=1), y_pred)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
report = classification_report(np.argmax(y_test, axis=1), y_pred, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']
print("Detection rates:", detection_rates)
# Out:
# Detection rates: {0: 0.9630220803405161, 1: 0.7181521643304241, 2: 0.8275278396436525, 3: 0.5679650592744452, 4: 0.5190758608480127, 5: 0.8510828709504206, 6: 0.9763409788694238, 7: 0.797555934944739, 8: 0.9712922966162707, 9: 0.9771300448430493}
