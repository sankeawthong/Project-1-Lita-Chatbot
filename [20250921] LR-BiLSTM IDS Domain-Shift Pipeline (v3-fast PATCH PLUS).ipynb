# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/%5B20250921%5D%20LR-BiLSTM%20IDS%20Domain-Shift%20Pipeline%20(v3-fast%20PATCH%20PLUS).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IDS Domain-Shift Pipeline (v3) — Leakage-safe + Expanded MQTT filter
# --------------------------------------------------------------------
# - Drops label-like columns from features to prevent leakage
# - Aligns feature schemas between train and test (categorical one-hot + scaler from train)
# - Expanded MQTT filtering for NF-ToN-IoT (checks DST and SRC ports; common fallbacks)
# - Defaults to RESAMPLING="smote_tomek" and LOSS_MODE="focal"
# - Keeps ablations: LR-only, BiLSTM-only, LR→BiLSTM; FGSM/PGD adversarial mixing for sequence models
# - Metrics: Macro-F1, AUROC/PR-AUC, ECE/MCE, FPR@1e-3/1e-4; Per-class recall/F1; Reliability bins
#
# Outputs under ./outputs_v3/
#
# Author: Sine & Mentor

# %% [markdown]
# IDS Domain-Shift Pipeline (v3 • FIXED)
# =====================================
# Key fixes based on crash/stall & 0.0 val-accuracy symptoms:
# - **Unified label mapping** (no LabelEncoder sorting surprises). We use a fixed
#   CLASS2IDX for the 6 families across *all* domains & stages.
# - **Hard guards for label range** and per-split class summaries (fail fast if a
#   label falls outside 0..C-1).
# - **Stable validation**: explicit internal train/val split instead of
#   `validation_split`, avoiding misaligned batches when concatenating adversarial
#   examples.
# - **Empty MQTT split**: skip gracefully.
# - **CPU-stable training**: default to CPU-only to avoid cuInit(303) & duplicate
#   CUDA plugin registrations seen in notebooks/containers. Can be toggled.
# - **Keras stability**: `workers=1`, `use_multiprocessing=False`,
#   `categorical_accuracy` metric, and tf.data pipelines.
# - **Benign index** based on CLASS2IDX (not list position); evaluation is
#   consistent with model output ordering.
#
# Outputs are written to ./outputs_v3/ as before.
#
# IDS Domain-Shift Pipeline (v3 • FIXED, Keras3-compatible)
# =========================================================
# This revision fixes the crash:
#   TypeError: TensorFlowTrainer.fit() got an unexpected keyword argument 'workers'
#
# Key changes
# -----------
# - **Removed** unsupported `workers`/`use_multiprocessing` args (Keras 3).
# - **Guarded resampling**: `SMOTETomek` is skipped for huge splits; use class
#   weights or light undersampling instead to avoid stalls/OOM.
# - **Adversarial cap**: upper-bound adversarial sample count to keep memory stable.
# - **CPU-stable default** retained (toggle via CONFIG["FORCE_CPU"]).
# - **Unified label mapping** and per-split summaries kept.
#
# Outputs go to `./outputs_v3/`.

# %% [markdown]
# IDS Domain-Shift Pipeline (v3-fast PATCH PLUS)
# ==============================================
# Adds on top of v3_fast_patch:
#   • Per-family thresholds (aggregated attack decision)
#   • Focal loss gamma tweak (γ=3.0 by default)
#   • Per-family temperature scaling (coordinate-descent power scaling)
#   • CORAL moment alignment in LR→BiLSTM feature space (unsupervised DA)
#
# Outputs OVERWRITE the same files as v3_fast_patch for direct A/B:
#   ./outputs_v3fast_patch/domain_shift_results_v3fast_patch.csv
#   ./outputs_v3fast_patch/domain_shift_perclass_v3fast_patch.csv
#   ./outputs_v3fast_patch/domain_shift_reliability_bins_v3fast_patch.csv

# %%
from __future__ import annotations
import os, time, warnings
from dataclasses import dataclass, asdict
from typing import List, Tuple, Dict

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.metrics import f1_score, recall_score, roc_auc_score, average_precision_score, roc_curve, log_loss
from sklearn.linear_model import LogisticRegression
from sklearn.utils.class_weight import compute_class_weight

from imblearn.combine import SMOTETomek

import tensorflow as tf
from tensorflow.keras import layers, models, regularizers, callbacks
from tensorflow.keras.utils import to_categorical

from scipy.sparse import csr_matrix
from numpy.linalg import eig

warnings.filterwarnings("ignore")

# %%
# --------------------
# Config
# --------------------
CONFIG = {
    "NF_TON_IOT_CSV": "Dataset_NF-ToN-IoT.csv",
    "CIC_IOMT_TRAIN_CSV": "CIC_IoMT_2024_WiFi_MQTT_train.csv",
    "CIC_IOMT_TEST_CSV":  "CIC_IoMT_2024_WiFi_MQTT_test.csv",

    "NF_NUMERIC_CLASS_COL": "Class",
    "NF_TEXT_LABEL_COL": "Attack",
    "CIC_CLASS_COL": "Class",
    "CIC_TEXT_LABEL_COL": "label",

    "NF_DST_PORT_CANDIDATES": ["L4_DST_PORT", "Dst Port", "dst_port", "Destination Port", "dport", "dstport","DstPort"],
    "NF_SRC_PORT_CANDIDATES": ["L4_SRC_PORT", "Src Port", "src_port", "Source Port", "sport", "srcport","SrcPort"],
    "MQTT_PORTS": [1883, 8883],

    "SEED": 42,
    "EPOCHS": 30,
    "BATCH_SIZE": 128,
    "LEARNING_RATE": 1e-3,
    "PATIENCE": 5,

    "RESAMPLING": "smote_tomek",            # "none" | "smote_tomek"
    "LOSS_MODE": "focal",                   # "ce" | "class_balanced_ce" | "focal"
    "FOCAL_GAMMA": 3.0,                    # tweaked gamma
    "RESAMPLING_MAX_N": 200_000,
    "UNDERSAMPLE_MAX_PER_CLASS": 100_000,

    "USE_ADV_TRAINING": True,
    "ADV_METHOD": "fgsm",                   # "fgsm" | "pgd" (kept minimal for epoch budget)

    "FORCE_CPU": True,
    "OUTDIR": "./outputs_v3fast_patch",     # same as patch

    # Per-family calibration/thresholds
    "USE_PER_CLASS_TEMP": True,
    "TEMP_GRID": list(np.linspace(0.5, 2.0, 16)),   # coarse grid
    "TEMP_COORD_ITERS": 2,
    "USE_PER_FAMILY_THRESH": True,

    # CORAL
    "USE_CORAL_LR2BLSTM": True,
    "CORAL_EPS": 1e-3,

    # Categorical guard
    "CATEGORICAL_MAX_CARD": 50,
    "MAX_DUMMIES": 800
}

np.random.seed(CONFIG["SEED"])
tf.random.set_seed(CONFIG["SEED"])

if CONFIG["FORCE_CPU"]:
    os.environ.setdefault("CUDA_VISIBLE_DEVICES", "-1")
    try:
        tf.config.set_visible_devices([], 'GPU')
    except Exception:
        pass
os.makedirs(CONFIG["OUTDIR"], exist_ok=True)
os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")
# Out:
# '1'

# %%
# --------------------
# Families
# --------------------
FAMILIES = ["Benign", "DoS_DDoS", "Recon_Scan", "MQTT", "Spoof", "Other"]
CLASS2IDX = {n:i for i,n in enumerate(FAMILIES)}
IDX2CLASS = {i:n for n,i in CLASS2IDX.items()}
NUM_CLASSES = len(FAMILIES)
BENIGN_IDX = CLASS2IDX["Benign"]

# %%
# --------------------
# Helpers
# --------------------
def log(msg): print(f"[{time.strftime('%H:%M:%S')}] {msg}", flush=True)

def map_label_string_to_family(s: str) -> str:
    if not isinstance(s, str): return "Other"
    st = s.lower()
    if "benign" in st or st.strip()=="normal": return "Benign"
    if "mqtt" in st: return "MQTT"
    if "ddos" in st or "dos" in st: return "DoS_DDoS"
    if "scan" in st or "recon" in st or "portscan" in st: return "Recon_Scan"
    if ("spoof" in st) or ("mitm" in st) or ("impersonat" in st) or ("man-in-the-middle" in st) or ("arp" in st and "spoof" in st) or ("dns" in st and "spoof" in st):
        return "Spoof"
    return "Other"

def _first_col(df: pd.DataFrame, candidates: List[str]):
    for c in candidates:
        if c in df.columns: return c
    return None

def _coerce_port_col(s: pd.Series) -> pd.Series:
    if pd.api.types.is_numeric_dtype(s):
        return s.round().astype("Int64")
    try:
        return pd.to_numeric(s.astype(str).str.extract(r'(\d+)', expand=False), errors="coerce").astype("Int64")
    except Exception:
        return pd.Series([pd.NA]*len(s), dtype="Int64")

def mqtt_filter_nf(df: pd.DataFrame) -> pd.DataFrame:
    dcol = _first_col(df, CONFIG["NF_DST_PORT_CANDIDATES"])
    scol = _first_col(df, CONFIG["NF_SRC_PORT_CANDIDATES"])
    if dcol is None and scol is None:
        log("[WARN] No dst/src port columns found; using full NF-ToN-IoT.")
        return df.copy()
    mask = np.zeros(len(df), dtype=bool)
    ports = set(CONFIG["MQTT_PORTS"])
    if dcol is not None:
        d = _coerce_port_col(df[dcol]); mask |= d.isin(ports).fillna(False).to_numpy()
    if scol is not None:
        s = _coerce_port_col(df[scol]); mask |= s.isin(ports).fillna(False).to_numpy()
    f = df[mask]
    if len(f)==0:
        log("[WARN] MQTT filter produced empty set; using full NF-ToN-IoT.")
        return df.copy()
    return f.copy()

def _drop_label_like_columns(Xdf: pd.DataFrame) -> pd.DataFrame:
    KEYS = ['label','Label','labels','Labels','Class','class','Labal','labal','Attack','attack','Target','target','Family','family','Benign','benign']
    return Xdf.drop(columns=[c for c in Xdf.columns if any(k in c for k in KEYS)], errors='ignore')

def build_features_train_lowcard(df: pd.DataFrame, y_col: str):
    df = df.copy()
    y = df[y_col].values
    Xdf = _drop_label_like_columns(df.drop(columns=[y_col]))
    Xnum = Xdf.select_dtypes(include=[np.number]).copy().fillna(0)
    Xcat_raw = Xdf.select_dtypes(exclude=[np.number]).astype(str)
    keep = []
    if Xcat_raw.shape[1]>0:
        for c in Xcat_raw.columns:
            u = Xcat_raw[c].nunique(dropna=False)
            if 1 < u <= CONFIG["CATEGORICAL_MAX_CARD"]: keep.append(c)
    Xcat = Xcat_raw[keep] if keep else pd.DataFrame(index=Xdf.index)
    if Xcat.shape[1]>0: Xcat = pd.get_dummies(Xcat, dummy_na=False, drop_first=False)
    else: Xcat = pd.DataFrame(index=Xdf.index)
    if Xcat.shape[1] > CONFIG["MAX_DUMMIES"]:
        log(f"[INFO] Dropping categoricals (dummies={Xcat.shape[1]} > {CONFIG['MAX_DUMMIES']}).")
        Xcat = pd.DataFrame(index=Xdf.index)
    Xall = pd.concat([Xnum, Xcat], axis=1)
    scaler = StandardScaler().fit(Xall.values)
    X = scaler.transform(Xall.values)
    cols = Xall.columns.tolist()
    return X, y, scaler, cols

def build_features_apply_lowcard(df: pd.DataFrame, y_col: str, scaler: StandardScaler, cols_schema: list):
    df = df.copy(); y = df[y_col].values
    Xdf = _drop_label_like_columns(df.drop(columns=[y_col]))
    Xnum = Xdf.select_dtypes(include=[np.number]).copy().fillna(0)
    Xcat_raw = Xdf.select_dtypes(exclude=[np.number]).astype(str)
    keep = []
    if Xcat_raw.shape[1]>0:
        for c in Xcat_raw.columns:
            u = Xcat_raw[c].nunique(dropna=False)
            if 1 < u <= CONFIG["CATEGORICAL_MAX_CARD"]: keep.append(c)
    Xcat = Xcat_raw[keep] if keep else pd.DataFrame(index=Xdf.index)
    if Xcat.shape[1]>0: Xcat = pd.get_dummies(Xcat, dummy_na=False, drop_first=False)
    else: Xcat = pd.DataFrame(index=Xdf.index)
    Xall = pd.concat([Xnum, Xcat], axis=1).reindex(columns=cols_schema, fill_value=0)
    X = scaler.transform(Xall.values)
    return X, y

def encode_family_series(series: pd.Series) -> np.ndarray:
    vals = [CLASS2IDX[map_label_string_to_family(v)] for v in series.astype(str).values]
    return np.asarray(vals, dtype=np.int32)

# %%
# -------------
# Loss / Models
# -------------
def focal_loss(gamma=3.0, alpha=None):
    def loss(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1-1e-7)
        ce = -y_true * tf.math.log(y_pred)
        if alpha is not None: ce = alpha * ce
        weight = tf.pow(1.0 - y_pred, gamma)
        return tf.reduce_sum(weight * ce, axis=1)
    return loss

def build_bilstm(input_shape, num_classes):
    return models.Sequential([
        layers.Bidirectional(layers.LSTM(64, return_sequences=True, kernel_regularizer=regularizers.l2(1e-4)), input_shape=input_shape),
        layers.Dropout(0.2),
        layers.Bidirectional(layers.LSTM(32, kernel_regularizer=regularizers.l2(1e-4))),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation="softmax", kernel_regularizer=regularizers.l2(1e-4))
    ])

# %%
# -------------
# Calibration & thresholds
# -------------
def temp_scale_probs(proba: np.ndarray, T: float) -> np.ndarray:
    p = np.clip(proba, 1e-12, 1.0)
    scaled = np.power(p, 1.0/float(T))
    scaled /= scaled.sum(axis=1, keepdims=True)
    return scaled

def temp_scale_probs_vec(proba: np.ndarray, T_vec: np.ndarray) -> np.ndarray:
    p = np.clip(proba, 1e-12, 1.0)
    scaled = np.power(p, 1.0/np.asarray(T_vec)[np.newaxis, :])
    scaled /= scaled.sum(axis=1, keepdims=True)
    return scaled

def fit_temperature_prob_grid(y_val: np.ndarray, proba_val: np.ndarray, grid=None) -> float:
    if grid is None: grid = np.linspace(0.5, 2.0, 31)
    best_T, best_nll = 1.0, np.inf
    for T in grid:
        pv = temp_scale_probs(proba_val, T)
        nll = log_loss(y_val, pv, labels=list(range(NUM_CLASSES)))
        if nll < best_nll: best_nll, best_T = nll, float(T)
    return best_T

def fit_per_class_temps(y_val: np.ndarray, proba_val: np.ndarray, grid=None, iters: int = 2) -> np.ndarray:
    """Coordinate-descent fit of per-class temperatures (power scaling)."""
    if grid is None: grid = CONFIG["TEMP_GRID"]
    T_vec = np.ones(NUM_CLASSES, dtype=float)
    for _ in range(iters):
        improved = False
        for c in range(NUM_CLASSES):
            best_tc, best_nll = T_vec[c], np.inf
            for tc in grid:
                Tv = T_vec.copy(); Tv[c] = tc
                pv = temp_scale_probs_vec(proba_val, Tv)
                nll = log_loss(y_val, pv, labels=list(range(NUM_CLASSES)))
                if nll < best_nll: best_nll, best_tc = nll, tc
            if not np.isclose(best_tc, T_vec[c]): improved = True
            T_vec[c] = float(best_tc)
        if not improved: break
    return T_vec

def tune_threshold(y_val_bin: np.ndarray, scores: np.ndarray, target_fpr: float) -> float:
    fpr, tpr, thr = roc_curve(y_val_bin, scores)[:3]
    idx = np.where(fpr <= target_fpr)[0]
    if len(idx)==0:
        j = int(np.argmin(np.abs(fpr - target_fpr)))
        return float(thr[j])
    return float(thr[idx[-1]])

def tune_per_family_thresholds(y_val: np.ndarray, proba_val: np.ndarray, target_fpr: float) -> Dict[int, float]:
    """Returns thresholds for each non-Benign class over its own score p(class)."""
    th = {}
    for c in range(NUM_CLASSES):
        if c == BENIGN_IDX: continue
        y_bin = (y_val == c).astype(int)
        sc = proba_val[:, c]
        if np.all(y_bin==0) or np.all(y_bin==1):
            th[c] = 1.1  # never fire if no negatives or no positives
        else:
            th[c] = tune_threshold((y_val==c).astype(int), sc, target_fpr)
    return th

def decision_from_per_family_thresholds(proba: np.ndarray, th: Dict[int, float]) -> np.ndarray:
    """Attack decision: positive if ANY non-benign class exceeds its threshold."""
    flags = []
    for c, t in th.items():
        if c == BENIGN_IDX: continue
        flags.append(proba[:, c] >= t)
    if len(flags)==0:
        return np.zeros(proba.shape[0], dtype=bool)
    return np.logical_or.reduce(flags)

# %%
# -------------
# Metrics (present-class AUROC/PR-AUC)
# -------------
def evaluate_multiclass_present(y_true: np.ndarray, proba: np.ndarray) -> Tuple[float, float, float, float]:
    macro_f1 = f1_score(y_true, proba.argmax(axis=1), average='macro')
    macro_rec = recall_score(y_true, proba.argmax(axis=1), average='macro')
    present = np.unique(y_true)
    if len(present) < 2:
        return macro_f1, macro_rec, float('nan'), float('nan')
    Yb = label_binarize(y_true, classes=present)
    proba_sub = proba[:, present]
    try: roc = roc_auc_score(Yb, proba_sub, average='macro', multi_class='ovr')
    except Exception: roc = float('nan')
    try: pr = average_precision_score(Yb, proba_sub, average='macro')
    except Exception: pr = float('nan')
    return macro_f1, macro_rec, roc, pr

# %%
# -------------
# Prob. expansion for LR-only
# -------------
def expand_proba_to_full(proba, classes, num_classes=NUM_CLASSES):
    proba = np.asarray(proba)
    full = np.zeros((proba.shape[0], num_classes), dtype=proba.dtype)
    classes = np.asarray(classes, dtype=int)
    full[:, classes] = proba
    row_sums = full.sum(axis=1, keepdims=True)
    zero_rows = (row_sums == 0)
    if np.any(zero_rows):
        full[zero_rows, BENIGN_IDX] = 1.0
    return full

# %%
# -------------
# CORAL alignment (whiten source, recolor to target)
# -------------
def _cov(X):
    Xc = X - X.mean(axis=0, keepdims=True)
    return (Xc.T @ Xc) / max(1, Xc.shape[0]-1)

def _sqrtm_psd(C, eps=1e-6):
    w, V = eig(C)
    w = np.real(w); V = np.real(V)
    w[w<0] = 0.0
    return (V * np.sqrt(w + eps)) @ V.T

def _invsqrtm_psd(C, eps=1e-6):
    w, V = eig(C)
    w = np.real(w); V = np.real(V)
    w[w<0] = 0.0
    return (V * (1.0/np.sqrt(w + eps))) @ V.T

def coral_fit_source_to_target(Xs: np.ndarray, Xt: np.ndarray, eps=1e-3):
    mu_s = Xs.mean(axis=0, keepdims=True)
    mu_t = Xt.mean(axis=0, keepdims=True)
    Cs = _cov(Xs) + eps*np.eye(Xs.shape[1])
    Ct = _cov(Xt) + eps*np.eye(Xt.shape[1])
    As = _invsqrtm_psd(Cs, eps)
    Bt = _sqrtm_psd(Ct, eps)
    # map: (x - mu_s) @ As @ Bt + mu_t
    return mu_s, mu_t, As, Bt

def coral_transform(X: np.ndarray, mu_s, mu_t, As, Bt):
    return (X - mu_s) @ As @ Bt + mu_t

# %%
# -------------
# Results schema
# -------------
@dataclass
class RunResult:
    setting: str
    model_name: str
    use_adv: bool
    resampling: str
    loss_mode: str
    macro_f1: float
    macro_recall: float
    roc_auc_ovr: float
    pr_auc_ovr: float
    ece: float
    mce: float
    fpr1e3: float
    tpr_at_fpr1e3: float
    fpr1e4: float
    tpr_at_fpr1e4: float
    # per-family tuned decision metrics
    fpr1e3_pf: float
    tpr_at_fpr1e3_pf: float
    fpr1e4_pf: float
    tpr_at_fpr1e4_pf: float

# %%
# --------------------
# Main
# --------------------
def main():
    tf.keras.backend.clear_session()

    log("Loading CSVs...")
    nf = pd.read_csv(CONFIG["NF_TON_IOT_CSV"])
    cic_tr = pd.read_csv(CONFIG["CIC_IOMT_TRAIN_CSV"])
    cic_te = pd.read_csv(CONFIG["CIC_IOMT_TEST_CSV"])

    log("Mapping families...")
    nf_family_all = nf.get(CONFIG["NF_TEXT_LABEL_COL"], pd.Series(["Other"]*len(nf))).astype(str).apply(map_label_string_to_family)
    cic_tr_family = cic_tr.get(CONFIG["CIC_TEXT_LABEL_COL"], pd.Series(["Other"]*len(cic_tr))).astype(str).apply(map_label_string_to_family)
    cic_te_family = cic_te.get(CONFIG["CIC_TEXT_LABEL_COL"], pd.Series(["Other"]*len(cic_te))).astype(str).apply(map_label_string_to_family)

    cic_tr2 = cic_tr.copy(); cic_tr2["Family"] = cic_tr_family.values
    cic_te2 = cic_te.copy(); cic_te2["Family"] = cic_te_family.values

    log("Applying MQTT filter to NF-ToN-IoT...")
    nf_mqtt = mqtt_filter_nf(nf)
    nf2 = nf_mqtt.copy()
    nf2["Family"] = nf_family_all.loc[nf_mqtt.index].values

    # splits
    y_nf_enc = encode_family_series(nf2["Family"])
    log("Splitting NF train/test...")
    nf_train, nf_test = train_test_split(nf2, test_size=0.2, random_state=CONFIG["SEED"], stratify=y_nf_enc)

    results = []
    perclass_rows = []
    relbin_rows = []

    def reliability_bins(probs: np.ndarray, y_true: np.ndarray, n_bins: int = 15):
        conf = probs.max(axis=1); preds = probs.argmax(axis=1)
        correct = (preds==y_true).astype(int)
        bins = np.linspace(0.0, 1.0, n_bins+1)
        ece = mce = 0.0; rows = []
        for i in range(n_bins):
            lo, hi = bins[i], bins[i+1]
            idx = np.where((conf>=lo) & (conf<hi))[0]
            if len(idx)==0:
                rows.append((0.5*(lo+hi), np.nan, 0)); continue
            acc = correct[idx].mean(); conf_mean = conf[idx].mean()
            gap = abs(acc-conf_mean)
            ece += (len(idx)/len(conf))*gap; mce = max(mce, gap)
            rows.append((conf_mean, acc, len(idx)))
        return ece, mce, rows

    def fpr_tpr_from_decisions(y_true_bin: np.ndarray, y_pred_bin: np.ndarray):
        fp = np.sum((y_pred_bin==1) & (y_true_bin==0))
        tp = np.sum((y_pred_bin==1) & (y_true_bin==1))
        tn = np.sum((y_pred_bin==0) & (y_true_bin==0))
        fn = np.sum((y_pred_bin==0) & (y_true_bin==1))
        fpr = fp / (fp + tn + 1e-12); tpr = tp / (tp + fn + 1e-12)
        return float(fpr), float(tpr)

    def run_setting(train_domain: str, test_domain: str, model_kind: str, use_adv: bool) -> RunResult:
        log(f"=== Setting: {train_domain} → {test_domain} | {model_kind} | adv={use_adv} ===")

        df_tr = cic_tr2 if train_domain=="IoMT" else nf_train
        df_te = cic_te2 if test_domain=="IoMT" else (nf_test if (train_domain=="IoT" and test_domain=="IoT") else nf2)

        df_tr = df_tr.copy(); df_te = df_te.copy()
        df_tr["y_enc"] = encode_family_series(df_tr["Family"])
        df_te["y_enc"] = encode_family_series(df_te["Family"])

        # Features
        log("Building features (train)...")
        Xtr, ytr, scaler, cols_schema = build_features_train_lowcard(df_tr.drop(columns=["Family"]).rename(columns={"y_enc":"Target"}), "Target")
        log(f"Train matrix: {Xtr.shape}")

        log("Building features (test)...")
        Xte, yte = build_features_apply_lowcard(df_te.drop(columns=["Family"]).rename(columns={"y_enc":"Target"}), "Target", scaler, cols_schema)
        log(f"Test  matrix: {Xte.shape}")

        # Validation split for calibration/threshold tuning
        Xtr_main, Xval, ytr_main, yval = train_test_split(Xtr, ytr, test_size=0.2, random_state=CONFIG["SEED"], stratify=ytr)

        # Resampling (guarded) on training MAIN only
        if CONFIG["RESAMPLING"]=="smote_tomek" and len(ytr_main) <= CONFIG["RESAMPLING_MAX_N"]:
            log("Applying SMOTE-Tomek on training-main...")
            Xtr_main, ytr_main = SMOTETomek(random_state=CONFIG["SEED"]).fit_resample(Xtr_main, ytr_main)
            log(f"Resampled train-main: {Xtr_main.shape}")
        elif CONFIG["RESAMPLING"]=="smote_tomek":
            log("[INFO] Skipping SMOTE-Tomek (too many samples).")

        # ---- Train per branch
        # Temperature/threshold defaults
        T_global = 1.0; T_vec = np.ones(NUM_CLASSES, dtype=float)
        thr_1e3 = thr_1e4 = None
        thr_pf_1e3 = {}; thr_pf_1e4 = {}

        if model_kind=="LR-only":
            log("Fitting LR (saga) on train-main...")
            lr = LogisticRegression(max_iter=1000, multi_class='multinomial', solver='saga', n_jobs=-1)
            lr.fit(csr_matrix(Xtr_main), ytr_main)

            proba_val_raw = lr.predict_proba(csr_matrix(Xval))
            proba_val = expand_proba_to_full(proba_val_raw, lr.classes_, NUM_CLASSES)

            # Temps
            T_global = fit_temperature_prob_grid(yval, proba_val)
            proba_val_T = temp_scale_probs(proba_val, T_global)
            if CONFIG["USE_PER_CLASS_TEMP"]:
                T_vec = fit_per_class_temps(yval, proba_val_T, grid=CONFIG["TEMP_GRID"], iters=CONFIG["TEMP_COORD_ITERS"])
                proba_val_T = temp_scale_probs_vec(proba_val, T_vec)
            else:
                T_vec = np.ones(NUM_CLASSES) * T_global

            # Global attack threshold (Benign score)
            atk_val = 1.0 - proba_val_T[:, BENIGN_IDX]
            yval_bin = (yval != BENIGN_IDX).astype(int)
            thr_1e3 = tune_threshold(yval_bin, atk_val, 1e-3)
            thr_1e4 = tune_threshold(yval_bin, atk_val, 1e-4)

            # Per-family thresholds
            if CONFIG["USE_PER_FAMILY_THRESH"]:
                thr_pf_1e3 = tune_per_family_thresholds(yval, proba_val_T, 1e-3)
                thr_pf_1e4 = tune_per_family_thresholds(yval, proba_val_T, 1e-4)

            # Test
            proba_te_raw = lr.predict_proba(csr_matrix(Xte))
            proba_te = expand_proba_to_full(proba_te_raw, lr.classes_, NUM_CLASSES)
            proba_te = temp_scale_probs_vec(proba_te, T_vec)

        else:
            # Sequence prep
            ytr_oh = to_categorical(ytr_main, num_classes=NUM_CLASSES)
            yval_oh = to_categorical(yval, num_classes=NUM_CLASSES)

            if CONFIG["LOSS_MODE"]=="class_balanced_ce":
                classes = np.arange(NUM_CLASSES)
                weights = compute_class_weight(class_weight='balanced', classes=classes, y=ytr_main)
                cw = {int(c): float(w) for c, w in zip(classes, weights)}
                loss_fn = tf.keras.losses.CategoricalCrossentropy()
            elif CONFIG["LOSS_MODE"]=="focal":
                cw=None; loss_fn=focal_loss(gamma=CONFIG["FOCAL_GAMMA"])
            else:
                cw=None; loss_fn=tf.keras.losses.CategoricalCrossentropy()

            if model_kind=="BiLSTM-only":
                # Use raw tabular features as 1-timestep sequence
                Xtr_seq = Xtr_main.reshape((Xtr_main.shape[0],1,Xtr_main.shape[1]))
                Xval_seq = Xval.reshape((Xval.shape[0],1,Xval.shape[1]))
                Xte_seq  = Xte.reshape((Xte.shape[0],1,Xte.shape[1]))
                model = build_bilstm(Xtr_seq.shape[1:], NUM_CLASSES)
                Xtrain_in, ytrain_in = Xtr_seq, ytr_oh

            elif model_kind=="LR->BiLSTM":
                log("Pre-fitting LR for LR->BiLSTM features...")
                lr = LogisticRegression(max_iter=1000, multi_class='multinomial', solver='saga', n_jobs=-1)
                lr.fit(csr_matrix(Xtr_main), ytr_main)
                Xlr_tr = lr.predict_proba(Xtr_main)
                Xlr_val = lr.predict_proba(Xval)
                Xlr_te  = lr.predict_proba(Xte)

                # CORAL alignment (source -> target) in LR-proba space
                if CONFIG["USE_CORAL_LR2BLSTM"]:
                    log("Applying CORAL alignment in LR→BiLSTM path...")
                    mu_s, mu_t, As, Bt = coral_fit_source_to_target(Xlr_tr, Xlr_te, eps=CONFIG["CORAL_EPS"])
                    Xlr_tr = coral_transform(Xlr_tr, mu_s, mu_t, As, Bt)
                    Xlr_val = coral_transform(Xlr_val, mu_s, mu_t, As, Bt)
                    # Xlr_te left as target (identity)

                Xtr_seq = Xlr_tr[:, np.newaxis, :]
                Xval_seq = Xlr_val[:, np.newaxis, :]
                Xte_seq  = Xlr_te[:,  np.newaxis, :]
                model = build_bilstm(Xtr_seq.shape[1:], NUM_CLASSES)
                Xtrain_in, ytrain_in = Xtr_seq, ytr_oh
            else:
                raise ValueError("Unknown model_kind")

            model.compile(optimizer=tf.keras.optimizers.Adam(CONFIG["LEARNING_RATE"]), loss=loss_fn, metrics=['categorical_accuracy'])
            es = callbacks.EarlyStopping(patience=CONFIG["PATIENCE"], restore_best_weights=True, monitor='val_loss')

            # Optional brief warmup to stabilize before main training
            if CONFIG["USE_ADV_TRAINING"] and use_adv and model_kind!="LR-only":
                log("Warmup (3 epochs) before main training...")
                model.fit(Xtrain_in, ytrain_in, validation_data=(Xval_seq, yval_oh), epochs=3, batch_size=CONFIG["BATCH_SIZE"], callbacks=[es], verbose=0)

            log("Training sequence model...")
            model.fit(Xtrain_in, ytrain_in, validation_data=(Xval_seq, yval_oh), epochs=CONFIG["EPOCHS"], batch_size=CONFIG["BATCH_SIZE"], callbacks=[es], verbose=2)

            log("Validating for temperature/thresholds...")
            proba_val = model.predict(Xval_seq, batch_size=CONFIG["BATCH_SIZE"], verbose=0)
            # Global then per-class temps
            T_global = fit_temperature_prob_grid(yval, proba_val)
            proba_val_T = temp_scale_probs(proba_val, T_global)
            if CONFIG["USE_PER_CLASS_TEMP"]:
                T_vec = fit_per_class_temps(yval, proba_val_T, grid=CONFIG["TEMP_GRID"], iters=CONFIG["TEMP_COORD_ITERS"])
                proba_val_T = temp_scale_probs_vec(proba_val, T_vec)
            else:
                T_vec = np.ones(NUM_CLASSES) * T_global

            # Global thresholds (Benign-vs-Attack)
            atk_val = 1.0 - proba_val_T[:, BENIGN_IDX]
            yval_bin = (yval != BENIGN_IDX).astype(int)
            thr_1e3 = tune_threshold(yval_bin, atk_val, 1e-3)
            thr_1e4 = tune_threshold(yval_bin, atk_val, 1e-4)

            # Per-family thresholds
            if CONFIG["USE_PER_FAMILY_THRESH"]:
                thr_pf_1e3 = tune_per_family_thresholds(yval, proba_val_T, 1e-3)
                thr_pf_1e4 = tune_per_family_thresholds(yval, proba_val_T, 1e-4)

            log("Predicting on test...")
            proba_te = model.predict(Xte_seq, batch_size=CONFIG["BATCH_SIZE"], verbose=0)
            proba_te = temp_scale_probs_vec(proba_te, T_vec)

        # -------- Metrics (present-class AUROC/PR, calibrated) --------
        log("Scoring...")
        yte_enc = df_te["y_enc"].values.astype(int)
        macro_f1, macro_rec, roc_ovr, pr_ovr = evaluate_multiclass_present(yte_enc, proba_te)

        # Reliability
        ece, mce, rel = reliability_bins(proba_te, yte_enc, n_bins=15)

        # Traditional low-FPR using tuned global thresholds
        atk_scores_test = 1.0 - proba_te[:, BENIGN_IDX]
        y_bin_test = (yte_enc != BENIGN_IDX).astype(int)

        def fpr_tpr_at_threshold(y_true_bin: np.ndarray, atk_scores: np.ndarray, thr: float):
            y_pred = (atk_scores >= thr).astype(int)
            fp = np.sum((y_pred==1) & (y_true_bin==0))
            tp = np.sum((y_pred==1) & (y_true_bin==1))
            tn = np.sum((y_pred==0) & (y_true_bin==0))
            fn = np.sum((y_pred==0) & (y_true_bin==1))
            fpr = fp / (fp + tn + 1e-12)
            tpr = tp / (tp + fn + 1e-12)
            return float(fpr), float(tpr)

        fpr1e3, tpr1e3 = fpr_tpr_at_threshold(y_bin_test, atk_scores_test, thr_1e3)
        fpr1e4, tpr1e4 = fpr_tpr_at_threshold(y_bin_test, atk_scores_test, thr_1e4)

        # Per-family tuned composite decision
        if CONFIG["USE_PER_FAMILY_THRESH"]:
            y_pred_pf_1e3 = decision_from_per_family_thresholds(proba_te, thr_pf_1e3).astype(int)
            y_pred_pf_1e4 = decision_from_per_family_thresholds(proba_te, thr_pf_1e4).astype(int)
            fpr1e3_pf, tpr1e3_pf = fpr_tpr_from_decisions(y_bin_test, y_pred_pf_1e3)
            fpr1e4_pf, tpr1e4_pf = fpr_tpr_from_decisions(y_bin_test, y_pred_pf_1e4)
        else:
            fpr1e3_pf = tpr1e3_pf = fpr1e4_pf = tpr1e4_pf = np.nan

        # Per-class table
        y_pred = proba_te.argmax(axis=1)
        for c in range(NUM_CLASSES):
            idxs = np.where(yte_enc==c)[0]
            if len(idxs)==0:
                rec=f1= np.nan; sup=0
            else:
                tp=int(np.sum(y_pred[idxs]==c)); fn=int(len(idxs)-tp); fp=int(np.sum((y_pred==c)&(yte_enc!=c)))
                rec = tp/(tp+fn) if (tp+fn)>0 else 0.0
                prec = tp/(tp+fp) if (tp+fp)>0 else 0.0
                f1 = 2*prec*rec/(prec+rec) if (prec+rec)>0 else 0.0
                sup=len(idxs)
            perclass_rows.append({"setting": f"{train_domain}->{test_domain}", "model_name": model_kind, "use_adv": use_adv, "class": IDX2CLASS[c], "recall": float(rec), "f1": float(f1), "support": int(sup)})

        for (cm, ac, ct) in rel:
            relbin_rows.append({"setting": f"{train_domain}->{test_domain}", "model_name": model_kind, "use_adv": use_adv, "conf_mean": float(0.0 if cm!=cm else cm), "acc": float(0.0 if ac!=ac else ac), "count": int(ct)})

        res = RunResult(setting=f"{train_domain}->{test_domain}", model_name=model_kind, use_adv=use_adv,
                        resampling=CONFIG["RESAMPLING"], loss_mode=CONFIG["LOSS_MODE"],
                        macro_f1=float(macro_f1), macro_recall=float(macro_rec),
                        roc_auc_ovr=float(roc_ovr) if not np.isnan(roc_ovr) else np.nan,
                        pr_auc_ovr=float(pr_ovr) if not np.isnan(pr_ovr) else np.nan,
                        ece=float(ece), mce=float(mce),
                        fpr1e3=float(fpr1e3), tpr_at_fpr1e3=float(tpr1e3),
                        fpr1e4=float(fpr1e4), tpr_at_fpr1e4=float(tpr1e4),
                        fpr1e3_pf=float(fpr1e3_pf), tpr_at_fpr1e3_pf=float(tpr1e3_pf),
                        fpr1e4_pf=float(fpr1e4_pf), tpr_at_fpr1e4_pf=float(tpr1e4_pf))
        log(f"Done setting: {res}")
        return res

    all_results = []
    for model_kind in ["LR-only", "BiLSTM-only", "LR->BiLSTM"]:
        all_results.append(run_setting("IoMT","IoMT",model_kind, use_adv=False))
        all_results.append(run_setting("IoT","IoT",model_kind, use_adv=False))
        all_results.append(run_setting("IoMT","IoT",model_kind, use_adv=(model_kind!="LR-only")))
        all_results.append(run_setting("IoT","IoMT",model_kind, use_adv=(model_kind!="LR-only")))

    df = pd.DataFrame([asdict(r) for r in all_results])
    out_csv = os.path.join(CONFIG["OUTDIR"], "domain_shift_results_v3fast_patch.csv")
    df.to_csv(out_csv, index=False)

    out_pc = os.path.join(CONFIG["OUTDIR"], "domain_shift_perclass_v3fast_patch.csv")
    pd.DataFrame(perclass_rows).to_csv(out_pc, index=False)

    out_rel = os.path.join(CONFIG["OUTDIR"], "domain_shift_reliability_bins_v3fast_patch.csv")
    pd.DataFrame(relbin_rows).to_csv(out_rel, index=False)

    log(f"Saved: {out_csv}")
    log(f"Saved: {out_pc}")
    log(f"Saved: {out_rel}")
    print(df.to_string(index=False))

if __name__ == "__main__":
    main()
# Out:
# [12:14:35] Loading CSVs...
# [12:14:39] Mapping families...
# [12:14:40] Applying MQTT filter to NF-ToN-IoT...
# [12:14:40] [WARN] MQTT filter produced empty set; using full NF-ToN-IoT.
# [12:14:41] Splitting NF train/test...
# [12:14:41] === Setting: IoMT → IoMT | LR-only | adv=False ===
# [12:14:42] Building features (train)...
# [12:14:43] Train matrix: (1048575, 45)
# [12:14:43] Building features (test)...
# [12:14:44] Test  matrix: (1048575, 45)
# [12:14:44] [INFO] Skipping SMOTE-Tomek (too many samples).
# [12:14:44] Fitting LR (saga) on train-main...
# [12:33:00] Scoring...
# [12:33:01] Done setting: RunResult(setting='IoMT->IoMT', model_name='LR-only', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.3536948793563853, macro_recall=0.3987351788913426, roc_auc_ovr=0.47347853255758415, pr_auc_ovr=0.3860086366087746, ece=0.04863784621679577, mce=0.7321589558620717, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=0.9886723216422475, tpr_at_fpr1e4_pf=0.16852066534252322)
# [12:33:02] === Setting: IoT → IoT | LR-only | adv=False ===
# [12:33:02] Building features (train)...
# [12:33:02] Train matrix: (838860, 10)
# [12:33:02] Building features (test)...
# [12:33:02] Test  matrix: (209715, 10)
# [12:33:03] [INFO] Skipping SMOTE-Tomek (too many samples).
# [12:33:03] Fitting LR (saga) on train-main...
# [12:44:13] Scoring...
# [12:44:14] Done setting: RunResult(setting='IoT->IoT', model_name='LR-only', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.4289147928605253, macro_recall=0.425994011078848, roc_auc_ovr=0.8222404955933653, pr_auc_ovr=0.4933428133809503, ece=0.04206659502720313, mce=0.1978193919022243, fpr1e3=3.0327843993570496e-05, tpr_at_fpr1e3=0.0, fpr1e4=3.0327843993570496e-05, tpr_at_fpr1e4=0.0, fpr1e3_pf=0.0013040972917235313, tpr_at_fpr1e3_pf=0.009686435595387627, fpr1e4_pf=6.065568798714099e-05, tpr_at_fpr1e4_pf=5.657964716932025e-05)
# [12:44:14] === Setting: IoMT → IoT | LR-only | adv=False ===
# [12:44:14] Building features (train)...
# [12:44:16] Train matrix: (1048575, 45)
# [12:44:16] Building features (test)...
# [12:44:16] Test  matrix: (1048575, 45)
# [12:44:17] [INFO] Skipping SMOTE-Tomek (too many samples).
# [12:44:17] Fitting LR (saga) on train-main...
# [13:02:37] Scoring...
# [13:02:38] Done setting: RunResult(setting='IoMT->IoT', model_name='LR-only', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.053051669600434115, macro_recall=0.2, roc_auc_ovr=0.5, pr_auc_ovr=0.2, ece=0.8470905753045659, mce=0.8470905753045659, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=1.0, tpr_at_fpr1e4_pf=1.0)
# [13:02:38] === Setting: IoT → IoMT | LR-only | adv=False ===
# [13:02:39] Building features (train)...
# [13:02:39] Train matrix: (838860, 10)
# [13:02:39] Building features (test)...
# [13:02:40] Test  matrix: (1048575, 10)
# [13:02:40] [INFO] Skipping SMOTE-Tomek (too many samples).
# [13:02:40] Fitting LR (saga) on train-main...
# [13:13:50] Scoring...
# [13:13:51] Done setting: RunResult(setting='IoT->IoMT', model_name='LR-only', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.18704153611581187, macro_recall=0.2, roc_auc_ovr=0.5, pr_auc_ovr=0.2, ece=0.21384896392169583, mce=0.21384896392169583, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=0.0, tpr_at_fpr1e3_pf=0.0, fpr1e4_pf=0.0, tpr_at_fpr1e4_pf=0.0)
# [13:13:51] === Setting: IoMT → IoMT | BiLSTM-only | adv=False ===
# [13:13:52] Building features (train)...
# [13:13:53] Train matrix: (1048575, 45)
# [13:13:53] Building features (test)...
# [13:13:54] Test  matrix: (1048575, 45)
# [13:13:54] [INFO] Skipping SMOTE-Tomek (too many samples).
# [13:13:55] Training sequence model...
# Epoch 1/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9991 - loss: 0.0100 - val_categorical_accuracy: 0.9999 - val_loss: 0.0011
# Epoch 2/30
# 6554/6554 - 43s - 7ms/step - categorical_accuracy: 0.9998 - loss: 9.0104e-04 - val_categorical_accuracy: 0.9999 - val_loss: 5.8703e-04
# Epoch 3/30
# 6554/6554 - 43s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.0471e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.2102e-04
# Epoch 4/30
# 6554/6554 - 43s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.4495e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.8542e-04
# Epoch 5/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.2467e-04 - val_categorical_accuracy: 0.9999 - val_loss: 4.3056e-04
# Epoch 6/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.1191e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.7402e-04
# Epoch 7/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.0857e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.5409e-04
# Epoch 8/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.9658e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.3311e-04
# Epoch 9/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.0484e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.2458e-04
# Epoch 10/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.9150e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.5580e-04
# Epoch 11/30
# 6554/6554 - 43s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.9831e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.3941e-04
# Epoch 12/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8782e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.5847e-04
# Epoch 13/30
# 6554/6554 - 43s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8706e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.7494e-04
# Epoch 14/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.7533e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.6037e-04
# [13:24:15] Validating for temperature/thresholds...
# [13:24:32] Predicting on test...
# [13:24:56] Scoring...
# [13:24:58] Done setting: RunResult(setting='IoMT->IoMT', model_name='BiLSTM-only', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.37077597250627614, macro_recall=0.3935158806720652, roc_auc_ovr=0.926701080719227, pr_auc_ovr=0.583765486611675, ece=0.04411029617522815, mce=0.6962929285428625, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=0.9509133937830723, tpr_at_fpr1e4_pf=0.9782663744055202)
# [13:24:58] === Setting: IoT → IoT | BiLSTM-only | adv=False ===
# [13:24:58] Building features (train)...
# [13:24:59] Train matrix: (838860, 10)
# [13:24:59] Building features (test)...
# [13:24:59] Test  matrix: (209715, 10)
# [13:24:59] [INFO] Skipping SMOTE-Tomek (too many samples).
# [13:24:59] Training sequence model...
# Epoch 1/30
# 5243/5243 - 40s - 8ms/step - categorical_accuracy: 0.8501 - loss: 0.1504 - val_categorical_accuracy: 0.8594 - val_loss: 0.1289
# Epoch 2/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8596 - loss: 0.1298 - val_categorical_accuracy: 0.8660 - val_loss: 0.1238
# Epoch 3/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8625 - loss: 0.1266 - val_categorical_accuracy: 0.8669 - val_loss: 0.1221
# Epoch 4/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8637 - loss: 0.1251 - val_categorical_accuracy: 0.8672 - val_loss: 0.1209
# Epoch 5/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8639 - loss: 0.1243 - val_categorical_accuracy: 0.8688 - val_loss: 0.1205
# Epoch 6/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8643 - loss: 0.1237 - val_categorical_accuracy: 0.8674 - val_loss: 0.1196
# Epoch 7/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8647 - loss: 0.1233 - val_categorical_accuracy: 0.8704 - val_loss: 0.1190
# Epoch 8/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8650 - loss: 0.1227 - val_categorical_accuracy: 0.8718 - val_loss: 0.1186
# Epoch 9/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8655 - loss: 0.1223 - val_categorical_accuracy: 0.8689 - val_loss: 0.1181
# Epoch 10/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8654 - loss: 0.1220 - val_categorical_accuracy: 0.8701 - val_loss: 0.1180
# Epoch 11/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8656 - loss: 0.1217 - val_categorical_accuracy: 0.8724 - val_loss: 0.1178
# Epoch 12/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8658 - loss: 0.1215 - val_categorical_accuracy: 0.8721 - val_loss: 0.1176
# Epoch 13/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8657 - loss: 0.1215 - val_categorical_accuracy: 0.8710 - val_loss: 0.1174
# Epoch 14/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8657 - loss: 0.1214 - val_categorical_accuracy: 0.8722 - val_loss: 0.1174
# Epoch 15/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8658 - loss: 0.1213 - val_categorical_accuracy: 0.8734 - val_loss: 0.1173
# Epoch 16/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8660 - loss: 0.1212 - val_categorical_accuracy: 0.8738 - val_loss: 0.1172
# Epoch 17/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8662 - loss: 0.1211 - val_categorical_accuracy: 0.8743 - val_loss: 0.1171
# Epoch 18/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8663 - loss: 0.1211 - val_categorical_accuracy: 0.8747 - val_loss: 0.1173
# Epoch 19/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8659 - loss: 0.1210 - val_categorical_accuracy: 0.8696 - val_loss: 0.1172
# Epoch 20/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1210 - val_categorical_accuracy: 0.8701 - val_loss: 0.1172
# Epoch 21/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8662 - loss: 0.1209 - val_categorical_accuracy: 0.8709 - val_loss: 0.1171
# Epoch 22/30
# 5243/5243 - 34s - 7ms/step - categorical_accuracy: 0.8663 - loss: 0.1207 - val_categorical_accuracy: 0.8725 - val_loss: 0.1170
# Epoch 23/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8660 - loss: 0.1208 - val_categorical_accuracy: 0.8733 - val_loss: 0.1168
# Epoch 24/30
# 5243/5243 - 34s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1207 - val_categorical_accuracy: 0.8713 - val_loss: 0.1167
# Epoch 25/30
# 5243/5243 - 34s - 7ms/step - categorical_accuracy: 0.8662 - loss: 0.1206 - val_categorical_accuracy: 0.8706 - val_loss: 0.1170
# Epoch 26/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1206 - val_categorical_accuracy: 0.8726 - val_loss: 0.1167
# Epoch 27/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8664 - loss: 0.1206 - val_categorical_accuracy: 0.8708 - val_loss: 0.1169
# Epoch 28/30
# 5243/5243 - 34s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1206 - val_categorical_accuracy: 0.8707 - val_loss: 0.1167
# Epoch 29/30
# 5243/5243 - 34s - 7ms/step - categorical_accuracy: 0.8662 - loss: 0.1205 - val_categorical_accuracy: 0.8705 - val_loss: 0.1169
# [13:41:57] Validating for temperature/thresholds...
# [13:42:12] Predicting on test...
# [13:42:16] Scoring...
# [13:42:17] Done setting: RunResult(setting='IoT->IoT', model_name='BiLSTM-only', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.4583699179198188, macro_recall=0.45917211477827713, roc_auc_ovr=0.8902015417876751, pr_auc_ovr=0.5322663189028298, ece=0.17811963685905302, mce=0.3351994229017088, fpr1e3=0.0011827859157492494, tpr_at_fpr1e3=0.3534870036550452, fpr1e4=0.00024262275194856397, tpr_at_fpr1e4=0.018263910106256578, fpr1e3_pf=0.0019409820155885118, tpr_at_fpr1e3_pf=0.1554752124565751, fpr1e4_pf=0.0006672125678585509, tpr_at_fpr1e4_pf=0.016798497244571182)
# [13:42:17] === Setting: IoMT → IoT | BiLSTM-only | adv=True ===
# [13:42:17] Building features (train)...
# [13:42:18] Train matrix: (1048575, 45)
# [13:42:18] Building features (test)...
# [13:42:19] Test  matrix: (1048575, 45)
# [13:42:19] [INFO] Skipping SMOTE-Tomek (too many samples).
# [13:42:20] Warmup (3 epochs) before main training...
# [13:44:39] Training sequence model...
# Epoch 1/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.4259e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.9272e-04
# Epoch 2/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.1409e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.4574e-04
# Epoch 3/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.1031e-04 - val_categorical_accuracy: 0.9999 - val_loss: 4.1296e-04
# Epoch 4/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.2083e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.7623e-04
# Epoch 5/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.0312e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.3735e-04
# Epoch 6/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8792e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.3542e-04
# Epoch 7/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 4.0557e-04 - val_categorical_accuracy: 0.9999 - val_loss: 4.1388e-04
# Epoch 8/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8131e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.8464e-04
# Epoch 9/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8401e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.2636e-04
# Epoch 10/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.7859e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.3751e-04
# Epoch 11/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8102e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.3870e-04
# Epoch 12/30
# 6554/6554 - 50s - 8ms/step - categorical_accuracy: 0.9998 - loss: 3.6845e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.6727e-04
# Epoch 13/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8466e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.2424e-04
# Epoch 14/30
# 6554/6554 - 47s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.8930e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.4806e-04
# Epoch 15/30
# 6554/6554 - 47s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.7640e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.6385e-04
# Epoch 16/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.6557e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.5370e-04
# Epoch 17/30
# 6554/6554 - 47s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.7323e-04 - val_categorical_accuracy: 0.9999 - val_loss: 4.0356e-04
# Epoch 18/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 3.6909e-04 - val_categorical_accuracy: 0.9999 - val_loss: 3.6004e-04
# [13:58:33] Validating for temperature/thresholds...
# [13:58:51] Predicting on test...
# [13:59:17] Scoring...
# [13:59:18] Done setting: RunResult(setting='IoMT->IoT', model_name='BiLSTM-only', use_adv=True, resampling='smote_tomek', loss_mode='focal', macro_f1=0.053051669600434115, macro_recall=0.2, roc_auc_ovr=0.5000016434011035, pr_auc_ovr=0.2000073607571598, ece=0.795844409295764, mce=0.795844409295764, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=1.0, tpr_at_fpr1e4_pf=1.0)
# [13:59:18] === Setting: IoT → IoMT | BiLSTM-only | adv=True ===
# [13:59:19] Building features (train)...
# [13:59:19] Train matrix: (838860, 10)
# [13:59:19] Building features (test)...
# [13:59:20] Test  matrix: (1048575, 10)
# [13:59:20] [INFO] Skipping SMOTE-Tomek (too many samples).
# [13:59:20] Warmup (3 epochs) before main training...
# [14:01:19] Training sequence model...
# Epoch 1/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8631 - loss: 0.1253 - val_categorical_accuracy: 0.8681 - val_loss: 0.1208
# Epoch 2/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8639 - loss: 0.1243 - val_categorical_accuracy: 0.8687 - val_loss: 0.1200
# Epoch 3/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8645 - loss: 0.1236 - val_categorical_accuracy: 0.8684 - val_loss: 0.1193
# Epoch 4/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8650 - loss: 0.1230 - val_categorical_accuracy: 0.8699 - val_loss: 0.1188
# Epoch 5/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8651 - loss: 0.1226 - val_categorical_accuracy: 0.8698 - val_loss: 0.1182
# Epoch 6/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8652 - loss: 0.1223 - val_categorical_accuracy: 0.8696 - val_loss: 0.1179
# Epoch 7/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8656 - loss: 0.1219 - val_categorical_accuracy: 0.8708 - val_loss: 0.1179
# Epoch 8/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8658 - loss: 0.1218 - val_categorical_accuracy: 0.8725 - val_loss: 0.1179
# Epoch 9/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8657 - loss: 0.1217 - val_categorical_accuracy: 0.8730 - val_loss: 0.1176
# Epoch 10/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8658 - loss: 0.1215 - val_categorical_accuracy: 0.8708 - val_loss: 0.1173
# Epoch 11/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8657 - loss: 0.1213 - val_categorical_accuracy: 0.8723 - val_loss: 0.1172
# Epoch 12/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1211 - val_categorical_accuracy: 0.8727 - val_loss: 0.1171
# Epoch 13/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8660 - loss: 0.1212 - val_categorical_accuracy: 0.8698 - val_loss: 0.1173
# Epoch 14/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1210 - val_categorical_accuracy: 0.8719 - val_loss: 0.1170
# Epoch 15/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8658 - loss: 0.1210 - val_categorical_accuracy: 0.8708 - val_loss: 0.1170
# Epoch 16/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8658 - loss: 0.1211 - val_categorical_accuracy: 0.8697 - val_loss: 0.1169
# Epoch 17/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8663 - loss: 0.1210 - val_categorical_accuracy: 0.8730 - val_loss: 0.1169
# Epoch 18/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8660 - loss: 0.1209 - val_categorical_accuracy: 0.8740 - val_loss: 0.1169
# Epoch 19/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1207 - val_categorical_accuracy: 0.8738 - val_loss: 0.1169
# Epoch 20/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8661 - loss: 0.1209 - val_categorical_accuracy: 0.8738 - val_loss: 0.1170
# Epoch 21/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8662 - loss: 0.1209 - val_categorical_accuracy: 0.8711 - val_loss: 0.1172
# [14:14:26] Validating for temperature/thresholds...
# [14:14:41] Predicting on test...
# [14:15:06] Scoring...
# [14:15:07] Done setting: RunResult(setting='IoT->IoMT', model_name='BiLSTM-only', use_adv=True, resampling='smote_tomek', loss_mode='focal', macro_f1=0.010286076389243773, macro_recall=0.2, roc_auc_ovr=0.5000431773249361, pr_auc_ovr=0.20000016405553103, ece=0.45005806741919185, mce=0.45005806741919185, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=1.0, tpr_at_fpr1e4_pf=1.0)
# [14:15:07] === Setting: IoMT → IoMT | LR->BiLSTM | adv=False ===
# [14:15:08] Building features (train)...
# [14:15:09] Train matrix: (1048575, 45)
# [14:15:09] Building features (test)...
# [14:15:10] Test  matrix: (1048575, 45)
# [14:15:10] [INFO] Skipping SMOTE-Tomek (too many samples).
# [14:15:10] Pre-fitting LR for LR->BiLSTM features...
# [14:34:03] Applying CORAL alignment in LR→BiLSTM path...
# [14:34:03] Training sequence model...
# Epoch 1/30
# 6554/6554 - 54s - 8ms/step - categorical_accuracy: 0.9992 - loss: 0.0102 - val_categorical_accuracy: 0.9998 - val_loss: 0.0015
# Epoch 2/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0012 - val_categorical_accuracy: 0.9998 - val_loss: 8.9984e-04
# Epoch 3/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 8.3708e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.9829e-04
# Epoch 4/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 7.1885e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.4365e-04
# Epoch 5/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.9180e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.3464e-04
# Epoch 6/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.8232e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.3508e-04
# Epoch 7/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.7733e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.3152e-04
# Epoch 8/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.7419e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.2467e-04
# Epoch 9/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.6774e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.2641e-04
# Epoch 10/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.6145e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.1771e-04
# Epoch 11/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.5876e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.1705e-04
# Epoch 12/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.5511e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.1931e-04
# Epoch 13/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.5367e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.1308e-04
# Epoch 14/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.4524e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.1273e-04
# Epoch 15/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.4740e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.1103e-04
# Epoch 16/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.4174e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0519e-04
# Epoch 17/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3927e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0599e-04
# Epoch 18/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.4232e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0100e-04
# Epoch 19/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.4154e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0235e-04
# Epoch 20/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.4058e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0385e-04
# Epoch 21/30
# 6554/6554 - 51s - 8ms/step - categorical_accuracy: 0.9998 - loss: 6.3781e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0053e-04
# Epoch 22/30
# 6554/6554 - 48s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3507e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0033e-04
# Epoch 23/30
# 6554/6554 - 47s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3688e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9888e-04
# Epoch 24/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3427e-04 - val_categorical_accuracy: 0.9998 - val_loss: 6.0104e-04
# Epoch 25/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3774e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9957e-04
# Epoch 26/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3526e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9725e-04
# Epoch 27/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3028e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9621e-04
# Epoch 28/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3141e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9637e-04
# Epoch 29/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3323e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9965e-04
# Epoch 30/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 6.3531e-04 - val_categorical_accuracy: 0.9998 - val_loss: 5.9456e-04
# [14:57:03] Validating for temperature/thresholds...
# [14:57:20] Predicting on test...
# [14:57:44] Scoring...
# [14:57:46] Done setting: RunResult(setting='IoMT->IoMT', model_name='LR->BiLSTM', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.18704153611581187, macro_recall=0.2, roc_auc_ovr=0.7045115816058554, pr_auc_ovr=0.38368626221650665, ece=0.07556543289347822, mce=0.502713360699101, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=0.21894859999468183, tpr_at_fpr1e4_pf=0.6682901931614057)
# [14:57:46] === Setting: IoT → IoT | LR->BiLSTM | adv=False ===
# [14:57:46] Building features (train)...
# [14:57:46] Train matrix: (838860, 10)
# [14:57:46] Building features (test)...
# [14:57:46] Test  matrix: (209715, 10)
# [14:57:47] [INFO] Skipping SMOTE-Tomek (too many samples).
# [14:57:47] Pre-fitting LR for LR->BiLSTM features...
# [15:09:04] Applying CORAL alignment in LR→BiLSTM path...
# [15:09:05] Training sequence model...
# Epoch 1/30
# 5243/5243 - 44s - 8ms/step - categorical_accuracy: 0.8377 - loss: 0.1665 - val_categorical_accuracy: 0.8488 - val_loss: 0.1498
# Epoch 2/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8438 - loss: 0.1504 - val_categorical_accuracy: 0.8496 - val_loss: 0.1439
# Epoch 3/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8461 - loss: 0.1461 - val_categorical_accuracy: 0.8503 - val_loss: 0.1413
# Epoch 4/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8471 - loss: 0.1446 - val_categorical_accuracy: 0.8510 - val_loss: 0.1405
# Epoch 5/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8476 - loss: 0.1440 - val_categorical_accuracy: 0.8524 - val_loss: 0.1401
# Epoch 6/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8475 - loss: 0.1437 - val_categorical_accuracy: 0.8521 - val_loss: 0.1400
# Epoch 7/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8478 - loss: 0.1435 - val_categorical_accuracy: 0.8507 - val_loss: 0.1398
# Epoch 8/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8484 - loss: 0.1433 - val_categorical_accuracy: 0.8507 - val_loss: 0.1396
# Epoch 9/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8486 - loss: 0.1431 - val_categorical_accuracy: 0.8515 - val_loss: 0.1395
# Epoch 10/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8483 - loss: 0.1430 - val_categorical_accuracy: 0.8517 - val_loss: 0.1394
# Epoch 11/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8485 - loss: 0.1429 - val_categorical_accuracy: 0.8527 - val_loss: 0.1393
# Epoch 12/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8486 - loss: 0.1428 - val_categorical_accuracy: 0.8516 - val_loss: 0.1392
# Epoch 13/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8491 - loss: 0.1426 - val_categorical_accuracy: 0.8517 - val_loss: 0.1390
# Epoch 14/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8490 - loss: 0.1425 - val_categorical_accuracy: 0.8527 - val_loss: 0.1389
# Epoch 15/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8487 - loss: 0.1425 - val_categorical_accuracy: 0.8517 - val_loss: 0.1389
# Epoch 16/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8494 - loss: 0.1423 - val_categorical_accuracy: 0.8521 - val_loss: 0.1387
# Epoch 17/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8492 - loss: 0.1422 - val_categorical_accuracy: 0.8516 - val_loss: 0.1387
# Epoch 18/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8495 - loss: 0.1422 - val_categorical_accuracy: 0.8518 - val_loss: 0.1386
# Epoch 19/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8497 - loss: 0.1421 - val_categorical_accuracy: 0.8517 - val_loss: 0.1384
# Epoch 20/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8501 - loss: 0.1418 - val_categorical_accuracy: 0.8520 - val_loss: 0.1385
# Epoch 21/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8494 - loss: 0.1418 - val_categorical_accuracy: 0.8530 - val_loss: 0.1383
# Epoch 22/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8498 - loss: 0.1418 - val_categorical_accuracy: 0.8528 - val_loss: 0.1383
# Epoch 23/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8500 - loss: 0.1418 - val_categorical_accuracy: 0.8518 - val_loss: 0.1383
# Epoch 24/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8498 - loss: 0.1416 - val_categorical_accuracy: 0.8517 - val_loss: 0.1380
# Epoch 25/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8498 - loss: 0.1417 - val_categorical_accuracy: 0.8527 - val_loss: 0.1381
# Epoch 26/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8496 - loss: 0.1417 - val_categorical_accuracy: 0.8525 - val_loss: 0.1380
# Epoch 27/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8495 - loss: 0.1417 - val_categorical_accuracy: 0.8523 - val_loss: 0.1379
# Epoch 28/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8496 - loss: 0.1416 - val_categorical_accuracy: 0.8527 - val_loss: 0.1379
# Epoch 29/30
# 5243/5243 - 35s - 7ms/step - categorical_accuracy: 0.8497 - loss: 0.1417 - val_categorical_accuracy: 0.8518 - val_loss: 0.1381
# Epoch 30/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8492 - loss: 0.1417 - val_categorical_accuracy: 0.8526 - val_loss: 0.1381
# [15:27:27] Validating for temperature/thresholds...
# [15:27:42] Predicting on test...
# [15:27:47] Scoring...
# [15:27:48] Done setting: RunResult(setting='IoT->IoT', model_name='LR->BiLSTM', use_adv=False, resampling='smote_tomek', loss_mode='focal', macro_f1=0.443594938199126, macro_recall=0.44549008147904595, roc_auc_ovr=0.857282202667838, pr_auc_ovr=0.49945983832679686, ece=0.20411629005477216, mce=0.40080956473996376, fpr1e3=0.0005459011918842689, tpr_at_fpr1e3=0.00011881725905557252, fpr1e4=3.0327843993570496e-05, tpr_at_fpr1e4=1.6973894150796077e-05, fpr1e3_pf=0.000727868255845692, tpr_at_fpr1e3_pf=0.029772210340496316, fpr1e4_pf=0.00024262275194856397, tpr_at_fpr1e4_pf=0.0011768566611218612)
# [15:27:48] === Setting: IoMT → IoT | LR->BiLSTM | adv=True ===
# [15:27:49] Building features (train)...
# [15:27:50] Train matrix: (1048575, 45)
# [15:27:50] Building features (test)...
# [15:27:50] Test  matrix: (1048575, 45)
# [15:27:51] [INFO] Skipping SMOTE-Tomek (too many samples).
# [15:27:51] Pre-fitting LR for LR->BiLSTM features...
# [15:46:32] Applying CORAL alignment in LR→BiLSTM path...
# [15:46:32] Warmup (3 epochs) before main training...
# [15:48:50] Training sequence model...
# Epoch 1/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0021 - val_categorical_accuracy: 0.9998 - val_loss: 0.0019
# Epoch 2/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0021 - val_categorical_accuracy: 0.9998 - val_loss: 0.0019
# Epoch 3/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0021 - val_categorical_accuracy: 0.9998 - val_loss: 0.0019
# Epoch 4/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0021 - val_categorical_accuracy: 0.9998 - val_loss: 0.0019
# Epoch 5/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0021 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 6/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 7/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 8/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 9/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 10/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 11/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 12/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 13/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 14/30
# 6554/6554 - 44s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 15/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 16/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 17/30
# 6554/6554 - 46s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# Epoch 18/30
# 6554/6554 - 45s - 7ms/step - categorical_accuracy: 0.9998 - loss: 0.0020 - val_categorical_accuracy: 0.9998 - val_loss: 0.0018
# [16:02:19] Validating for temperature/thresholds...
# [16:02:36] Predicting on test...
# [16:03:00] Scoring...
# [16:03:01] Done setting: RunResult(setting='IoMT->IoT', model_name='LR->BiLSTM', use_adv=True, resampling='smote_tomek', loss_mode='focal', macro_f1=0.053051669600434115, macro_recall=0.2, roc_auc_ovr=0.4999999045187458, pr_auc_ovr=0.2, ece=0.8377719114770623, mce=0.8377719114770623, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=1.0, tpr_at_fpr1e3_pf=1.0, fpr1e4_pf=0.0, tpr_at_fpr1e4_pf=0.0)
# [16:03:01] === Setting: IoT → IoMT | LR->BiLSTM | adv=True ===
# [16:03:02] Building features (train)...
# [16:03:02] Train matrix: (838860, 10)
# [16:03:02] Building features (test)...
# [16:03:02] Test  matrix: (1048575, 10)
# [16:03:03] [INFO] Skipping SMOTE-Tomek (too many samples).
# [16:03:03] Pre-fitting LR for LR->BiLSTM features...
# [16:14:35] Applying CORAL alignment in LR→BiLSTM path...
# [16:14:36] Warmup (3 epochs) before main training...
# [16:16:40] Training sequence model...
# Epoch 1/30
# 5243/5243 - 40s - 8ms/step - categorical_accuracy: 0.8444 - loss: 0.1504 - val_categorical_accuracy: 0.8529 - val_loss: 0.1466
# Epoch 2/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8449 - loss: 0.1498 - val_categorical_accuracy: 0.8536 - val_loss: 0.1464
# Epoch 3/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8449 - loss: 0.1495 - val_categorical_accuracy: 0.8555 - val_loss: 0.1465
# Epoch 4/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8449 - loss: 0.1493 - val_categorical_accuracy: 0.8537 - val_loss: 0.1459
# Epoch 5/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8452 - loss: 0.1491 - val_categorical_accuracy: 0.8550 - val_loss: 0.1460
# Epoch 6/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8448 - loss: 0.1488 - val_categorical_accuracy: 0.8544 - val_loss: 0.1459
# Epoch 7/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8451 - loss: 0.1488 - val_categorical_accuracy: 0.8536 - val_loss: 0.1457
# Epoch 8/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8450 - loss: 0.1488 - val_categorical_accuracy: 0.8539 - val_loss: 0.1457
# Epoch 9/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8451 - loss: 0.1487 - val_categorical_accuracy: 0.8528 - val_loss: 0.1455
# Epoch 10/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8448 - loss: 0.1487 - val_categorical_accuracy: 0.8548 - val_loss: 0.1457
# Epoch 11/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8453 - loss: 0.1485 - val_categorical_accuracy: 0.8541 - val_loss: 0.1456
# Epoch 12/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8450 - loss: 0.1485 - val_categorical_accuracy: 0.8538 - val_loss: 0.1456
# Epoch 13/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8451 - loss: 0.1485 - val_categorical_accuracy: 0.8535 - val_loss: 0.1455
# Epoch 14/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8450 - loss: 0.1485 - val_categorical_accuracy: 0.8517 - val_loss: 0.1457
# Epoch 15/30
# 5243/5243 - 39s - 7ms/step - categorical_accuracy: 0.8449 - loss: 0.1484 - val_categorical_accuracy: 0.8511 - val_loss: 0.1455
# Epoch 16/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8451 - loss: 0.1484 - val_categorical_accuracy: 0.8541 - val_loss: 0.1454
# Epoch 17/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8451 - loss: 0.1484 - val_categorical_accuracy: 0.8516 - val_loss: 0.1454
# Epoch 18/30
# 5243/5243 - 36s - 7ms/step - categorical_accuracy: 0.8453 - loss: 0.1484 - val_categorical_accuracy: 0.8517 - val_loss: 0.1454
# Epoch 19/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8450 - loss: 0.1485 - val_categorical_accuracy: 0.8497 - val_loss: 0.1454
# Epoch 20/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8453 - loss: 0.1484 - val_categorical_accuracy: 0.8546 - val_loss: 0.1456
# Epoch 21/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8451 - loss: 0.1483 - val_categorical_accuracy: 0.8520 - val_loss: 0.1456
# Epoch 22/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8453 - loss: 0.1484 - val_categorical_accuracy: 0.8526 - val_loss: 0.1454
# Epoch 23/30
# 5243/5243 - 38s - 7ms/step - categorical_accuracy: 0.8448 - loss: 0.1483 - val_categorical_accuracy: 0.8491 - val_loss: 0.1454
# Epoch 24/30
# 5243/5243 - 37s - 7ms/step - categorical_accuracy: 0.8450 - loss: 0.1484 - val_categorical_accuracy: 0.8523 - val_loss: 0.1455
# [16:31:49] Validating for temperature/thresholds...
# [16:32:04] Predicting on test...
# [16:32:29] Scoring...
# [16:32:29] Done setting: RunResult(setting='IoT->IoMT', model_name='LR->BiLSTM', use_adv=True, resampling='smote_tomek', loss_mode='focal', macro_f1=0.0, macro_recall=0.0, roc_auc_ovr=0.4999636085243727, pr_auc_ovr=0.20000025445980318, ece=0.5326623720795576, mce=0.5326623720795576, fpr1e3=0.0, tpr_at_fpr1e3=0.0, fpr1e4=0.0, tpr_at_fpr1e4=0.0, fpr1e3_pf=0.0, tpr_at_fpr1e3_pf=0.0, fpr1e4_pf=0.0, tpr_at_fpr1e4_pf=0.0)
# [16:32:29] Saved: ./outputs_v3fast_patch/domain_shift_results_v3fast_patch.csv
# [16:32:29] Saved: ./outputs_v3fast_patch/domain_shift_perclass_v3fast_patch.csv
# [16:32:29] Saved: ./outputs_v3fast_patch/domain_shift_reliability_bins_v3fast_patch.csv
#    setting  model_name  use_adv  resampling loss_mode  macro_f1  macro_recall  roc_auc_ovr  pr_auc_ovr      ece      mce   fpr1e3  tpr_at_fpr1e3   fpr1e4  tpr_at_fpr1e4  fpr1e3_pf  tpr_at_fpr1e3_pf  fpr1e4_pf  tpr_at_fpr1e4_pf
# IoMT->IoMT     LR-only    False smote_tomek     focal  0.353695      0.398735     0.473479    0.386009 0.048638 0.732159 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   0.988672          0.168521
#   IoT->IoT     LR-only    False smote_tomek     focal  0.428915      0.425994     0.822240    0.493343 0.042067 0.197819 0.000030       0.000000 0.000030       0.000000   0.001304          0.009686   0.000061          0.000057
#  IoMT->IoT     LR-only    False smote_tomek     focal  0.053052      0.200000     0.500000    0.200000 0.847091 0.847091 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   1.000000          1.000000
#  IoT->IoMT     LR-only    False smote_tomek     focal  0.187042      0.200000     0.500000    0.200000 0.213849 0.213849 0.000000       0.000000 0.000000       0.000000   0.000000          0.000000   0.000000          0.000000
# IoMT->IoMT BiLSTM-only    False smote_tomek     focal  0.370776      0.393516     0.926701    0.583765 0.044110 0.696293 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   0.950913          0.978266
#   IoT->IoT BiLSTM-only    False smote_tomek     focal  0.458370      0.459172     0.890202    0.532266 0.178120 0.335199 0.001183       0.353487 0.000243       0.018264   0.001941          0.155475   0.000667          0.016798
#  IoMT->IoT BiLSTM-only     True smote_tomek     focal  0.053052      0.200000     0.500002    0.200007 0.795844 0.795844 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   1.000000          1.000000
#  IoT->IoMT BiLSTM-only     True smote_tomek     focal  0.010286      0.200000     0.500043    0.200000 0.450058 0.450058 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   1.000000          1.000000
# IoMT->IoMT  LR->BiLSTM    False smote_tomek     focal  0.187042      0.200000     0.704512    0.383686 0.075565 0.502713 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   0.218949          0.668290
#   IoT->IoT  LR->BiLSTM    False smote_tomek     focal  0.443595      0.445490     0.857282    0.499460 0.204116 0.400810 0.000546       0.000119 0.000030       0.000017   0.000728          0.029772   0.000243          0.001177
#  IoMT->IoT  LR->BiLSTM     True smote_tomek     focal  0.053052      0.200000     0.500000    0.200000 0.837772 0.837772 0.000000       0.000000 0.000000       0.000000   1.000000          1.000000   0.000000          0.000000
#  IoT->IoMT  LR->BiLSTM     True smote_tomek     focal  0.000000      0.000000     0.499964    0.200000 0.532662 0.532662 0.000000       0.000000 0.000000       0.000000   0.000000          0.000000   0.000000          0.000000

# %%
import os
import zipfile
from google.colab import files

def zip_and_download_results():
    output_dir = CONFIG["OUTDIR"]
    csv_files = [
        os.path.join(output_dir, "domain_shift_results_v3fast_patch.csv"),
        os.path.join(output_dir, "domain_shift_perclass_v3fast_patch.csv"),
        os.path.join(output_dir, "domain_shift_reliability_bins_v3fast_patch.csv")
    ]
    zip_filename = os.path.join(output_dir, "domain_shift_results_v3fast_patch(Cali).zip")

    print("\nZipping and downloading results...")

    try:
        with zipfile.ZipFile(zip_filename, 'w') as zipf:
            for file in csv_files:
                if os.path.exists(file):
                    zipf.write(file, os.path.basename(file))
                else:
                    print(f"Warning: File not found and will not be included in the zip: {file}")

        if os.path.exists(zip_filename):
            files.download(zip_filename)
            print("Download complete.")
        else:
            print("Zip file was not created.")

    except Exception as e:
        print(f"An error occurred during zipping or downloading: {e}")

# Call the download function
zip_and_download_results()
# Out:
# Zipping and downloading results...
# Download complete.
