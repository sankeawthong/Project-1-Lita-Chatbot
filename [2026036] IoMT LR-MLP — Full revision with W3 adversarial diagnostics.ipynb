# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/%5B2026036%5D%20IoMT%20LR-MLP%20%E2%80%94%20Full%20revision%20with%20W3%20adversarial%20diagnostics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [20260322] IoMT LR-MLP — Full revision with W3 adversarial diagnostics
# **Adds to original notebook:**
# - Working FGSM and PGD (sklearn-based, LR gradient approximation)
# - Q1 diagnostic: confusion matrix under fixed clean threshold (FN count under attack)
# - Q2 diagnostic: score distribution shift under FGSM/PGD
# - τ₉₅ ceiling-effect demonstration
# - 95% CI overlap test for CIC-IoMT FPR improvement
# - Seed-averaged adversarial summary table (reproduces Table 6)
# All original functions preserved unchanged.

# %%
import os, sys, json, time, math, glob, argparse
from pathlib import Path
from zipfile import ZipFile

import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    confusion_matrix, log_loss, brier_score_loss,
)
from sklearn.calibration import calibration_curve
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
try:
    from xgboost import XGBClassifier
    HAVE_XGB = True
except Exception:
    HAVE_XGB = False

from sklearn.metrics import classification_report
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from scipy.stats import norm

print("[OK] Imports complete")
# Out:
# [OK] Imports complete

# %%
# ----------------------
# Global configuration
# ----------------------
CFG = {
    "paths": {
        "nf":        "/content/Dataset_NF-ToN-IoT.csv",
        "cic_train": "/content/CIC_IoMT_2024_WiFi_MQTT_train.csv",
        "cic_test":  "/content/CIC_IoMT_2024_WiFi_MQTT_test.csv",
        "outdir":    "./outputs",
    },
    "columns": {
        "nf_label_binary":  "Label",
        "nf_label_mc":      "Class",
        "cic_label_binary": "label",
        "cic_label_mc":     "Class",
    },
    "train": {
        "test_size":               0.2,
        "random_state":            42,
        "use_smote":               True,
        "smote_kind":              "smote_tomek",
        "mlp_hidden_units":        64,
        "mlp_dropout":             0.2,
        "batch_size":              2048,
        "max_epochs":              25,
        "early_stopping_patience": 5,
    },
    "adv": {
        "eps_list":       [0.01, 0.02, 0.05, 0.10],
        "pgd_steps":      10,
        "pgd_alpha_factor": 0.02,
    },
    "calibration": {
        "method":    "temperature",
        "n_bins_ece": 15,
        "calib_frac": 0.1,
    },
    "tiny_slice": {
        "enabled":     True,
        "benign_frac": 0.015,
        "seed":        42,
    },
}
SEEDS = [42, 43, 44, 45, 46]
print("[OK] CFG loaded")
# Out:
# [OK] CFG loaded

# %%
# ================================
# Utility + metric helpers
# ================================
def ensure_outdir(path):
    out = Path(path)
    out.mkdir(parents=True, exist_ok=True)
    return str(out)

def save_json(obj, path):
    with open(path, "w") as f:
        json.dump(obj, f, indent=2)

def load_csv(path):
    df = pd.read_csv(path, low_memory=False)
    # Drop unnamed index columns
    df = df.loc[:, ~df.columns.str.match(r'^Unnamed')]
    return df

def build_feature_list(df, drop_cols):
    return [c for c in df.columns if c not in drop_cols]

def build_binary_labels(df, bin_col, pos_label=None):
    y = df[bin_col].values
    if y.dtype == object:
        unique_labels = np.unique(y)
        if 'Benign' in unique_labels or 'Benign_test' in unique_labels:
            return np.where((y == 'Benign') | (y == 'Benign_test'), 0, 1)
        else:
            return np.ones(len(y), dtype=int)
    return y.astype(int)

def fpr_at_dr(y_true, scores, target_dr=0.95):
    y_true  = np.asarray(y_true).astype(int)
    scores  = np.asarray(scores)
    pos_scores = scores[y_true == 1]
    if len(pos_scores) == 0:
        return np.nan, np.nan
    thr   = np.quantile(pos_scores, 1.0 - target_dr)
    y_hat = (scores >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_hat, labels=[0, 1]).ravel()
    fpr = fp / (fp + tn + 1e-12)
    return fpr, thr

def expected_calibration_error(y_true, prob_pos, n_bins=15):
    probas = np.column_stack([1 - prob_pos, prob_pos])
    confidences = probas.max(axis=1)
    predictions = probas.argmax(axis=1)
    bins = np.linspace(0.0, 1.0, n_bins + 1)
    ece  = 0.0
    for i in range(n_bins):
        in_bin = (confidences > bins[i]) & (confidences <= bins[i+1])
        if in_bin.any():
            acc  = (y_true[in_bin] == predictions[in_bin]).mean()
            conf = confidences[in_bin].mean()
            ece += np.abs(acc - conf) * in_bin.mean()
    return ece

print("[OK] Helpers loaded")
# Out:
# [OK] Helpers loaded

# %%
# ================================
# LR-MLP training (unchanged)
# ================================
def make_smote(kind="smote_tomek", random_state=42):
    if kind == "smote":      return SMOTE(random_state=random_state)
    elif kind == "smote_tomek": return SMOTETomek(random_state=random_state)
    return None

def fit_lr_then_mlp(X_train, y_train, X_eval, y_eval,
                    use_smote=True, seed=42, max_epochs=25,
                    batch_size=2048, hidden_units=64):
    scaler = StandardScaler()
    X_train_s = scaler.fit_transform(X_train)
    X_eval_s  = scaler.transform(X_eval)

    if use_smote and len(np.unique(y_train)) > 1:
        sampler  = make_smote(CFG["train"]["smote_kind"], random_state=seed)
        X_train_s, y_train = sampler.fit_resample(X_train_s, y_train)

    lr = LogisticRegression(penalty="l2", C=1.0, solver="lbfgs",
                            max_iter=1000, class_weight="balanced",
                            n_jobs=-1, random_state=seed)

    synthetic_sample_added = False
    if len(np.unique(y_train)) < 2:
        print("[WARN] Single class — adding synthetic benign sample.")
        synthetic_x = X_train_s.mean(axis=0).reshape(1, -1)
        X_train_s   = np.vstack([X_train_s, synthetic_x])
        y_train     = np.append(y_train, 0)
        synthetic_sample_added = True

    lr.fit(X_train_s, y_train)
    z_train = lr.decision_function(X_train_s).reshape(-1, 1)
    z_eval  = lr.decision_function(X_eval_s ).reshape(-1, 1)

    mlp = MLPClassifier(
        hidden_layer_sizes=(hidden_units,), activation="relu",
        solver="adam", alpha=0.0,
        batch_size=batch_size, learning_rate_init=1e-3,
        max_iter=max_epochs,
        early_stopping=not synthetic_sample_added,
        n_iter_no_change=CFG["train"]["early_stopping_patience"],
        validation_fraction=0.1 if not synthetic_sample_added else 0.0,
        random_state=seed,
    )
    mlp.fit(z_train, y_train)

    class Pipe:
        def __init__(self, sc, lr_):
            self.scaler = sc
            self.lr     = lr_
        def transform(self, X):
            return self.lr.decision_function(self.scaler.transform(X)).reshape(-1, 1)

    return Pipe(scaler, lr), mlp

print("[OK] fit_lr_then_mlp loaded")
# Out:
# [OK] fit_lr_then_mlp loaded

# %%
# ============================================================
# Adversarial generation — FGSM + PGD (sklearn LR-gradient)
# ============================================================
# The LR front-end is linear: z_lr = X_s @ coef.T + intercept
# Gradient of BCE loss w.r.t. standardised input X_s:
#   dL/dX_s ≈ (p_mlp - y) * lr.coef_.flatten()
# This is exact for a pure LR; for LR→MLP it is a first-order
# approximation via the LR pre-layer (as stated in Section 3.8
# of the paper: "gradients from the trained LR–MLP (typically
# the LR pre-layer)").

def _predict(pipe, mlp, X_std):
    """Predict probabilities for standardised inputs."""
    z = pipe.lr.decision_function(X_std).reshape(-1, 1)
    return mlp.predict_proba(z)[:, 1]

def _lr_gradient(pipe, mlp, X_std, y):
    """
    Signed gradient of BCE w.r.t. standardised input.
    Returns sign_grad shape (n, n_features).
    """
    p    = _predict(pipe, mlp, X_std)           # (n,)
    dloss = (p - y.astype(float))               # dL/dp ≈ p - y for BCE
    coef  = pipe.lr.coef_.flatten()             # (n_features,)
    grad  = np.outer(dloss, coef)               # (n, n_features)
    return np.sign(grad)

def fgsm_sklearn(X_std, y, pipe, mlp, eps, clip_min, clip_max):
    """
    Single-step FGSM in standardised feature space.
    Perturbations clipped to [clip_min, clip_max] per feature.
    """
    sign_grad = _lr_gradient(pipe, mlp, X_std, y)
    X_adv = X_std + eps * sign_grad
    return np.clip(X_adv, clip_min, clip_max)

def pgd_sklearn(X_std, y, pipe, mlp, eps, alpha, steps, clip_min, clip_max):
    """
    PGD (multi-step FGSM) in standardised feature space.
    Projects back to l-inf ball of radius eps after each step.
    """
    X_adv = X_std.copy()
    for _ in range(steps):
        sign_grad = _lr_gradient(pipe, mlp, X_adv, y)
        X_adv = X_adv + alpha * sign_grad
        # Project onto l-inf ball centred at original X_std
        X_adv = np.clip(X_adv, X_std - eps, X_std + eps)
        X_adv = np.clip(X_adv, clip_min, clip_max)
    return X_adv

def constrained_pgd_sklearn(X_std, y, pipe, mlp, eps, alpha,
                             steps, clip_min, clip_max, mask):
    """
    Constrained PGD (Eq. 7 in paper) — restricts gradient updates
    to attacker-actionable features only via binary mask M.

    mask : np.ndarray of shape (n_features,), dtype float
           M_i = 1.0 if feature i is actionable (attacker can modify),
           M_i = 0.0 if non-actionable (protocol fixed, addressing, flags).

    All other behaviour identical to pgd_sklearn():
      - l-inf ball projection after each step
      - per-feature training-range clipping
    """
    X_adv = X_std.copy()
    for _ in range(steps):
        sign_grad = _lr_gradient(pipe, mlp, X_adv, y)
        sign_grad = sign_grad * mask          # ← Eq. 7: zero non-actionable gradients
        X_adv = X_adv + alpha * sign_grad
        X_adv = np.clip(X_adv, X_std - eps, X_std + eps)
        X_adv = np.clip(X_adv, clip_min, clip_max)
    return X_adv


def compute_clip_bounds(X_std_train):
    """Per-feature min/max from training set (standardised space)."""
    return X_std_train.min(axis=0), X_std_train.max(axis=0)

print("[OK] FGSM + PGD (sklearn LR-gradient) loaded")
# Out:
# [OK] FGSM + PGD (sklearn LR-gradient) loaded

# %%
# ============================================================
# W3 DIAGNOSTICS
# Q1: FN count under fixed clean threshold (confusion matrix)
# Q2: Score distribution shift under FGSM/PGD
# Plus: tau95 ceiling effect + CI overlap test
# ============================================================

def w3_diagnostics(pipe, mlp, X_train_std, X_test_std, y_test,
                   dataset_name, outdir, seed=42,
                   eps_list=[0.05, 0.10], pgd_steps=10):
    """
    Run all W3 diagnostics for one trained model on one test set.
    Produces printed output and saves a summary JSON.
    """
    ensure_outdir(outdir)
    clip_min, clip_max = compute_clip_bounds(X_train_std)

    # --- Clean baseline ---
    p_clean   = _predict(pipe, mlp, X_test_std)
    fpr_clean, tau_clean = fpr_at_dr(y_test, p_clean, target_dr=0.95)
    auroc_clean = roc_auc_score(y_test, p_clean)

    attack_mask = (y_test == 1)
    benign_mask = (y_test == 0)

    print(f"\n{'='*60}")
    print(f"W3 DIAGNOSTICS — {dataset_name} (seed={seed})")
    print(f"{'='*60}")
    print(f"Clean: AUROC={auroc_clean:.6f}  FPR@95%DR={fpr_clean:.2e}  tau95={tau_clean:.8f}")
    print(f"  Attack score: mean={p_clean[attack_mask].mean():.6f}  "
          f"min={p_clean[attack_mask].min():.6f}  max={p_clean[attack_mask].max():.6f}")
    print(f"  Benign score: mean={p_clean[benign_mask].mean():.6f}  "
          f"min={p_clean[benign_mask].min():.6f}  max={p_clean[benign_mask].max():.6f}")

    summary = {
        "dataset": dataset_name, "seed": seed,
        "clean": {
            "auroc": float(auroc_clean),
            "fpr95": float(fpr_clean) if fpr_clean == fpr_clean else None,
            "tau95": float(tau_clean) if tau_clean == tau_clean else None,
            "attack_score_mean": float(p_clean[attack_mask].mean()),
            "benign_score_mean": float(p_clean[benign_mask].mean()),
        },
        "adversarial": []
    }

    for eps in eps_list:
        alpha = CFG["adv"]["pgd_alpha_factor"] * eps
        for attack_name, X_adv in [
            ("FGSM", fgsm_sklearn(X_test_std, y_test, pipe, mlp, eps, clip_min, clip_max)),
            ("PGD",  pgd_sklearn (X_test_std, y_test, pipe, mlp, eps, alpha, pgd_steps, clip_min, clip_max)),
        ]:
            p_adv = _predict(pipe, mlp, X_adv)
            fpr_adv,  tau_adv  = fpr_at_dr(y_test, p_adv, target_dr=0.95)
            auroc_adv = roc_auc_score(y_test, p_adv)

            # --- Q2: Score distribution shift ---
            atk_shift    = p_adv[attack_mask].mean() - p_clean[attack_mask].mean()
            benign_shift = p_adv[benign_mask].mean() - p_clean[benign_mask].mean()

            # --- Q1: FN count under FIXED clean threshold ---
            if tau_clean == tau_clean:  # not nan
                y_hat_fixed = (p_adv >= tau_clean).astype(int)
                tn_f, fp_f, fn_f, tp_f = confusion_matrix(
                    y_test, y_hat_fixed, labels=[0,1]).ravel()
                fn_rate_fixed = fn_f / attack_mask.sum() if attack_mask.sum() > 0 else np.nan
                fpr_fixed     = fp_f / (fp_f + tn_f + 1e-12)
            else:
                fn_f, fn_rate_fixed, fpr_fixed = np.nan, np.nan, np.nan

            # --- Ceiling effect check ---
            tau_ceiling = (tau_adv >= 1.0 - 1e-8) if tau_adv == tau_adv else False

            print(f"\n  [{attack_name} eps={eps}]")
            print(f"    AUROC={auroc_adv:.6f}  FPR@95%DR={fpr_adv:.2e}  "
                  f"tau95={tau_adv:.8f}  CEILING={tau_ceiling}")
            print(f"    Attack score shift : {atk_shift:+.6f}  "
                  f"({p_clean[attack_mask].mean():.6f} → {p_adv[attack_mask].mean():.6f})")
            print(f"    Benign score shift : {benign_shift:+.6f}  "
                  f"({p_clean[benign_mask].mean():.6f} → {p_adv[benign_mask].mean():.6f})")
            if tau_clean == tau_clean:
                print(f"    Fixed-threshold FN count: {fn_f}  "
                      f"(FN rate={fn_rate_fixed:.4f})  FPR={fpr_fixed:.2e}")
                if fpr_adv == fpr_adv and fpr_clean == fpr_clean:
                    fpr_diff = fpr_adv - fpr_clean
                    direction = "DECREASE (counterintuitive)" if fpr_diff < 0 else "INCREASE (expected)"
                    print(f"    FPR change vs clean: {fpr_diff:+.2e}  → {direction}")
                    if tau_ceiling:
                        print(f"    *** tau95 CEILING EFFECT: threshold hit 1.0, "
                              f"FPR reduction is a boundary artifact ***")

            summary["adversarial"].append({
                "attack": attack_name, "eps": eps,
                "auroc": float(auroc_adv),
                "fpr95_retuned": float(fpr_adv) if fpr_adv==fpr_adv else None,
                "tau95": float(tau_adv) if tau_adv==tau_adv else None,
                "tau95_ceiling": bool(tau_ceiling),
                "attack_score_mean_adv": float(p_adv[attack_mask].mean()),
                "attack_score_shift": float(atk_shift),
                "benign_score_mean_adv": float(p_adv[benign_mask].mean()),
                "benign_score_shift": float(benign_shift),
                "fn_count_fixed_threshold": int(fn_f) if fn_f==fn_f else None,
                "fn_rate_fixed_threshold": float(fn_rate_fixed) if fn_rate_fixed==fn_rate_fixed else None,
                "fpr_fixed_threshold": float(fpr_fixed) if fpr_fixed==fpr_fixed else None,
            })

    save_json(summary, os.path.join(outdir, f"w3_diagnostics_{dataset_name}_seed{seed}.json"))
    return summary

print("[OK] W3 diagnostic function loaded")
# Out:
# [OK] W3 diagnostic function loaded

# %%
# ============================================================
# CI Overlap test (Table 6 CIC-IoMT FPR improvement)
# ============================================================

def ci_overlap_test(fpr_clean_mean, fpr_clean_std,
                    fpr_adv_mean,   fpr_adv_std,
                    label=""):
    """
    Test whether the FPR 'improvement' under attack is statistically
    significant by checking 95% CI overlap (seed-averaged values).
    """
    z = 1.96
    clean_lo = fpr_clean_mean - z * fpr_clean_std
    clean_hi = fpr_clean_mean + z * fpr_clean_std
    adv_lo   = fpr_adv_mean   - z * fpr_adv_std
    adv_hi   = fpr_adv_mean   + z * fpr_adv_std

    overlap  = not (clean_lo > adv_hi or adv_lo > clean_hi)
    diff     = fpr_adv_mean - fpr_clean_mean

    print(f"\n{'='*60}")
    print(f"CI Overlap Test: {label}")
    print(f"  Clean FPR: {fpr_clean_mean:.2e} ± {fpr_clean_std:.2e}")
    print(f"    95% CI : [{clean_lo:.2e}, {clean_hi:.2e}]")
    print(f"  Adv FPR : {fpr_adv_mean:.2e}  ± {fpr_adv_std:.2e}")
    print(f"    95% CI : [{adv_lo:.2e},  {adv_hi:.2e}]")
    print(f"  Mean difference : {diff:+.2e}")
    print(f"  CIs OVERLAP     : {overlap}")
    if overlap:
        print(f"  => NOT statistically significant. FPR 'improvement'")
        print(f"     is within measurement noise across seeds.")
    else:
        print(f"  => Statistically significant at 95% level.")
    return overlap

# --- Reproduce Table 6 CI test from paper ---
print("Reproducing Table 6 CI overlap test (seed-averaged values from paper):")

# CIC-IoMT: clean vs FGSM eps=0.05
ci_overlap_test(
    fpr_clean_mean=3.72e-4, fpr_clean_std=2.82e-4,
    fpr_adv_mean  =2.51e-4, fpr_adv_std  =1.06e-4,
    label="CIC-IoMT: Clean vs FGSM eps=0.05"
)
ci_overlap_test(
    fpr_clean_mean=3.72e-4, fpr_clean_std=2.82e-4,
    fpr_adv_mean  =2.08e-4, fpr_adv_std  =9.77e-5,
    label="CIC-IoMT: Clean vs PGD  eps=0.05"
)
ci_overlap_test(
    fpr_clean_mean=3.72e-4, fpr_clean_std=2.82e-4,
    fpr_adv_mean  =2.29e-4, fpr_adv_std  =9.77e-5,
    label="CIC-IoMT: Clean vs PGD  eps=0.10"
)
# Out:
# Reproducing Table 6 CI overlap test (seed-averaged values from paper):
#
# ============================================================
# CI Overlap Test: CIC-IoMT: Clean vs FGSM eps=0.05
#   Clean FPR: 3.72e-04 ± 2.82e-04
#     95% CI : [-1.81e-04, 9.25e-04]
#   Adv FPR : 2.51e-04  ± 1.06e-04
#     95% CI : [4.32e-05,  4.59e-04]
#   Mean difference : -1.21e-04
#   CIs OVERLAP     : True
#   => NOT statistically significant. FPR 'improvement'
#      is within measurement noise across seeds.
#
# ============================================================
# CI Overlap Test: CIC-IoMT: Clean vs PGD  eps=0.05
#   Clean FPR: 3.72e-04 ± 2.82e-04
#     95% CI : [-1.81e-04, 9.25e-04]
#   Adv FPR : 2.08e-04  ± 9.77e-05
#     95% CI : [1.65e-05,  3.99e-04]
#   Mean difference : -1.64e-04
#   CIs OVERLAP     : True
#   => NOT statistically significant. FPR 'improvement'
#      is within measurement noise across seeds.
#
# ============================================================
# CI Overlap Test: CIC-IoMT: Clean vs PGD  eps=0.10
#   Clean FPR: 3.72e-04 ± 2.82e-04
#     95% CI : [-1.81e-04, 9.25e-04]
#   Adv FPR : 2.29e-04  ± 9.77e-05
#     95% CI : [3.75e-05,  4.20e-04]
#   Mean difference : -1.43e-04
#   CIs OVERLAP     : True
#   => NOT statistically significant. FPR 'improvement'
#      is within measurement noise across seeds.
# True

# %%
# ============================================================
# Seed-averaged adversarial evaluation (reproduces Table 6)
# ============================================================

def run_adv_seed_avg(dataset_name, df_train_fn, df_test_fn,
                     feats, bin_col, outdir,
                     use_smote=True, seeds=None):
    """
    Train LR→MLP over multiple seeds, run W3 diagnostics each time,
    then aggregate seed-averaged mean ± std for Table 6.

    df_train_fn, df_test_fn: callables returning (X, y) arrays.
    """
    if seeds is None:
        seeds = SEEDS

    all_rows = []
    for seed in seeds:
        X_train, y_train, X_test, y_test = df_train_fn(seed), None, None, None
        # Caller provides (X_train, y_train, X_test, y_test) via df_train_fn
        # For flexibility, accept a single callable returning all four
        X_train, y_train, X_test, y_test = df_train_fn(seed)

        pipe, mlp = fit_lr_then_mlp(
            X_train, y_train, X_test, y_test,
            use_smote=use_smote, seed=seed,
            max_epochs=CFG["train"]["max_epochs"],
            batch_size=CFG["train"]["batch_size"],
            hidden_units=CFG["train"]["mlp_hidden_units"],
        )
        scaler    = pipe.scaler
        X_train_s = scaler.transform(X_train)
        X_test_s  = scaler.transform(X_test)

        diag = w3_diagnostics(
            pipe, mlp, X_train_s, X_test_s, y_test,
            dataset_name, outdir, seed=seed,
            eps_list=CFG["adv"]["eps_list"],
            pgd_steps=CFG["adv"]["pgd_steps"],
        )
        all_rows.append(diag)

    # Aggregate
    print(f"\n{'='*60}")
    print(f"SEED-AVERAGED TABLE 6 REPRODUCTION — {dataset_name}")
    print(f"{'='*60}")
    print(f"{'Attack':8s} {'eps':5s} | {'AUROC':>12s} {'FPR@95%DR':>14s} {'tau95':>12s} | {'Atk shift':>10s} | {'Ceiling':>8s}")
    print("-"*80)

    # Clean row
    clean_aurocs = [r["clean"]["auroc"] for r in all_rows]
    clean_fprs   = [r["clean"]["fpr95"] for r in all_rows if r["clean"]["fpr95"] is not None]
    clean_taus   = [r["clean"]["tau95"] for r in all_rows if r["clean"]["tau95"] is not None]
    print(f"{'Clean':8s} {'0.00':5s} | "
          f"{np.mean(clean_aurocs):.4f}±{np.std(clean_aurocs):.4f} "
          f"{np.mean(clean_fprs):.2e}±{np.std(clean_fprs):.2e} "
          f"{np.mean(clean_taus):.6f}±{np.std(clean_taus):.6f} | "
          f"{'—':>10s} | {'—':>8s}")

    # Adversarial rows
    from collections import defaultdict
    adv_by_key = defaultdict(list)
    for r in all_rows:
        for entry in r["adversarial"]:
            key = (entry["attack"], entry["eps"])
            adv_by_key[key].append(entry)

    for (attack, eps) in [(a,e) for a in ["FGSM","PGD"] for e in CFG["adv"]["eps_list"]]:
        rows_k = adv_by_key[(attack, eps)]
        if not rows_k: continue
        aurocs    = [x["auroc"]               for x in rows_k]
        fprs      = [x["fpr95_retuned"]       for x in rows_k if x["fpr95_retuned"] is not None]
        taus      = [x["tau95"]               for x in rows_k if x["tau95"] is not None]
        atk_shift = [x["attack_score_shift"]  for x in rows_k]
        ceiling   = any(x["tau95_ceiling"]    for x in rows_k)
        print(f"{attack:8s} {eps:5.2f} | "
              f"{np.mean(aurocs):.4f}±{np.std(aurocs):.4f} "
              f"{np.mean(fprs):.2e}±{np.std(fprs):.2e} "
              f"{np.mean(taus):.6f}±{np.std(taus):.6f} | "
              f"{np.mean(atk_shift):+.4f}    | "
              f"{'YES ***' if ceiling else 'no':>8s}")

    return all_rows

print("[OK] Seed-averaged adversarial runner loaded")
print("NOTE: To run the full seed-averaged evaluation, call run_adv_seed_avg()")
print("      after loading your datasets. See Cell 9 for the entry point.")
# Out:
# [OK] Seed-averaged adversarial runner loaded
# NOTE: To run the full seed-averaged evaluation, call run_adv_seed_avg()
#       after loading your datasets. See Cell 9 for the entry point.

# %%
# ----------------------
# Global configuration
# ----------------------
CFG = {
    "paths": {
        "nf":        "/content/Dataset_NF-ToN-IoT.csv",
        "cic_train": "/content/CIC_IoMT_2024_WiFi_MQTT_train.csv",
        "cic_test":  "/content/CIC_IoMT_2024_WiFi_MQTT_test.csv",
        "outdir":    "./outputs",
    },
    "columns": {
        "nf_label_binary":  "Label",
        "nf_label_mc":      "Class",
        "cic_label_binary": "label",
        "cic_label_mc":     "Class",
    },
    "train": {
        "test_size":               0.2,
        "random_state":            42,
        "use_smote":               True,
        "smote_kind":              "smote_tomek",
        "mlp_hidden_units":        64,
        "mlp_dropout":             0.2,
        "batch_size":              2048,
        "max_epochs":              25,
        "early_stopping_patience": 5,
    },
    "adv": {
        "eps_list":       [0.01, 0.02, 0.05, 0.10],
        "pgd_steps":      10,
        "pgd_alpha_factor": 0.02,
    },
    "calibration": {
        "method":    "temperature",
        "n_bins_ece": 15,
        "calib_frac": 0.1,
    },
    "tiny_slice": {
        "enabled":     True,
        "benign_frac": 0.015,
        "seed":        42,
    },
}
SEEDS = [42, 43, 44, 45, 46]

# ================================ Added definitions for local execution
import numpy as np
import os, json
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import (
    roc_auc_score, average_precision_score,
    confusion_matrix, log_loss, brier_score_loss,
)
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from pathlib import Path

def build_feature_list(df, drop_cols):
    return [c for c in df.columns if c not in drop_cols]

def build_binary_labels(df, bin_col, pos_label=None):
    y = df[bin_col].values
    if y.dtype == object:
        unique_labels = np.unique(y)
        if 'Benign' in unique_labels or 'Benign_test' in unique_labels:
            return np.where((y == 'Benign') | (y == 'Benign_test'), 0, 1)
        else:
            return np.ones(len(y), dtype=int)
    return y.astype(int)

def make_smote(kind="smote_tomek", random_state=42):
    if kind == "smote":      return SMOTE(random_state=random_state)
    elif kind == "smote_tomek": return SMOTETomek(random_state=random_state)
    return None

def fit_lr_then_mlp(X_train, y_train, X_eval, y_eval,
                    use_smote=True, seed=42, max_epochs=25,
                    batch_size=2048, hidden_units=64):
    scaler = StandardScaler()
    X_train_s = scaler.fit_transform(X_train)
    X_eval_s  = scaler.transform(X_eval)

    if use_smote and len(np.unique(y_train)) > 1:
        sampler  = make_smote(CFG["train"]["smote_kind"], random_state=seed)
        X_train_s, y_train = sampler.fit_resample(X_train_s, y_train)

    lr = LogisticRegression(penalty="l2", C=1.0, solver="lbfgs",
                            max_iter=1000, class_weight="balanced",
                            n_jobs=-1, random_state=seed)

    synthetic_sample_added = False
    if len(np.unique(y_train)) < 2:
        print("[WARN] Single class — adding synthetic benign sample.")
        synthetic_x = X_train_s.mean(axis=0).reshape(1, -1)
        X_train_s   = np.vstack([X_train_s, synthetic_x])
        y_train     = np.append(y_train, 0)
        synthetic_sample_added = True

    lr.fit(X_train_s, y_train)
    z_train = lr.decision_function(X_train_s).reshape(-1, 1)
    z_eval  = lr.decision_function(X_eval_s ).reshape(-1, 1)

    mlp = MLPClassifier(
        hidden_layer_sizes=(hidden_units,), activation="relu",
        solver="adam", alpha=0.0,
        batch_size=batch_size, learning_rate_init=1e-3,
        max_iter=max_epochs,
        early_stopping=not synthetic_sample_added,
        n_iter_no_change=CFG["train"]["early_stopping_patience"],
        validation_fraction=0.1 if not synthetic_sample_added else 0.0,
        random_state=seed,
    )
    mlp.fit(z_train, y_train)

    class Pipe:
        def __init__(self, sc, lr_):
            self.scaler = sc
            self.lr     = lr_
        def transform(self, X):
            return self.lr.decision_function(self.scaler.transform(X)).reshape(-1, 1)

    return Pipe(scaler, lr), mlp

# ================================ Utility + metric helpers
def ensure_outdir(path):
    out = Path(path)
    out.mkdir(parents=True, exist_ok=True)
    return str(out)

def save_json(obj, path):
    with open(path, "w") as f:
        json.dump(obj, f, indent=2)

def fpr_at_dr(y_true, scores, target_dr=0.95):
    y_true  = np.asarray(y_true).astype(int)
    scores  = np.asarray(scores)
    pos_scores = scores[y_true == 1]
    if len(pos_scores) == 0:
        return np.nan, np.nan
    thr   = np.quantile(pos_scores, 1.0 - target_dr)
    y_hat = (scores >= thr).astype(int)
    tn, fp, fn, tp = confusion_matrix(y_true, y_hat, labels=[0, 1]).ravel()
    fpr = fp / (fp + tn + 1e-12)
    return fpr, thr

# ============================================================
# Adversarial generation — FGSM + PGD (sklearn LR-gradient)
# ============================================================
# The LR front-end is linear: z_lr = X_s @ coef.T + intercept
# Gradient of BCE loss w.r.t. standardised input X_s:
#   dL/dX_s ≈ (p_mlp - y) * lr.coef_.flatten()
# This is exact for a pure LR; for LR→MLP it is a first-order
# approximation via the LR pre-layer (as stated in Section 3.8
# of the paper: "gradients from the trained LR–MLP (typically
# the LR pre-layer)").

def _predict(pipe, mlp, X_std):
    """Predict probabilities for standardised inputs."""
    z = pipe.lr.decision_function(X_std).reshape(-1, 1)
    return mlp.predict_proba(z)[:, 1]

def _lr_gradient(pipe, mlp, X_std, y):
    """
    Signed gradient of BCE w.r.t. standardised input.
    Returns sign_grad shape (n, n_features).
    """
    p    = _predict(pipe, mlp, X_std)           # (n,)
    dloss = (p - y.astype(float))               # dL/dp ≈ p - y for BCE
    coef  = pipe.lr.coef_.flatten()             # (n_features,)
    grad  = np.outer(dloss, coef)               # (n, n_features)
    return np.sign(grad)

def fgsm_sklearn(X_std, y, pipe, mlp, eps, clip_min, clip_max):
    """
    Single-step FGSM in standardised feature space.
    Perturbations clipped to [clip_min, clip_max] per feature.
    """
    sign_grad = _lr_gradient(pipe, mlp, X_std, y)
    X_adv = X_std + eps * sign_grad
    return np.clip(X_adv, clip_min, clip_max)

def pgd_sklearn(X_std, y, pipe, mlp, eps, alpha, steps, clip_min, clip_max):
    """
    PGD (multi-step FGSM) in standardised feature space.
    Projects back to l-inf ball of radius eps after each step.
    """
    X_adv = X_std.copy()
    for _ in range(steps):
        sign_grad = _lr_gradient(pipe, mlp, X_adv, y)
        X_adv = X_adv + alpha * sign_grad
        # Project onto l-inf ball centred at original X_std
        X_adv = np.clip(X_adv, X_std - eps, X_std + eps)
        X_adv = np.clip(X_adv, clip_min, clip_max)
    return X_adv

def compute_clip_bounds(X_std_train):
    """Per-feature min/max from training set (standardised space)."""
    return X_std_train.min(axis=0), X_std_train.max(axis=0)

# ============================================================
# W3 DIAGNOSTICS
# Q1: FN count under fixed clean threshold (confusion matrix)
# Q2: Score distribution shift under FGSM/PGD
# Plus: tau95 ceiling effect + CI overlap test
# ============================================================

def w3_diagnostics(pipe, mlp, X_train_std, X_test_std, y_test,
                   dataset_name, outdir, seed=42,
                   eps_list=[0.05, 0.10], pgd_steps=10):
    """
    Run all W3 diagnostics for one trained model on one test set.
    Produces printed output and saves a summary JSON.
    """
    ensure_outdir(outdir)
    clip_min, clip_max = compute_clip_bounds(X_train_std)

    # --- Clean baseline ---
    p_clean   = _predict(pipe, mlp, X_test_std)
    fpr_clean, tau_clean = fpr_at_dr(y_test, p_clean, target_dr=0.95)
    auroc_clean = roc_auc_score(y_test, p_clean)

    attack_mask = (y_test == 1)
    benign_mask = (y_test == 0)

    print(f"\n{'='*60}")
    print(f"W3 DIAGNOSTICS — {dataset_name} (seed={seed})")
    print(f"{'='*60}")
    print(f"Clean: AUROC={auroc_clean:.6f}  FPR@95%DR={fpr_clean:.2e}  tau95={tau_clean:.8f}")
    print(f"  Attack score: mean={p_clean[attack_mask].mean():.6f}  "
          f"min={p_clean[attack_mask].min():.6f}  max={p_clean[attack_mask].max():.6f}")
    print(f"  Benign score: mean={p_clean[benign_mask].mean():.6f}  "
          f"min={p_clean[benign_mask].min():.6f}  max={p_clean[benign_mask].max():.6f}")

    summary = {
        "dataset": dataset_name, "seed": seed,
        "clean": {
            "auroc": float(auroc_clean),
            "fpr95": float(fpr_clean) if fpr_clean == fpr_clean else None,
            "tau95": float(tau_clean) if tau_clean == tau_clean else None,
            "attack_score_mean": float(p_clean[attack_mask].mean()),
            "benign_score_mean": float(p_clean[benign_mask].mean()),
        },
        "adversarial": []
    }

    for eps in eps_list:
        alpha = CFG["adv"]["pgd_alpha_factor"] * eps
        for attack_name, X_adv in [
            ("FGSM", fgsm_sklearn(X_test_std, y_test, pipe, mlp, eps, clip_min, clip_max)),
            ("PGD",  pgd_sklearn (X_test_std, y_test, pipe, mlp, eps, alpha, pgd_steps, clip_min, clip_max)),
        ]:
            p_adv = _predict(pipe, mlp, X_adv)
            fpr_adv,  tau_adv  = fpr_at_dr(y_test, p_adv, target_dr=0.95)
            auroc_adv = roc_auc_score(y_test, p_adv)

            # --- Q2: Score distribution shift ---
            atk_shift    = p_adv[attack_mask].mean() - p_clean[attack_mask].mean()
            benign_shift = p_adv[benign_mask].mean() - p_clean[benign_mask].mean()

            # --- Q1: FN count under FIXED clean threshold ---
            if tau_clean == tau_clean:  # not nan
                y_hat_fixed = (p_adv >= tau_clean).astype(int)
                tn_f, fp_f, fn_f, tp_f = confusion_matrix(
                    y_test, y_hat_fixed, labels=[0,1]).ravel()
                fn_rate_fixed = fn_f / attack_mask.sum() if attack_mask.sum() > 0 else np.nan
                fpr_fixed     = fp_f / (fp_f + tn_f + 1e-12)
            else:
                fn_f, fn_rate_fixed, fpr_fixed = np.nan, np.nan, np.nan

            # --- Ceiling effect check ---
            tau_ceiling = (tau_adv >= 1.0 - 1e-8) if tau_adv == tau_adv else False

            print(f"\n  [{attack_name} eps={eps}]")
            print(f"    AUROC={auroc_adv:.6f}  FPR@95%DR={fpr_adv:.2e}  "
                  f"tau95={tau_adv:.8f}  CEILING={tau_ceiling}")
            print(f"    Attack score shift : {atk_shift:+.6f}  "
                  f"({p_clean[attack_mask].mean():.6f} → {p_adv[attack_mask].mean():.6f})")
            print(f"    Benign score shift : {benign_shift:+.6f}  "
                  f"({p_clean[benign_mask].mean():.6f} → {p_adv[benign_mask].mean():.6f})")
            if tau_clean == tau_clean:
                print(f"    Fixed-threshold FN count: {fn_f}  "
                      f"(FN rate={fn_rate_fixed:.4f})  FPR={fpr_fixed:.2e}")
                if fpr_adv == fpr_adv and fpr_clean == fpr_clean:
                    fpr_diff = fpr_adv - fpr_clean
                    direction = "DECREASE (counterintuitive)" if fpr_diff < 0 else "INCREASE (expected)"
                    print(f"    FPR change vs clean: {fpr_diff:+.2e}  → {direction}")
                    if tau_ceiling:
                        print(f"    *** tau95 CEILING EFFECT: threshold hit 1.0, "
                              f"FPR reduction is a boundary artifact ***")

            summary["adversarial"].append({
                "attack": attack_name, "eps": eps,
                "auroc": float(auroc_adv),
                "fpr95_retuned": float(fpr_adv) if fpr_adv==fpr_adv else None,
                "tau95": float(tau_adv) if tau_adv==tau_adv else None,
                "tau95_ceiling": bool(tau_ceiling),
                "attack_score_mean_adv": float(p_adv[attack_mask].mean()),
                "attack_score_shift": float(atk_shift),
                "benign_score_mean_adv": float(p_adv[benign_mask].mean()),
                "benign_score_shift": float(benign_shift),
                "fn_count_fixed_threshold": int(fn_f) if fn_f==fn_f else None,
                "fn_rate_fixed_threshold": float(fn_rate_fixed) if fn_rate_fixed==fn_rate_fixed else None,
                "fpr_fixed_threshold": float(fpr_fixed) if fpr_fixed==fpr_fixed else None,
            })

    save_json(summary, os.path.join(outdir, f"w3_diagnostics_{dataset_name}_seed{seed}.json"))
    return summary

# ============================================================
# Seed-averaged adversarial evaluation (reproduces Table 6)
# ============================================================

def run_adv_seed_avg(dataset_name, df_train_fn, df_test_fn,
                     feats, bin_col, outdir,
                     use_smote=True, seeds=None):
    """
    Train LR→MLP over multiple seeds, run W3 diagnostics each time,
    then aggregate seed-averaged mean ± std for Table 6.

    df_train_fn, df_test_fn: callables returning (X, y) arrays.
    """
    if seeds is None:
        seeds = SEEDS

    all_rows = []
    for seed in seeds:
        X_train, y_train, X_test, y_test = df_train_fn(seed)

        pipe, mlp = fit_lr_then_mlp(
            X_train, y_train, X_test, y_test,
            use_smote=use_smote, seed=seed,
            max_epochs=CFG["train"]["max_epochs"],
            batch_size=CFG["train"]["batch_size"],
            hidden_units=CFG["train"]["mlp_hidden_units"],
        )
        scaler    = pipe.scaler
        X_train_s = scaler.transform(X_train)
        X_test_s  = scaler.transform(X_test)

        diag = w3_diagnostics(
            pipe, mlp, X_train_s, X_test_s, y_test,
            dataset_name, outdir, seed=seed,
            eps_list=CFG["adv"]["eps_list"],
            pgd_steps=CFG["adv"]["pgd_steps"],
        )
        all_rows.append(diag)

    # Aggregate
    print(f"\n{'='*60}")
    print(f"SEED-AVERAGED TABLE 6 REPRODUCTION — {dataset_name}")
    print(f"{'='*60}")
    print(f"{'Attack':8s} {'eps':5s} | {'AUROC':>12s} {'FPR@95%DR':>14s} {'tau95':>12s} | {'Atk shift':>10s} | {'Ceiling':>8s}")
    print("-"*80)

    # Clean row
    clean_aurocs = [r["clean"]["auroc"] for r in all_rows]
    clean_fprs   = [r["clean"]["fpr95"] for r in all_rows if r["clean"]["fpr95"] is not None]
    clean_taus   = [r["clean"]["tau95"] for r in all_rows if r["clean"]["tau95"] is not None]
    print(f"{'Clean':8s} {'0.00':5s} | "
          f"{np.mean(clean_aurocs):.4f}±{np.std(clean_aurocs):.4f} "
          f"{np.mean(clean_fprs):.2e}±{np.std(clean_fprs):.2e} "
          f"{np.mean(clean_taus):.6f}±{np.std(clean_taus):.6f} | "
          f"{'—':>10s} | {'—':>8s}")

    # Adversarial rows
    from collections import defaultdict
    adv_by_key = defaultdict(list)
    for r in all_rows:
        for entry in r["adversarial"]:
            key = (entry["attack"], entry["eps"])
            adv_by_key[key].append(entry)

    for (attack, eps) in [(a,e) for a in ["FGSM","PGD"] for e in CFG["adv"]["eps_list"]]:
        rows_k = adv_by_key[(attack, eps)]
        if not rows_k: continue
        aurocs    = [x["auroc"]               for x in rows_k]
        fprs      = [x["fpr95_retuned"]       for x in rows_k if x["fpr95_retuned"] is not None]
        taus      = [x["tau95"]               for x in rows_k if x["tau95"] is not None]
        atk_shift = [x["attack_score_shift"]  for x in rows_k]
        ceiling   = any(x["tau95_ceiling"]    for x in rows_k)
        print(f"{attack:8s} {eps:5.2f} | "
              f"{np.mean(aurocs):.4f}±{np.std(aurocs):.4f} "
              f"{np.mean(fprs):.2e}±{np.std(fprs):.2e} "
              f"{np.mean(taus):.6f}±{np.std(taus):.6f} | "
              f"{np.mean(atk_shift):+.4f}    | "
              f"{'YES ***' if ceiling else 'no':>8s}")

    return all_rows

# =====================================================================

# ============================================================
# Entry point — run W3 diagnostics on your datasets
# ============================================================
# Modify the paths below to match your Colab/Drive setup,
# then run this cell.

def make_nf_split_fn(df, feats, bin_col):
    """Returns a callable (seed) -> (X_train, y_train, X_test, y_test)."""
    X   = df[feats].values
    y   = df[bin_col].values.astype(int)
    def fn(seed):
        X_train_split, X_test_split, y_train_split, y_test_split = train_test_split(X, y, test_size=0.2, random_state=seed, stratify=y)
        return X_train_split, y_train_split, X_test_split, y_test_split
    return fn

def make_cic_split_fn(df_tr, df_te, feats):
    """CIC Option A: pool → stratified 60/20/20 split."""
    df_all = pd.concat([df_tr, df_te], ignore_index=True)
    # Binary labels
    bin_col = CFG["columns"]["cic_label_binary"]
    mc_col  = CFG["columns"]["cic_label_mc"]
    y_all   = build_binary_labels(df_all, bin_col, None)
    common  = [f for f in feats if f in df_all.columns]
    X_all   = df_all[common].values

    def fn(seed):
        X_tr, X_tmp, y_tr, y_tmp = train_test_split(
            X_all, y_all, test_size=0.40, random_state=seed, stratify=y_all)
        X_val, X_te, y_val, y_te = train_test_split(
            X_tmp, y_tmp, test_size=0.50, random_state=seed, stratify=y_tmp)
        # Return train vs test only (val used internally for calibration)
        return X_tr, y_tr, X_te, y_te
    return fn

# ---- RUN ----
# Uncomment and run after mounting your datasets in Colab:

import pandas as pd
nf_df     = pd.read_csv(CFG["paths"]["nf"],        low_memory=False)
cic_tr_df = pd.read_csv(CFG["paths"]["cic_train"], low_memory=False)
cic_te_df = pd.read_csv(CFG["paths"]["cic_test"],  low_memory=False)

# NF-ToN-IoT
nf_feats  = build_feature_list(nf_df, [CFG["columns"]["nf_label_binary"],
                                        CFG["columns"]["nf_label_mc"], "Attack"])
nf_split  = make_nf_split_fn(nf_df, nf_feats, CFG["columns"]["nf_label_binary"])
nf_results = run_adv_seed_avg("NF-ToN-IoT", nf_split, None,
                               nf_feats, CFG["columns"]["nf_label_binary"],
                               outdir="./outputs/w3", use_smote=True)

# CIC-IoMT (Option A pooled)
cic_feats_tr = build_feature_list(cic_tr_df, [CFG["columns"]["cic_label_binary"],
                                               CFG["columns"]["cic_label_mc"]])
cic_split    = make_cic_split_fn(cic_tr_df, cic_te_df, cic_feats_tr)
cic_results  = run_adv_seed_avg("CIC-IoMT-OptionA", cic_split, None,
                                 cic_feats_tr, CFG["columns"]["cic_label_binary"],
                                 outdir="./outputs/w3", use_smote=True)

print("[READY] Uncomment the lines above and run after datasets are mounted.")
print("The CI overlap test (Cell 7) runs standalone on the paper Table 6 values.")
# Out:
# ============================================================
# W3 DIAGNOSTICS — NF-ToN-IoT (seed=42)
# ============================================================
# Clean: AUROC=0.990185  FPR@95%DR=5.32e-02  tau95=0.26657323
#   Attack score: mean=0.928014  min=0.000178  max=0.998321
#   Benign score: mean=0.070032  min=0.000000  max=0.999999
#
#   [FGSM eps=0.01]
#     AUROC=0.988104  FPR@95%DR=5.55e-02  tau95=0.26626093  CEILING=False
#     Attack score shift : -0.009654  (0.928014 → 0.918359)
#     Benign score shift : +0.002621  (0.070032 → 0.072653)
#     Fixed-threshold FN count: 8876  (FN rate=0.0502)  FPR=5.48e-02
#     FPR change vs clean: +2.24e-03  → INCREASE (expected)
#
#   [PGD eps=0.01]
#     AUROC=0.989796  FPR@95%DR=5.36e-02  tau95=0.26646187  CEILING=False
#     Attack score shift : -0.001748  (0.928014 → 0.926266)
#     Benign score shift : +0.000738  (0.070032 → 0.070770)
#     Fixed-threshold FN count: 8851  (FN rate=0.0501)  FPR=5.34e-02
#     FPR change vs clean: +3.94e-04  → INCREASE (expected)
#
#   [FGSM eps=0.02]
#     AUROC=0.985076  FPR@95%DR=7.23e-02  tau95=0.26064874  CEILING=False
#     Attack score shift : -0.022077  (0.928014 → 0.905937)
#     Benign score shift : +0.004850  (0.070032 → 0.074882)
#     Fixed-threshold FN count: 9112  (FN rate=0.0516)  FPR=6.10e-02
#     FPR change vs clean: +1.91e-02  → INCREASE (expected)
#
#   [PGD eps=0.02]
#     AUROC=0.989403  FPR@95%DR=5.32e-02  tau95=0.26646597  CEILING=False
#     Attack score shift : -0.003573  (0.928014 → 0.924441)
#     Benign score shift : +0.001351  (0.070032 → 0.071383)
#     Fixed-threshold FN count: 8856  (FN rate=0.0501)  FPR=5.30e-02
#     FPR change vs clean: -6.07e-05  → DECREASE (counterintuitive)
#
#   [FGSM eps=0.05]
#     AUROC=0.968889  FPR@95%DR=1.82e-01  tau95=0.17742504  CEILING=False
#     Attack score shift : -0.076053  (0.928014 → 0.851961)
#     Benign score shift : +0.012403  (0.070032 → 0.082434)
#     Fixed-threshold FN count: 15781  (FN rate=0.0893)  FPR=6.70e-02
#     FPR change vs clean: +1.28e-01  → INCREASE (expected)
#
#   [PGD eps=0.05]
#     AUROC=0.988104  FPR@95%DR=5.55e-02  tau95=0.26626093  CEILING=False
#     Attack score shift : -0.009654  (0.928014 → 0.918359)
#     Benign score shift : +0.002621  (0.070032 → 0.072653)
#     Fixed-threshold FN count: 8876  (FN rate=0.0502)  FPR=5.48e-02
#     FPR change vs clean: +2.24e-03  → INCREASE (expected)
#
#   [FGSM eps=0.1]
#     AUROC=0.942196  FPR@95%DR=2.75e-01  tau95=0.09683002  CEILING=False
#     Attack score shift : -0.225863  (0.928014 → 0.702151)
#     Benign score shift : +0.025312  (0.070032 → 0.095343)
#     Fixed-threshold FN count: 29186  (FN rate=0.1651)  FPR=9.25e-02
#     FPR change vs clean: +2.21e-01  → INCREASE (expected)
#
#   [PGD eps=0.1]
#     AUROC=0.985076  FPR@95%DR=7.23e-02  tau95=0.26064874  CEILING=False
#     Attack score shift : -0.022077  (0.928014 → 0.905937)
#     Benign score shift : +0.004850  (0.070032 → 0.074882)
#     Fixed-threshold FN count: 9112  (FN rate=0.0516)  FPR=6.10e-02
#     FPR change vs clean: +1.91e-02  → INCREASE (expected)
#
# ============================================================
# W3 DIAGNOSTICS — NF-ToN-IoT (seed=43)
# ============================================================
# Clean: AUROC=0.990649  FPR@95%DR=5.39e-02  tau95=0.26971098
#   Attack score: mean=0.925425  min=0.000001  max=0.997714
#   Benign score: mean=0.073719  min=0.000000  max=1.000000
#
#   [FGSM eps=0.01]
#     AUROC=0.988603  FPR@95%DR=5.60e-02  tau95=0.26978948  CEILING=False
#     Attack score shift : -0.008502  (0.925425 → 0.916923)
#     Benign score shift : +0.002158  (0.073719 → 0.075877)
#     Fixed-threshold FN count: 8820  (FN rate=0.0499)  FPR=5.62e-02
#     FPR change vs clean: +2.12e-03  → INCREASE (expected)
#
#   [PGD eps=0.01]
#     AUROC=0.990253  FPR@95%DR=5.39e-02  tau95=0.26964847  CEILING=False
#     Attack score shift : -0.001547  (0.925425 → 0.923878)
#     Benign score shift : +0.000621  (0.073719 → 0.074340)
#     Fixed-threshold FN count: 8849  (FN rate=0.0501)  FPR=5.38e-02
#     FPR change vs clean: +0.00e+00  → INCREASE (expected)
#
#   [FGSM eps=0.02]
#     AUROC=0.985981  FPR@95%DR=6.36e-02  tau95=0.26929978  CEILING=False
#     Attack score shift : -0.019041  (0.925425 → 0.906384)
#     Benign score shift : +0.003985  (0.073719 → 0.077704)
#     Fixed-threshold FN count: 8905  (FN rate=0.0504)  FPR=6.27e-02
#     FPR change vs clean: +9.70e-03  → INCREASE (expected)
#
#   [PGD eps=0.02]
#     AUROC=0.989845  FPR@95%DR=5.46e-02  tau95=0.26953800  CEILING=False
#     Attack score shift : -0.003168  (0.925425 → 0.922257)
#     Benign score shift : +0.001143  (0.073719 → 0.074862)
#     Fixed-threshold FN count: 8870  (FN rate=0.0502)  FPR=5.42e-02
#     FPR change vs clean: +6.98e-04  → INCREASE (expected)
#
#   [FGSM eps=0.05]
#     AUROC=0.972159  FPR@95%DR=1.69e-01  tau95=0.19925475  CEILING=False
#     Attack score shift : -0.063112  (0.925425 → 0.862313)
#     Benign score shift : +0.010377  (0.073719 → 0.084096)
#     Fixed-threshold FN count: 13840  (FN rate=0.0783)  FPR=6.89e-02
#     FPR change vs clean: +1.15e-01  → INCREASE (expected)
#
#   [PGD eps=0.05]
#     AUROC=0.988603  FPR@95%DR=5.60e-02  tau95=0.26978948  CEILING=False
#     Attack score shift : -0.008502  (0.925425 → 0.916923)
#     Benign score shift : +0.002158  (0.073719 → 0.075877)
#     Fixed-threshold FN count: 8820  (FN rate=0.0499)  FPR=5.62e-02
#     FPR change vs clean: +2.12e-03  → INCREASE (expected)
#
#   [FGSM eps=0.1]
#     AUROC=0.948007  FPR@95%DR=2.94e-01  tau95=0.11119408  CEILING=False
#     Attack score shift : -0.175063  (0.925425 → 0.750362)
#     Benign score shift : +0.022345  (0.073719 → 0.096064)
#     Fixed-threshold FN count: 26942  (FN rate=0.1524)  FPR=7.97e-02
#     FPR change vs clean: +2.41e-01  → INCREASE (expected)
#
#   [PGD eps=0.1]
#     AUROC=0.985981  FPR@95%DR=6.36e-02  tau95=0.26929978  CEILING=False
#     Attack score shift : -0.019041  (0.925425 → 0.906384)
#     Benign score shift : +0.003985  (0.073719 → 0.077704)
#     Fixed-threshold FN count: 8905  (FN rate=0.0504)  FPR=6.27e-02
#     FPR change vs clean: +9.70e-03  → INCREASE (expected)
#
# ============================================================
# W3 DIAGNOSTICS — NF-ToN-IoT (seed=44)
# ============================================================
# Clean: AUROC=0.989746  FPR@95%DR=5.06e-02  tau95=0.29430158
#   Attack score: mean=0.930886  min=0.000032  max=0.997131
#   Benign score: mean=0.072182  min=0.000000  max=0.999735
#
#   [FGSM eps=0.01]
#     AUROC=0.988004  FPR@95%DR=5.29e-02  tau95=0.29221550  CEILING=False
#     Attack score shift : -0.007920  (0.930886 → 0.922966)
#     Benign score shift : +0.001868  (0.072182 → 0.074050)
#     Fixed-threshold FN count: 8963  (FN rate=0.0507)  FPR=5.15e-02
#     FPR change vs clean: +2.37e-03  → INCREASE (expected)
#
#   [PGD eps=0.01]
#     AUROC=0.989432  FPR@95%DR=5.10e-02  tau95=0.29379328  CEILING=False
#     Attack score shift : -0.001379  (0.930886 → 0.929508)
#     Benign score shift : +0.000522  (0.072182 → 0.072703)
#     Fixed-threshold FN count: 8876  (FN rate=0.0502)  FPR=5.07e-02
#     FPR change vs clean: +4.85e-04  → INCREASE (expected)
#
#   [FGSM eps=0.02]
#     AUROC=0.985084  FPR@95%DR=7.96e-02  tau95=0.27010251  CEILING=False
#     Attack score shift : -0.018718  (0.930886 → 0.912168)
#     Benign score shift : +0.003701  (0.072182 → 0.075883)
#     Fixed-threshold FN count: 10133  (FN rate=0.0573)  FPR=5.54e-02
#     FPR change vs clean: +2.91e-02  → INCREASE (expected)
#
#   [PGD eps=0.02]
#     AUROC=0.989106  FPR@95%DR=5.16e-02  tau95=0.29397644  CEILING=False
#     Attack score shift : -0.002854  (0.930886 → 0.928032)
#     Benign score shift : +0.000929  (0.072182 → 0.073110)
#     Fixed-threshold FN count: 8866  (FN rate=0.0502)  FPR=5.13e-02
#     FPR change vs clean: +1.03e-03  → INCREASE (expected)
#
#   [FGSM eps=0.05]
#     AUROC=0.968313  FPR@95%DR=2.16e-01  tau95=0.15188791  CEILING=False
#     Attack score shift : -0.066214  (0.930886 → 0.864672)
#     Benign score shift : +0.010581  (0.072182 → 0.082763)
#     Fixed-threshold FN count: 17257  (FN rate=0.0976)  FPR=6.36e-02
#     FPR change vs clean: +1.65e-01  → INCREASE (expected)
#
#   [PGD eps=0.05]
#     AUROC=0.988004  FPR@95%DR=5.29e-02  tau95=0.29221550  CEILING=False
#     Attack score shift : -0.007920  (0.930886 → 0.922966)
#     Benign score shift : +0.001868  (0.072182 → 0.074050)
#     Fixed-threshold FN count: 8963  (FN rate=0.0507)  FPR=5.15e-02
#     FPR change vs clean: +2.37e-03  → INCREASE (expected)
#
#   [FGSM eps=0.1]
#     AUROC=0.940966  FPR@95%DR=2.80e-01  tau95=0.10353986  CEILING=False
#     Attack score shift : -0.162436  (0.930886 → 0.768450)
#     Benign score shift : +0.022167  (0.072182 → 0.094349)
#     Fixed-threshold FN count: 29742  (FN rate=0.1683)  FPR=6.67e-02
#     FPR change vs clean: +2.29e-01  → INCREASE (expected)
#
#   [PGD eps=0.1]
#     AUROC=0.985084  FPR@95%DR=7.96e-02  tau95=0.27010251  CEILING=False
#     Attack score shift : -0.018718  (0.930886 → 0.912168)
#     Benign score shift : +0.003701  (0.072182 → 0.075883)
#     Fixed-threshold FN count: 10133  (FN rate=0.0573)  FPR=5.54e-02
#     FPR change vs clean: +2.91e-02  → INCREASE (expected)
#
# ============================================================
# W3 DIAGNOSTICS — NF-ToN-IoT (seed=45)
# ============================================================
# Clean: AUROC=0.990361  FPR@95%DR=5.23e-02  tau95=0.27393737
#   Attack score: mean=0.927686  min=0.000000  max=0.998375
#   Benign score: mean=0.070542  min=0.000000  max=1.000000
#
#   [FGSM eps=0.01]
#     AUROC=0.988287  FPR@95%DR=5.77e-02  tau95=0.27401620  CEILING=False
#     Attack score shift : -0.010028  (0.927686 → 0.917658)
#     Benign score shift : +0.002765  (0.070542 → 0.073307)
#     Fixed-threshold FN count: 8830  (FN rate=0.0500)  FPR=5.78e-02
#     FPR change vs clean: +5.40e-03  → INCREASE (expected)
#
#   [PGD eps=0.01]
#     AUROC=0.990000  FPR@95%DR=5.30e-02  tau95=0.27410603  CEILING=False
#     Attack score shift : -0.001815  (0.927686 → 0.925871)
#     Benign score shift : +0.000746  (0.070542 → 0.071288)
#     Fixed-threshold FN count: 8820  (FN rate=0.0499)  FPR=5.32e-02
#     FPR change vs clean: +7.28e-04  → INCREASE (expected)
#
#   [FGSM eps=0.02]
#     AUROC=0.985115  FPR@95%DR=7.33e-02  tau95=0.26702472  CEILING=False
#     Attack score shift : -0.022955  (0.927686 → 0.904731)
#     Benign score shift : +0.005314  (0.070542 → 0.075856)
#     Fixed-threshold FN count: 9168  (FN rate=0.0519)  FPR=6.39e-02
#     FPR change vs clean: +2.10e-02  → INCREASE (expected)
#
#   [PGD eps=0.02]
#     AUROC=0.989619  FPR@95%DR=5.43e-02  tau95=0.27399547  CEILING=False
#     Attack score shift : -0.003711  (0.927686 → 0.923975)
#     Benign score shift : +0.001362  (0.070542 → 0.071904)
#     Fixed-threshold FN count: 8829  (FN rate=0.0500)  FPR=5.43e-02
#     FPR change vs clean: +2.00e-03  → INCREASE (expected)
#
#   [FGSM eps=0.05]
#     AUROC=0.967498  FPR@95%DR=2.02e-01  tau95=0.17184764  CEILING=False
#     Attack score shift : -0.079408  (0.927686 → 0.848278)
#     Benign score shift : +0.013241  (0.070542 → 0.083783)
#     Fixed-threshold FN count: 16533  (FN rate=0.0935)  FPR=6.92e-02
#     FPR change vs clean: +1.50e-01  → INCREASE (expected)
#
#   [PGD eps=0.05]
#     AUROC=0.988287  FPR@95%DR=5.77e-02  tau95=0.27401620  CEILING=False
#     Attack score shift : -0.010028  (0.927686 → 0.917658)
#     Benign score shift : +0.002765  (0.070542 → 0.073307)
#     Fixed-threshold FN count: 8830  (FN rate=0.0500)  FPR=5.78e-02
#     FPR change vs clean: +5.40e-03  → INCREASE (expected)
#
#   [FGSM eps=0.1]
#     AUROC=0.938701  FPR@95%DR=2.79e-01  tau95=0.10190415  CEILING=False
#     Attack score shift : -0.239388  (0.927686 → 0.688299)
#     Benign score shift : +0.026165  (0.070542 → 0.096707)
#     Fixed-threshold FN count: 29317  (FN rate=0.1659)  FPR=9.82e-02
#     FPR change vs clean: +2.27e-01  → INCREASE (expected)
#
#   [PGD eps=0.1]
#     AUROC=0.985115  FPR@95%DR=7.33e-02  tau95=0.26702472  CEILING=False
#     Attack score shift : -0.022955  (0.927686 → 0.904731)
#     Benign score shift : +0.005314  (0.070542 → 0.075856)
#     Fixed-threshold FN count: 9168  (FN rate=0.0519)  FPR=6.39e-02
#     FPR change vs clean: +2.10e-02  → INCREASE (expected)
#
# ============================================================
# W3 DIAGNOSTICS — NF-ToN-IoT (seed=46)
# ============================================================
# Clean: AUROC=0.991104  FPR@95%DR=5.08e-02  tau95=0.27440801
#   Attack score: mean=0.927257  min=0.005717  max=0.997980
#   Benign score: mean=0.072418  min=0.000000  max=1.000000
#
#   [FGSM eps=0.01]
#     AUROC=0.989128  FPR@95%DR=5.47e-02  tau95=0.27374062  CEILING=False
#     Attack score shift : -0.008870  (0.927257 → 0.918387)
#     Benign score shift : +0.002369  (0.072418 → 0.074786)
#     Fixed-threshold FN count: 8920  (FN rate=0.0505)  FPR=5.38e-02
#     FPR change vs clean: +3.88e-03  → INCREASE (expected)
#
#   [PGD eps=0.01]
#     AUROC=0.990734  FPR@95%DR=5.11e-02  tau95=0.27439672  CEILING=False
#     Attack score shift : -0.001619  (0.927257 → 0.925638)
#     Benign score shift : +0.000632  (0.072418 → 0.073050)
#     Fixed-threshold FN count: 8840  (FN rate=0.0500)  FPR=5.11e-02
#     FPR change vs clean: +2.73e-04  → INCREASE (expected)
#
#   [FGSM eps=0.02]
#     AUROC=0.986486  FPR@95%DR=6.13e-02  tau95=0.27327883  CEILING=False
#     Attack score shift : -0.019843  (0.927257 → 0.907414)
#     Benign score shift : +0.004549  (0.072418 → 0.076967)
#     Fixed-threshold FN count: 9002  (FN rate=0.0509)  FPR=5.98e-02
#     FPR change vs clean: +1.05e-02  → INCREASE (expected)
#
#   [PGD eps=0.02]
#     AUROC=0.990346  FPR@95%DR=5.09e-02  tau95=0.27450806  CEILING=False
#     Attack score shift : -0.003305  (0.927257 → 0.923952)
#     Benign score shift : +0.001179  (0.072418 → 0.073597)
#     Fixed-threshold FN count: 8825  (FN rate=0.0499)  FPR=5.11e-02
#     FPR change vs clean: +6.07e-05  → INCREASE (expected)
#
#   [FGSM eps=0.05]
#     AUROC=0.971848  FPR@95%DR=1.71e-01  tau95=0.19400825  CEILING=False
#     Attack score shift : -0.066102  (0.927257 → 0.861155)
#     Benign score shift : +0.012110  (0.072418 → 0.084528)
#     Fixed-threshold FN count: 13859  (FN rate=0.0784)  FPR=6.72e-02
#     FPR change vs clean: +1.20e-01  → INCREASE (expected)
#
#   [PGD eps=0.05]
#     AUROC=0.989128  FPR@95%DR=5.47e-02  tau95=0.27374062  CEILING=False
#     Attack score shift : -0.008870  (0.927257 → 0.918387)
#     Benign score shift : +0.002369  (0.072418 → 0.074786)
#     Fixed-threshold FN count: 8920  (FN rate=0.0505)  FPR=5.38e-02
#     FPR change vs clean: +3.88e-03  → INCREASE (expected)
#
#   [FGSM eps=0.1]
#     AUROC=0.945546  FPR@95%DR=2.99e-01  tau95=0.10700627  CEILING=False
#     Attack score shift : -0.181880  (0.927257 → 0.745377)
#     Benign score shift : +0.025771  (0.072418 → 0.098189)
#     Fixed-threshold FN count: 28345  (FN rate=0.1604)  FPR=8.98e-02
#     FPR change vs clean: +2.49e-01  → INCREASE (expected)
#
#   [PGD eps=0.1]
#     AUROC=0.986486  FPR@95%DR=6.13e-02  tau95=0.27327883  CEILING=False
#     Attack score shift : -0.019843  (0.927257 → 0.907414)
#     Benign score shift : +0.004549  (0.072418 → 0.076967)
#     Fixed-threshold FN count: 9002  (FN rate=0.0509)  FPR=5.98e-02
#     FPR change vs clean: +1.05e-02  → INCREASE (expected)
#
# ============================================================
# SEED-AVERAGED TABLE 6 REPRODUCTION — NF-ToN-IoT
# ============================================================
# Attack   eps   |        AUROC      FPR@95%DR        tau95 |  Atk shift |  Ceiling
# --------------------------------------------------------------------------------
# Clean    0.00  | 0.9904±0.0005 5.22e-02±1.30e-03 0.275786±0.009695 |          — |        —
# FGSM      0.01 | 0.9884±0.0004 5.54e-02±1.55e-03 0.275205±0.008969 | -0.0090    |       no
# FGSM      0.02 | 0.9855±0.0006 7.00e-02±6.72e-03 0.268071±0.004218 | -0.0205    |       no
# FGSM      0.05 | 0.9697±0.0019 1.88e-01±1.83e-02 0.178885±0.016877 | -0.0702    |       no
# FGSM      0.10 | 0.9431±0.0033 2.85e-01±9.69e-03 0.104095±0.004832 | -0.1969    |       no
# PGD       0.01 | 0.9900±0.0004 5.25e-02±1.22e-03 0.275681±0.009524 | -0.0016    |       no
# PGD       0.02 | 0.9897±0.0004 5.29e-02±1.45e-03 0.275697±0.009608 | -0.0033    |       no
# PGD       0.05 | 0.9884±0.0004 5.54e-02±1.55e-03 0.275205±0.008969 | -0.0090    |       no
# PGD       0.10 | 0.9855±0.0006 7.00e-02±6.72e-03 0.268071±0.004218 | -0.0205    |       no
