# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/Hybrid%20RF-LSTM%20for%2010%20class%20classifications%20based%20on%20UNSW-NB15%20dataset%20ver.2.2(2)(15062023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hybrid RF-LSTM for 10 class classifications based on UNSW-NB15 dataset ver.2.2**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
# Load dataset
dataset = pd.read_csv("dataset_P2.2.csv")
dataset.isnull().sum()
# Out:
# id                   0
# dur                  0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# Class                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 175341 non-null  int64
#  1   dur                175341 non-null  float64
#  2   spkts              175341 non-null  int64
#  3   dpkts              175341 non-null  int64
#  4   sbytes             175341 non-null  int64
#  5   dbytes             175341 non-null  int64
#  6   rate               175341 non-null  float64
#  7   sttl               175341 non-null  int64
#  8   dttl               175341 non-null  int64
#  9   sload              175341 non-null  float64
#  10  dload              175341 non-null  float64
#  11  sloss              175341 non-null  int64
#  12  dloss              175341 non-null  int64
#  13  sinpkt             175341 non-null  float64
#  14  dinpkt             175341 non-null  float64
#  15  sjit               175341 non-null  float64
#  16  djit               175341 non-null  float64
#  17  swin               175341 non-null  int64
#  18  stcpb              175341 non-null  int64
#  19  dtcpb              175341 non-null  int64
#  20  dwin               175341 non-null  int64
#  21  tcprtt             175341 non-null  float64
#  22  synack             175341 non-null  float64
#  23  ackdat             175341 non-null  float64
#  24  smean              175341 non-null  int64
#  25  dmean              175341 non-null  int64
#  26  trans_depth        175341 non-null  int64
#  27  response_body_len  175341 non-null  int64
#  28  ct_srv_src         175341 non-null  int64
#  29  ct_state_ttl       175341 non-null  int64
#  30  ct_dst_ltm         175341 non-null  int64
#  31  ct_src_dport_ltm   175341 non-null  int64
#  32  ct_dst_sport_ltm   175341 non-null  int64
#  33  ct_dst_src_ltm     175341 non-null  int64
#  34  is_ftp_login       175341 non-null  int64
#  35  ct_ftp_cmd         175341 non-null  int64
#  36  ct_flw_http_mthd   175341 non-null  int64
#  37  ct_src_ltm         175341 non-null  int64
#  38  ct_srv_dst         175341 non-null  int64
#  39  is_sm_ips_ports    175341 non-null  int64
#  40  Class              175341 non-null  int64
# dtypes: float64(11), int64(30)
# memory usage: 54.8 MB

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])
y = np_utils.to_categorical(y, num_classes=10)  # update to 10 classes
X = dataset.drop(['Class'], axis=1)
X = X.values
print(X.shape)
print(y.shape)
# Out:
# (175341, 40)
# (175341, 10)

# %% [markdown]
# **Data Preprocessing**

# %%
# Data preprocessing
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Hybrid RF-LSTM for 10 class Ver.2.2**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))

# %%
# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
lstm_model.add(Dropout(0.5))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.001)))
lstm_model.add(Dropout(0.5))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.001)))
lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(10, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = lstm_model.fit(train_rf_features, y_train, epochs=50, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)

print(confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions))
print(classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions))

# Plot training/validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 5600/5600 [==============================] - 49s 8ms/step - loss: 0.7639 - accuracy: 0.7593 - val_loss: 0.1417 - val_accuracy: 0.9999
# Epoch 2/50
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.2763 - accuracy: 0.9395 - val_loss: 0.0912 - val_accuracy: 0.9999
# Epoch 3/50
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.2024 - accuracy: 0.9589 - val_loss: 0.0779 - val_accuracy: 0.9999
# Epoch 4/50
# 5600/5600 [==============================] - 42s 8ms/step - loss: 0.1759 - accuracy: 0.9671 - val_loss: 0.0735 - val_accuracy: 0.9999
# Epoch 5/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.1602 - accuracy: 0.9705 - val_loss: 0.0696 - val_accuracy: 0.9999
# Epoch 6/50
# 5600/5600 [==============================] - 49s 9ms/step - loss: 0.1478 - accuracy: 0.9733 - val_loss: 0.0651 - val_accuracy: 0.9999
# Epoch 7/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.1391 - accuracy: 0.9754 - val_loss: 0.0630 - val_accuracy: 0.9999
# Epoch 8/50
# 5600/5600 [==============================] - 44s 8ms/step - loss: 0.1317 - accuracy: 0.9768 - val_loss: 0.0607 - val_accuracy: 0.9999
# Epoch 9/50
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.1270 - accuracy: 0.9777 - val_loss: 0.0598 - val_accuracy: 0.9999
# Epoch 10/50
# 5600/5600 [==============================] - 51s 9ms/step - loss: 0.1244 - accuracy: 0.9776 - val_loss: 0.0593 - val_accuracy: 0.9999
# Epoch 11/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.1216 - accuracy: 0.9782 - val_loss: 0.0567 - val_accuracy: 0.9999
# Epoch 12/50
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.1198 - accuracy: 0.9783 - val_loss: 0.0556 - val_accuracy: 0.9999
# Epoch 13/50
# 5600/5600 [==============================] - 49s 9ms/step - loss: 0.1158 - accuracy: 0.9790 - val_loss: 0.0541 - val_accuracy: 0.9999
# Epoch 14/50
# 5600/5600 [==============================] - 50s 9ms/step - loss: 0.1129 - accuracy: 0.9792 - val_loss: 0.0526 - val_accuracy: 0.9999
# Epoch 15/50
# 5600/5600 [==============================] - 42s 7ms/step - loss: 0.1101 - accuracy: 0.9800 - val_loss: 0.0515 - val_accuracy: 0.9999
# Epoch 16/50
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.1087 - accuracy: 0.9799 - val_loss: 0.0507 - val_accuracy: 0.9999
# Epoch 17/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.1064 - accuracy: 0.9807 - val_loss: 0.0490 - val_accuracy: 0.9999
# Epoch 18/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.1024 - accuracy: 0.9814 - val_loss: 0.0480 - val_accuracy: 0.9999
# Epoch 19/50
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.0987 - accuracy: 0.9823 - val_loss: 0.0463 - val_accuracy: 0.9999
# Epoch 20/50
# 5600/5600 [==============================] - 45s 8ms/step - loss: 0.0972 - accuracy: 0.9824 - val_loss: 0.0457 - val_accuracy: 0.9999
# Epoch 21/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.0952 - accuracy: 0.9831 - val_loss: 0.0454 - val_accuracy: 0.9999
# Epoch 22/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.0945 - accuracy: 0.9832 - val_loss: 0.0447 - val_accuracy: 0.9999
# Epoch 23/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.0942 - accuracy: 0.9827 - val_loss: 0.0435 - val_accuracy: 0.9999
# Epoch 24/50
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0930 - accuracy: 0.9830 - val_loss: 0.0439 - val_accuracy: 0.9999
# Epoch 25/50
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0921 - accuracy: 0.9828 - val_loss: 0.0422 - val_accuracy: 0.9999
# Epoch 26/50
# 5600/5600 [==============================] - 35s 6ms/step - loss: 0.0910 - accuracy: 0.9830 - val_loss: 0.0409 - val_accuracy: 0.9999
# Epoch 27/50
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0894 - accuracy: 0.9835 - val_loss: 0.0398 - val_accuracy: 0.9999
# Epoch 28/50
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0883 - accuracy: 0.9833 - val_loss: 0.0390 - val_accuracy: 0.9999
# Epoch 29/50
# 5600/5600 [==============================] - 45s 8ms/step - loss: 0.0861 - accuracy: 0.9843 - val_loss: 0.0384 - val_accuracy: 0.9999
# Epoch 30/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.0856 - accuracy: 0.9841 - val_loss: 0.0370 - val_accuracy: 0.9999
# Epoch 31/50
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0850 - accuracy: 0.9842 - val_loss: 0.0382 - val_accuracy: 0.9999
# Epoch 32/50
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0844 - accuracy: 0.9844 - val_loss: 0.0370 - val_accuracy: 0.9999
# Epoch 33/50
# 5600/5600 [==============================] - 44s 8ms/step - loss: 0.0847 - accuracy: 0.9840 - val_loss: 0.0372 - val_accuracy: 0.9999
# Epoch 34/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.0840 - accuracy: 0.9842 - val_loss: 0.0369 - val_accuracy: 0.9999
# Epoch 35/50
# 5600/5600 [==============================] - 47s 8ms/step - loss: 0.0830 - accuracy: 0.9846 - val_loss: 0.0357 - val_accuracy: 0.9999
# Epoch 36/50
# 5600/5600 [==============================] - 48s 9ms/step - loss: 0.0827 - accuracy: 0.9847 - val_loss: 0.0358 - val_accuracy: 0.9999
# Epoch 37/50
# 5600/5600 [==============================] - 46s 8ms/step - loss: 0.0822 - accuracy: 0.9846 - val_loss: 0.0361 - val_accuracy: 0.9999
# Epoch 38/50
# 5600/5600 [==============================] - 43s 8ms/step - loss: 0.0823 - accuracy: 0.9846 - val_loss: 0.0348 - val_accuracy: 0.9999
# Epoch 39/50
# 5600/5600 [==============================] - 37s 7ms/step - loss: 0.0816 - accuracy: 0.9847 - val_loss: 0.0355 - val_accuracy: 0.9999
# Epoch 40/50
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0814 - accuracy: 0.9848 - val_loss: 0.0360 - val_accuracy: 0.9999
# Epoch 41/50
# 5600/5600 [==============================] - 35s 6ms/step - loss: 0.0809 - accuracy: 0.9849 - val_loss: 0.0351 - val_accuracy: 0.9999
# Epoch 42/50
# 5600/5600 [==============================] - 36s 6ms/step - loss: 0.0813 - accuracy: 0.9846 - val_loss: 0.0345 - val_accuracy: 0.9999
# Epoch 43/50
# 5600/5600 [==============================] - 39s 7ms/step - loss: 0.0801 - accuracy: 0.9849 - val_loss: 0.0353 - val_accuracy: 0.9999
# Epoch 44/50
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0800 - accuracy: 0.9853 - val_loss: 0.0351 - val_accuracy: 0.9999
# Epoch 45/50
# 5600/5600 [==============================] - 40s 7ms/step - loss: 0.0794 - accuracy: 0.9850 - val_loss: 0.0347 - val_accuracy: 0.9999
# Epoch 46/50
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0797 - accuracy: 0.9845 - val_loss: 0.0346 - val_accuracy: 0.9999
# Epoch 47/50
# 5600/5600 [==============================] - 42s 8ms/step - loss: 0.0783 - accuracy: 0.9850 - val_loss: 0.0336 - val_accuracy: 0.9999
# Epoch 48/50
# 5600/5600 [==============================] - 35s 6ms/step - loss: 0.0779 - accuracy: 0.9850 - val_loss: 0.0342 - val_accuracy: 0.9999
# Epoch 49/50
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0773 - accuracy: 0.9849 - val_loss: 0.0334 - val_accuracy: 0.9999
# Epoch 50/50
# 5600/5600 [==============================] - 38s 7ms/step - loss: 0.0769 - accuracy: 0.9848 - val_loss: 0.0315 - val_accuracy: 0.9999
# 3500/3500 [==============================] - 9s 2ms/step
# [[10840     6     0    96    16   313     0     1     5     0]
#  [    0  7979   452  2704   128    46     0    31     3     0]
#  [    0   285  8136  2519    95    27     1   137    23     2]
#  [    0   579   541  8309  1407   107    18   182    73     3]
#  [    0   199   182  2512  7945   139    13   224    65    18]
#  [   30   120   128   779   116  9855     2    65    79     0]
#  [    0     4    10   124    83    10 10838     4     1     0]
#  [    0   115   338  1212   148    40     1  9163   111     1]
#  [    0     0     0    28     0     3     1     4 11076     0]
#  [    0     0     0     5     1     0     0     0     0 11144]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     11277
#            1       0.86      0.70      0.77     11343
#            2       0.83      0.72      0.77     11225
#            3       0.45      0.74      0.56     11219
#            4       0.80      0.70      0.75     11297
#            5       0.94      0.88      0.91     11174
#            6       1.00      0.98      0.99     11074
#            7       0.93      0.82      0.88     11129
#            8       0.97      1.00      0.98     11112
#            9       1.00      1.00      1.00     11150
#
#     accuracy                           0.85    112000
#    macro avg       0.88      0.85      0.86    112000
# weighted avg       0.88      0.85      0.86    112000

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
# Calculate evaluation metrics
accuracy = accuracy_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
recall = recall_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
precision = precision_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
f1score = f1_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
classification_rep = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.8507589285714285
# Recall: 0.8507589285714285
# Precision: 0.8769451497534857
# F1-Score: 0.8584712515868561
# Confusion Matrix:
#  [[10840     6     0    96    16   313     0     1     5     0]
#  [    0  7979   452  2704   128    46     0    31     3     0]
#  [    0   285  8136  2519    95    27     1   137    23     2]
#  [    0   579   541  8309  1407   107    18   182    73     3]
#  [    0   199   182  2512  7945   139    13   224    65    18]
#  [   30   120   128   779   116  9855     2    65    79     0]
#  [    0     4    10   124    83    10 10838     4     1     0]
#  [    0   115   338  1212   148    40     1  9163   111     1]
#  [    0     0     0    28     0     3     1     4 11076     0]
#  [    0     0     0     5     1     0     0     0     0 11144]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98     11277
#            1       0.86      0.70      0.77     11343
#            2       0.83      0.72      0.77     11225
#            3       0.45      0.74      0.56     11219
#            4       0.80      0.70      0.75     11297
#            5       0.94      0.88      0.91     11174
#            6       1.00      0.98      0.99     11074
#            7       0.93      0.82      0.88     11129
#            8       0.97      1.00      0.98     11112
#            9       1.00      1.00      1.00     11150
#
#     accuracy                           0.85    112000
#    macro avg       0.88      0.85      0.86    112000
# weighted avg       0.88      0.85      0.86    112000

# %%
# Plot training loss and validation/test loss over each epoch of training
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy and Training Loss')
plt.xlabel('Accuracy')
plt.ylabel('Loss')
plt.legend()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  plt.figure(figsize=(8,6.5))
  ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='copper')
  sns.set(font_scale=1)
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n');
  ax.xaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])
  ax.yaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])

  plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees

  plt.tight_layout()
  # plt.savefig("F1.eps", format = 'eps')
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model")
conf_mat(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']
print("Detection rates of Hybrid RF-LSTM Model:", detection_rates)
# Out:
# Detection rates of Hybrid RF-LSTM Model: {0: 0.9612485590139221, 1: 0.7034294278409592, 2: 0.7248106904231626, 3: 0.7406185934575275, 4: 0.7032840577144375, 5: 0.8819581170574549, 6: 0.9786888206610078, 7: 0.8233444154910594, 8: 0.9967602591792657, 9: 0.9994618834080717}

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']

# Plot detection rates
labels = detection_rates.keys()
rates = detection_rates.values()

plt.bar(labels, rates)
plt.xlabel('Class')
plt.ylabel('Detection Rate')
plt.title('Detection Rates of Hybrid RF-LSTM Model')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']

# Extract the class labels and detection rates
labels = list(detection_rates.keys())
rates = list(detection_rates.values())

# Plot the line graph with filled area and labels
plt.figure(figsize=(10, 6))
plt.plot(labels, rates, marker='o', linestyle='-', linewidth=2)
plt.fill_between(labels, rates, color='darkslategrey', alpha=0.4)

# Add labels to each data point
for i in range(len(labels)):
    plt.text(labels[i], rates[i], "{:.2f}".format(rates[i]), ha='center', va='bottom')

plt.xlabel('Class')
plt.ylabel('Detection Rate')
plt.title('Detection Rates of Hybrid RF-LSTM Model')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
from keras.utils import np_utils

# Convert y_test and test_rf_lstm_predictions to one-hot encoded format
y_test_onehot = np_utils.to_categorical(np.argmax(y_test, axis=1))
test_rf_lstm_predictions_onehot = np_utils.to_categorical(test_rf_lstm_predictions, num_classes=10)  # Convert to one-hot encoded format with 10 classes

# Compute the AUC and ROC curves for each class
n_classes = y_test_onehot.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_onehot[:, i], test_rf_lstm_predictions_onehot[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_onehot.ravel(), test_rf_lstm_predictions_onehot.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta']  # Adjust the colors as needed
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='Class {0} (AUC = {1:0.2f})'.format(i, roc_auc[i]))

# Plot the micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='black', lw=2, linestyle='--', label='Micro-average (AUC = {0:0.2f})'.format(roc_auc["micro"]))

plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Print confusion matrix and classification report
##print(confusion_matrix(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))
##print(classification_report(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))
