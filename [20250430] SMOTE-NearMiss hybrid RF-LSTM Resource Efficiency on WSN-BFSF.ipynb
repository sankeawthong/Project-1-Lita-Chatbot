# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/%5B20250430%5D%20SMOTE-NearMiss%20hybrid%20RF-LSTM%20Resource%20Efficiency%20on%20WSN-BFSF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **SMOTE-MissNear Hybrid RF-LSTM for 4 class classifications with k-folds, kernel=0.0001, Dropout=0.1(100ep)**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
#from keras.utils import np_utils
from tensorflow.python.keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from collections import Counter

# %%
# Load dataset
dataset = pd.read_csv("dataset.csv")
dataset.isnull().sum()
# Out:
# Event             0
# Time              0
# S_Node            0
# Node_id           0
# Rest_Energy       0
# Trace_Level       0
# Mac_Type_Pckt     0
# Source_IP_Port    0
# Des_IP_Port       0
# Packet_Size       0
# TTL               0
# Hop_Count         0
# Broadcast_ID      0
# Dest_Node_Num     0
# Dest_Seq_Num      0
# Src_Node_ID       0
# Src_Seq_Num       0
# Class             0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312106 entries, 0 to 312105
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Event           312106 non-null  int64
#  1   Time            312106 non-null  float64
#  2   S_Node          312106 non-null  int64
#  3   Node_id         312106 non-null  int64
#  4   Rest_Energy     312106 non-null  float64
#  5   Trace_Level     312106 non-null  int64
#  6   Mac_Type_Pckt   312106 non-null  int64
#  7   Source_IP_Port  312106 non-null  float64
#  8   Des_IP_Port     312106 non-null  float64
#  9   Packet_Size     312106 non-null  int64
#  10  TTL             312106 non-null  int64
#  11  Hop_Count       312106 non-null  int64
#  12  Broadcast_ID    312106 non-null  int64
#  13  Dest_Node_Num   312106 non-null  int64
#  14  Dest_Seq_Num    312106 non-null  int64
#  15  Src_Node_ID     312106 non-null  int64
#  16  Src_Seq_Num     312106 non-null  int64
#  17  Class           312106 non-null  int64
# dtypes: float64(4), int64(14)
# memory usage: 42.9 MB

# %%
print(dataset["Class"].unique())
# Out:
# [0 1 2 3]

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.python.keras.utils import np_utils

encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])
y = np_utils.to_categorical(y, num_classes=4)  # update to 4 classes
X = dataset.drop(['Class'], axis=1)
X = X.values
print(X.shape)
print(y.shape)
# Out:
# (312106, 17)
# (312106, 4)

# %%
# Data preprocessing
y = dataset['Class'].values
X = dataset.drop(['Class'],axis=1)
X=X.values
print(X)
print(y)
# Out:
# [[1.00000000e+00 1.00000000e-01 7.90000000e+01 ... 0.00000000e+00
#   7.90000000e+01 4.00000000e+00]
#  [2.00000000e+00 1.00963167e-01 7.80000000e+01 ... 0.00000000e+00
#   7.90000000e+01 4.00000000e+00]
#  [2.00000000e+00 1.00963500e-01 7.60000000e+01 ... 0.00000000e+00
#   7.90000000e+01 4.00000000e+00]
#  ...
#  [4.00000000e+00 6.57891729e+02 1.40000000e+02 ... 1.60000000e+01
#   1.40000000e+02 7.60000000e+01]
#  [4.00000000e+00 6.58574656e+02 1.40000000e+02 ... 1.60000000e+01
#   1.40000000e+02 8.00000000e+01]
#  [4.00000000e+00 6.79054956e+02 1.40000000e+02 ... 1.60000000e+01
#   1.40000000e+02 9.00000000e+01]]
# [0 0 0 ... 1 1 1]

# %%
import collections as c
counter = c.Counter(y)
print(counter)
# Out:
# Counter({np.int64(0): 262851, np.int64(3): 29844, np.int64(1): 11766, np.int64(2): 7645})

# %% [markdown]
# **SMOTE-NearMiss Databalancing**

# %%
# Check class distribution
counter = Counter(y)
print("Before SMOTE:", counter)
# Out:
# Before SMOTE: Counter({np.int64(0): 262851, np.int64(3): 29844, np.int64(1): 11766, np.int64(2): 7645})

# %%
# Data preprocessing
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)
counter = c.Counter(y)
print(counter)
# Out:
# Counter({np.int64(0): 262851, np.int64(1): 262851, np.int64(2): 262851, np.int64(3): 262851})

# %%
# Apply NearMiss for undersampling
nm = NearMiss()
X_res, y_res = nm.fit_resample(X, y)
print("After NearMiss:", Counter(y_res))
# Out:
# After NearMiss: Counter({np.int64(0): 262851, np.int64(1): 262851, np.int64(2): 262851, np.int64(3): 262851})

# %% [markdown]
# **Data Splitting (Train 80/Test 20)**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Utilized K-Fold Cross Validation**

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
# Define the number of classes
num_classes = 4

# Define the number of folds
num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Initialize lists to store evaluation metrics for each fold
accuracies = []
recalls = []
precisions = []
f1scores = []
confusion_matrices = []
classification_reports = []

# %%
# Iterate through the folds
#for fold, (train_index, test_index) in enumerate(skf.split(X, y.argmax(axis=1))):
for fold, (train_index, test_index) in enumerate(skf.split(X, y)):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# **Hybrid RF-LSTM for 4 class Ver.2.2**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input
#train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
#test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, 1))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, 1))

# %%
train_rf_features = train_rf_features[:y_train.shape[0]]
#y_train = np.concatenate((y_train, np.zeros((train_rf_features.shape[0] - y_train.shape[0], 4))))

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.1))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.1))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.1))
lstm_model.add(Dense(4, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

y_train = to_categorical(y_train, num_classes=4)  # One-hot encode y_train

history = lstm_model.fit(train_rf_features, y_train, epochs=100, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 0.9625 - loss: 0.1137 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 2/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 3/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 9.6915e-04
# Epoch 4/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 9.1711e-04
# Epoch 5/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 9.8859e-04 - val_accuracy: 1.0000 - val_loss: 7.1475e-04
# Epoch 6/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 8.4953e-04 - val_accuracy: 1.0000 - val_loss: 6.0654e-04
# Epoch 7/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 5ms/step - accuracy: 1.0000 - loss: 7.1361e-04 - val_accuracy: 1.0000 - val_loss: 5.3203e-04
# Epoch 8/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 6.6499e-04 - val_accuracy: 1.0000 - val_loss: 5.0723e-04
# Epoch 9/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 6.2989e-04 - val_accuracy: 1.0000 - val_loss: 5.6371e-04
# Epoch 10/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 5.3701e-04 - val_accuracy: 1.0000 - val_loss: 4.3214e-04
# Epoch 11/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 5.6804e-04 - val_accuracy: 1.0000 - val_loss: 4.2380e-04
# Epoch 12/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 5.2152e-04 - val_accuracy: 1.0000 - val_loss: 5.1359e-04
# Epoch 13/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.2311e-04 - val_accuracy: 1.0000 - val_loss: 4.9924e-04
# Epoch 14/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.1810e-04 - val_accuracy: 1.0000 - val_loss: 4.2184e-04
# Epoch 15/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.4789e-04 - val_accuracy: 1.0000 - val_loss: 4.9091e-04
# Epoch 16/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 4.9148e-04 - val_accuracy: 1.0000 - val_loss: 3.9589e-04
# Epoch 17/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.0516e-04 - val_accuracy: 1.0000 - val_loss: 3.9904e-04
# Epoch 18/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.5961e-04 - val_accuracy: 1.0000 - val_loss: 3.8131e-04
# Epoch 19/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.0630e-04 - val_accuracy: 1.0000 - val_loss: 3.5363e-04
# Epoch 20/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 5.3386e-04 - val_accuracy: 1.0000 - val_loss: 3.9907e-04
# Epoch 21/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 5.5586e-04 - val_accuracy: 1.0000 - val_loss: 4.0091e-04
# Epoch 22/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.4894e-04 - val_accuracy: 1.0000 - val_loss: 3.6198e-04
# Epoch 23/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.4876e-04 - val_accuracy: 1.0000 - val_loss: 4.0997e-04
# Epoch 24/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.4256e-04 - val_accuracy: 1.0000 - val_loss: 4.2589e-04
# Epoch 25/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.2991e-04 - val_accuracy: 1.0000 - val_loss: 3.3993e-04
# Epoch 26/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.8640e-04 - val_accuracy: 1.0000 - val_loss: 3.9135e-04
# Epoch 27/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.6804e-04 - val_accuracy: 1.0000 - val_loss: 4.0758e-04
# Epoch 28/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.1883e-04 - val_accuracy: 1.0000 - val_loss: 3.4088e-04
# Epoch 29/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 0.9999 - loss: 7.2216e-04 - val_accuracy: 1.0000 - val_loss: 3.7657e-04
# Epoch 30/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 4.2963e-04 - val_accuracy: 1.0000 - val_loss: 4.2439e-04
# Epoch 31/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.9109e-04 - val_accuracy: 1.0000 - val_loss: 3.9821e-04
# Epoch 32/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 4.7307e-04 - val_accuracy: 1.0000 - val_loss: 4.1283e-04
# Epoch 33/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.5067e-04 - val_accuracy: 1.0000 - val_loss: 3.5525e-04
# Epoch 34/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 5.0164e-04 - val_accuracy: 1.0000 - val_loss: 3.5924e-04
# Epoch 35/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.9999 - loss: 6.0887e-04 - val_accuracy: 1.0000 - val_loss: 3.1631e-04
# Epoch 36/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.9999 - loss: 7.9912e-04 - val_accuracy: 1.0000 - val_loss: 3.3540e-04
# Epoch 37/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 4.3112e-04 - val_accuracy: 1.0000 - val_loss: 3.5413e-04
# Epoch 38/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 4.4199e-04 - val_accuracy: 1.0000 - val_loss: 3.2485e-04
# Epoch 39/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 5.3062e-04 - val_accuracy: 1.0000 - val_loss: 3.8485e-04
# Epoch 40/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.4172e-04 - val_accuracy: 1.0000 - val_loss: 3.3248e-04
# Epoch 41/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 0.9999 - loss: 7.1298e-04 - val_accuracy: 1.0000 - val_loss: 4.6524e-04
# Epoch 42/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 5.0735e-04 - val_accuracy: 1.0000 - val_loss: 3.4136e-04
# Epoch 43/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 4.3685e-04 - val_accuracy: 1.0000 - val_loss: 3.0077e-04
# Epoch 44/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.4596e-04 - val_accuracy: 1.0000 - val_loss: 4.1001e-04
# Epoch 45/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.0816e-04 - val_accuracy: 1.0000 - val_loss: 3.6681e-04
# Epoch 46/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.9376e-04 - val_accuracy: 1.0000 - val_loss: 4.1162e-04
# Epoch 47/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.0868e-04 - val_accuracy: 1.0000 - val_loss: 3.3498e-04
# Epoch 48/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 5.4861e-04 - val_accuracy: 1.0000 - val_loss: 4.1484e-04
# Epoch 49/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.6143e-04 - val_accuracy: 1.0000 - val_loss: 3.0798e-04
# Epoch 50/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.2177e-04 - val_accuracy: 1.0000 - val_loss: 4.2938e-04
# Epoch 51/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.9768e-04 - val_accuracy: 1.0000 - val_loss: 3.7457e-04
# Epoch 52/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 5.0740e-04 - val_accuracy: 1.0000 - val_loss: 3.8116e-04
# Epoch 53/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 0.9999 - loss: 5.9047e-04 - val_accuracy: 1.0000 - val_loss: 4.4671e-04
# Epoch 54/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.1056e-04 - val_accuracy: 1.0000 - val_loss: 2.9848e-04
# Epoch 55/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 0.9999 - loss: 5.8325e-04 - val_accuracy: 1.0000 - val_loss: 3.3760e-04
# Epoch 56/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.6065e-04 - val_accuracy: 1.0000 - val_loss: 3.5769e-04
# Epoch 57/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 3.7273e-04 - val_accuracy: 1.0000 - val_loss: 3.7562e-04
# Epoch 58/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.0908e-04 - val_accuracy: 1.0000 - val_loss: 2.8842e-04
# Epoch 59/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.6730e-04 - val_accuracy: 1.0000 - val_loss: 3.7376e-04
# Epoch 60/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.5325e-04 - val_accuracy: 1.0000 - val_loss: 3.1549e-04
# Epoch 61/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 4.8974e-04 - val_accuracy: 1.0000 - val_loss: 3.5630e-04
# Epoch 62/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.7645e-04 - val_accuracy: 1.0000 - val_loss: 4.0137e-04
# Epoch 63/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.2718e-04 - val_accuracy: 1.0000 - val_loss: 3.8605e-04
# Epoch 64/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 5.0738e-04 - val_accuracy: 1.0000 - val_loss: 3.9542e-04
# Epoch 65/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.4669e-04 - val_accuracy: 1.0000 - val_loss: 4.1831e-04
# Epoch 66/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 5.5349e-04 - val_accuracy: 1.0000 - val_loss: 3.8290e-04
# Epoch 67/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 1.0000 - loss: 4.1717e-04 - val_accuracy: 1.0000 - val_loss: 4.4109e-04
# Epoch 68/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 4.5439e-04 - val_accuracy: 1.0000 - val_loss: 4.5958e-04
# Epoch 69/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 5.2413e-04 - val_accuracy: 1.0000 - val_loss: 4.2768e-04
# Epoch 70/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.0638e-04 - val_accuracy: 1.0000 - val_loss: 3.3003e-04
# Epoch 71/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.9849e-04 - val_accuracy: 1.0000 - val_loss: 3.9209e-04
# Epoch 72/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.7514e-04 - val_accuracy: 1.0000 - val_loss: 3.2972e-04
# Epoch 73/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 1.0000 - loss: 5.1728e-04 - val_accuracy: 1.0000 - val_loss: 3.4231e-04
# Epoch 74/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 1.0000 - loss: 4.0835e-04 - val_accuracy: 1.0000 - val_loss: 4.2482e-04
# Epoch 75/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 1.0000 - loss: 4.4714e-04 - val_accuracy: 1.0000 - val_loss: 3.5600e-04
# Epoch 76/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 0.9999 - loss: 8.9190e-04 - val_accuracy: 1.0000 - val_loss: 3.5459e-04
# Epoch 77/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.1713e-04 - val_accuracy: 1.0000 - val_loss: 3.3981e-04
# Epoch 78/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 6.4117e-04 - val_accuracy: 1.0000 - val_loss: 3.9196e-04
# Epoch 79/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 5.1998e-04 - val_accuracy: 1.0000 - val_loss: 2.8686e-04
# Epoch 80/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 0.9999 - loss: 8.5210e-04 - val_accuracy: 1.0000 - val_loss: 3.4218e-04
# Epoch 81/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 0.9999 - loss: 5.3056e-04 - val_accuracy: 1.0000 - val_loss: 4.1235e-04
# Epoch 82/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.6464e-04 - val_accuracy: 1.0000 - val_loss: 3.6799e-04
# Epoch 83/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 0.9999 - loss: 6.5147e-04 - val_accuracy: 1.0000 - val_loss: 3.1633e-04
# Epoch 84/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.4475e-04 - val_accuracy: 1.0000 - val_loss: 4.7235e-04
# Epoch 85/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 0.9999 - loss: 6.8565e-04 - val_accuracy: 1.0000 - val_loss: 4.6829e-04
# Epoch 86/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.4819e-04 - val_accuracy: 1.0000 - val_loss: 4.9949e-04
# Epoch 87/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.3074e-04 - val_accuracy: 1.0000 - val_loss: 3.5055e-04
# Epoch 88/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.7418e-04 - val_accuracy: 1.0000 - val_loss: 3.2844e-04
# Epoch 89/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 0.9999 - loss: 7.9254e-04 - val_accuracy: 1.0000 - val_loss: 3.7248e-04
# Epoch 90/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 5.3844e-04 - val_accuracy: 1.0000 - val_loss: 4.0729e-04
# Epoch 91/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.6080e-04 - val_accuracy: 1.0000 - val_loss: 4.3762e-04
# Epoch 92/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.9935e-04 - val_accuracy: 1.0000 - val_loss: 3.3419e-04
# Epoch 93/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 0.9999 - loss: 5.6683e-04 - val_accuracy: 1.0000 - val_loss: 4.2312e-04
# Epoch 94/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 3.9747e-04 - val_accuracy: 1.0000 - val_loss: 3.1120e-04
# Epoch 95/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 3.5581e-04 - val_accuracy: 1.0000 - val_loss: 4.5551e-04
# Epoch 96/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 3.7516e-04 - val_accuracy: 1.0000 - val_loss: 3.2073e-04
# Epoch 97/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.8389e-04 - val_accuracy: 1.0000 - val_loss: 4.1116e-04
# Epoch 98/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.8072e-04 - val_accuracy: 1.0000 - val_loss: 3.8083e-04
# Epoch 99/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 3.8393e-04 - val_accuracy: 1.0000 - val_loss: 3.3151e-04
# Epoch 100/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 5ms/step - accuracy: 0.9999 - loss: 6.0037e-04 - val_accuracy: 1.0000 - val_loss: 4.2074e-04
# 3286/3286 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step

# %%
import collections as c

# Calculate the confusion matrix and classification report
# Ensure that y_test and test_rf_lstm_predictions are 2D arrays
confusion = confusion_matrix(y_test, test_rf_lstm_predictions)
classification_report_result = classification_report(y_test, test_rf_lstm_predictions)

# Print the confusion matrix and classification report
print("Confusion Matrix:")
print(confusion)
print("\nClassification Report:")
print(classification_report_result)

# Plot the training and validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Confusion Matrix:
# [[26282     3     0     0]
#  [    6 26272     0     7]
#  [    3     0 26282     0]
#  [    0     5     7 26273]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     26285
#            1       1.00      1.00      1.00     26285
#            2       1.00      1.00      1.00     26285
#            3       1.00      1.00      1.00     26285
#
#     accuracy                           1.00    105140
#    macro avg       1.00      1.00      1.00    105140
# weighted avg       1.00      1.00      1.00    105140

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
# Calculate evaluation metrics
accuracy = accuracy_score(y_test, test_rf_lstm_predictions)
recall = recall_score(y_test, test_rf_lstm_predictions, average='weighted')
precision = precision_score(y_test, test_rf_lstm_predictions, average='weighted')
f1score = f1_score(y_test, test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(y_test, test_rf_lstm_predictions)
classification_rep = classification_report(y_test, test_rf_lstm_predictions)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.9997051550313867
# Recall: 0.9997051550313867
# Precision: 0.9997051575531462
# F1-Score: 0.9997051470680303
# Confusion Matrix:
#  [[26282     3     0     0]
#  [    6 26272     0     7]
#  [    3     0 26282     0]
#  [    0     5     7 26273]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     26285
#            1       1.00      1.00      1.00     26285
#            2       1.00      1.00      1.00     26285
#            3       1.00      1.00      1.00     26285
#
#     accuracy                           1.00    105140
#    macro avg       1.00      1.00      1.00    105140
# weighted avg       1.00      1.00      1.00    105140

# %%
# prompt: Evaluate Training time and Memory usage

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import NearMiss
from collections import Counter
import collections as c
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score
import time
import tracemalloc

# ... (rest of your code remains the same)

# Start tracing memory usage
tracemalloc.start()

# Start timer
start_time = time.time()

# ... (your model training code)

# Stop timer
end_time = time.time()

# Stop tracing memory usage
current, peak = tracemalloc.get_traced_memory()
tracemalloc.stop()

# Calculate training time
training_time = end_time - start_time

print(f"Training time: {training_time:.2f} seconds")
print(f"Peak memory usage: {peak / 10**6:.2f} MB")
# Out:
# Training time: 0.00 seconds
# Peak memory usage: 0.01 MB

# %%
import time, psutil, os
start_time = time.time()
process = psutil.Process(os.getpid())

# === TRAINING STARTS HERE ===
# The original code used 'model' which was not defined.
# Replacing it with 'lstm_model' which is the trained LSTM model.
lstm_model.fit(train_rf_features, y_train, epochs=100, batch_size=64, validation_split=0.2)
# === TRAINING ENDS HERE ===

end_time = time.time()
print(f"Training time: {end_time - start_time:.2f} seconds")
print(f"Memory usage: {process.memory_info().rss / (1024 ** 2):.8f} MB")
# Out:
# Epoch 1/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 0.9999 - loss: 7.7879e-04 - val_accuracy: 1.0000 - val_loss: 4.8617e-04
# Epoch 2/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 47s 4ms/step - accuracy: 1.0000 - loss: 5.1694e-04 - val_accuracy: 1.0000 - val_loss: 3.4265e-04
# Epoch 3/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 45s 4ms/step - accuracy: 1.0000 - loss: 5.9338e-04 - val_accuracy: 1.0000 - val_loss: 4.0292e-04
# Epoch 4/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 45s 4ms/step - accuracy: 1.0000 - loss: 5.6863e-04 - val_accuracy: 1.0000 - val_loss: 4.5478e-04
# Epoch 5/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 1.0000 - loss: 4.4825e-04 - val_accuracy: 1.0000 - val_loss: 5.0235e-04
# Epoch 6/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 46s 4ms/step - accuracy: 1.0000 - loss: 5.4398e-04 - val_accuracy: 1.0000 - val_loss: 4.6321e-04
# Epoch 7/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 48s 4ms/step - accuracy: 1.0000 - loss: 4.6401e-04 - val_accuracy: 1.0000 - val_loss: 4.2188e-04
# Epoch 8/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 4.8632e-04 - val_accuracy: 1.0000 - val_loss: 3.8554e-04
# Epoch 9/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.6904e-04 - val_accuracy: 1.0000 - val_loss: 3.9661e-04
# Epoch 10/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.4858e-04 - val_accuracy: 1.0000 - val_loss: 3.5144e-04
# Epoch 11/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 0.9999 - loss: 6.0007e-04 - val_accuracy: 1.0000 - val_loss: 3.6252e-04
# Epoch 12/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.3325e-04 - val_accuracy: 1.0000 - val_loss: 2.7978e-04
# Epoch 13/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 0.9999 - loss: 9.0692e-04 - val_accuracy: 1.0000 - val_loss: 2.9217e-04
# Epoch 14/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 5.0398e-04 - val_accuracy: 1.0000 - val_loss: 4.2747e-04
# Epoch 15/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 4.4613e-04 - val_accuracy: 1.0000 - val_loss: 4.7874e-04
# Epoch 16/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 5.4538e-04 - val_accuracy: 1.0000 - val_loss: 4.8092e-04
# Epoch 17/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.7638e-04 - val_accuracy: 1.0000 - val_loss: 3.6020e-04
# Epoch 18/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.4569e-04 - val_accuracy: 1.0000 - val_loss: 5.0084e-04
# Epoch 19/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.7475e-04 - val_accuracy: 1.0000 - val_loss: 3.8163e-04
# Epoch 20/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.1709e-04 - val_accuracy: 1.0000 - val_loss: 4.0595e-04
# Epoch 21/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.0224e-04 - val_accuracy: 1.0000 - val_loss: 4.3810e-04
# Epoch 22/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 4.5806e-04 - val_accuracy: 1.0000 - val_loss: 5.0939e-04
# Epoch 23/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 1.0000 - loss: 5.6850e-04 - val_accuracy: 1.0000 - val_loss: 3.8564e-04
# Epoch 24/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.8197e-04 - val_accuracy: 1.0000 - val_loss: 4.1732e-04
# Epoch 25/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 58s 5ms/step - accuracy: 1.0000 - loss: 5.2865e-04 - val_accuracy: 1.0000 - val_loss: 4.6619e-04
# Epoch 26/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 4.3940e-04 - val_accuracy: 1.0000 - val_loss: 3.8322e-04
# Epoch 27/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.1869e-04 - val_accuracy: 1.0000 - val_loss: 3.7415e-04
# Epoch 28/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 51s 4ms/step - accuracy: 0.9999 - loss: 7.6215e-04 - val_accuracy: 1.0000 - val_loss: 3.9530e-04
# Epoch 29/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 4.5675e-04 - val_accuracy: 1.0000 - val_loss: 4.3185e-04
# Epoch 30/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 0.9999 - loss: 6.3455e-04 - val_accuracy: 1.0000 - val_loss: 6.2958e-04
# Epoch 31/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 6.6961e-04 - val_accuracy: 1.0000 - val_loss: 3.9589e-04
# Epoch 32/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 59s 5ms/step - accuracy: 1.0000 - loss: 4.8997e-04 - val_accuracy: 1.0000 - val_loss: 3.7654e-04
# Epoch 33/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 4.8346e-04 - val_accuracy: 1.0000 - val_loss: 4.5650e-04
# Epoch 34/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 5.0139e-04 - val_accuracy: 1.0000 - val_loss: 2.9951e-04
# Epoch 35/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9999 - loss: 6.9004e-04 - val_accuracy: 1.0000 - val_loss: 2.9855e-04
# Epoch 36/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 0.9999 - loss: 7.8205e-04 - val_accuracy: 1.0000 - val_loss: 3.4608e-04
# Epoch 37/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 4.3808e-04 - val_accuracy: 1.0000 - val_loss: 5.6300e-04
# Epoch 38/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.8733e-04 - val_accuracy: 1.0000 - val_loss: 3.8641e-04
# Epoch 39/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 5.3532e-04 - val_accuracy: 1.0000 - val_loss: 3.5107e-04
# Epoch 40/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 0.9999 - loss: 6.7889e-04 - val_accuracy: 1.0000 - val_loss: 3.2067e-04
# Epoch 41/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 5.2826e-04 - val_accuracy: 1.0000 - val_loss: 3.8861e-04
# Epoch 42/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 58s 5ms/step - accuracy: 1.0000 - loss: 4.7688e-04 - val_accuracy: 1.0000 - val_loss: 3.2167e-04
# Epoch 43/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 58s 5ms/step - accuracy: 1.0000 - loss: 4.4979e-04 - val_accuracy: 1.0000 - val_loss: 3.3295e-04
# Epoch 44/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 5.0511e-04 - val_accuracy: 1.0000 - val_loss: 4.9726e-04
# Epoch 45/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 6.3143e-04 - val_accuracy: 1.0000 - val_loss: 3.3057e-04
# Epoch 46/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9998 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 4.1003e-04
# Epoch 47/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 59s 5ms/step - accuracy: 1.0000 - loss: 5.1377e-04 - val_accuracy: 1.0000 - val_loss: 4.0865e-04
# Epoch 48/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 0.9999 - loss: 6.5121e-04 - val_accuracy: 1.0000 - val_loss: 5.6848e-04
# Epoch 49/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 58s 5ms/step - accuracy: 1.0000 - loss: 5.3554e-04 - val_accuracy: 1.0000 - val_loss: 3.5184e-04
# Epoch 50/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 0.9999 - loss: 5.2075e-04 - val_accuracy: 1.0000 - val_loss: 3.1745e-04
# Epoch 51/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 4.1996e-04 - val_accuracy: 1.0000 - val_loss: 3.8004e-04
# Epoch 52/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - accuracy: 1.0000 - loss: 5.6417e-04 - val_accuracy: 1.0000 - val_loss: 4.0527e-04
# Epoch 53/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 5.0602e-04 - val_accuracy: 1.0000 - val_loss: 4.1432e-04
# Epoch 54/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 4.7741e-04 - val_accuracy: 1.0000 - val_loss: 3.3169e-04
# Epoch 55/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 60s 5ms/step - accuracy: 1.0000 - loss: 5.6500e-04 - val_accuracy: 1.0000 - val_loss: 4.1844e-04
# Epoch 56/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 5.2096e-04 - val_accuracy: 1.0000 - val_loss: 4.4425e-04
# Epoch 57/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 5.3404e-04 - val_accuracy: 1.0000 - val_loss: 3.5930e-04
# Epoch 58/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 0.9999 - loss: 6.3126e-04 - val_accuracy: 1.0000 - val_loss: 3.7980e-04
# Epoch 59/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9999 - loss: 5.3156e-04 - val_accuracy: 1.0000 - val_loss: 5.0178e-04
# Epoch 60/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 5.2885e-04 - val_accuracy: 1.0000 - val_loss: 4.1215e-04
# Epoch 61/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - accuracy: 0.9999 - loss: 7.1219e-04 - val_accuracy: 1.0000 - val_loss: 4.1293e-04
# Epoch 62/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 0.9999 - loss: 7.6086e-04 - val_accuracy: 1.0000 - val_loss: 3.0036e-04
# Epoch 63/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 0.9999 - loss: 5.8209e-04 - val_accuracy: 1.0000 - val_loss: 4.9626e-04
# Epoch 64/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 5.4044e-04 - val_accuracy: 1.0000 - val_loss: 4.3507e-04
# Epoch 65/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 4.9852e-04 - val_accuracy: 1.0000 - val_loss: 2.8078e-04
# Epoch 66/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 0.9999 - loss: 7.3634e-04 - val_accuracy: 1.0000 - val_loss: 3.3593e-04
# Epoch 67/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 4.4065e-04 - val_accuracy: 1.0000 - val_loss: 3.9219e-04
# Epoch 68/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 4.0333e-04 - val_accuracy: 1.0000 - val_loss: 3.4363e-04
# Epoch 69/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 4.4854e-04 - val_accuracy: 1.0000 - val_loss: 4.2308e-04
# Epoch 70/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 5.2276e-04 - val_accuracy: 1.0000 - val_loss: 3.8473e-04
# Epoch 71/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9999 - loss: 7.2317e-04 - val_accuracy: 1.0000 - val_loss: 4.6240e-04
# Epoch 72/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 5ms/step - accuracy: 1.0000 - loss: 5.7781e-04 - val_accuracy: 1.0000 - val_loss: 3.7140e-04
# Epoch 73/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 58s 5ms/step - accuracy: 1.0000 - loss: 5.2968e-04 - val_accuracy: 1.0000 - val_loss: 3.8453e-04
# Epoch 74/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 63s 5ms/step - accuracy: 1.0000 - loss: 4.9128e-04 - val_accuracy: 1.0000 - val_loss: 3.4619e-04
# Epoch 75/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 58s 5ms/step - accuracy: 1.0000 - loss: 5.5951e-04 - val_accuracy: 1.0000 - val_loss: 4.0126e-04
# Epoch 76/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 5.2228e-04 - val_accuracy: 1.0000 - val_loss: 4.2756e-04
# Epoch 77/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9999 - loss: 6.2706e-04 - val_accuracy: 1.0000 - val_loss: 4.7934e-04
# Epoch 78/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.3588e-04 - val_accuracy: 1.0000 - val_loss: 3.9173e-04
# Epoch 79/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 1.0000 - loss: 4.6370e-04 - val_accuracy: 1.0000 - val_loss: 3.5411e-04
# Epoch 80/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 1.0000 - loss: 4.9320e-04 - val_accuracy: 1.0000 - val_loss: 3.0095e-04
# Epoch 81/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9999 - loss: 5.3892e-04 - val_accuracy: 1.0000 - val_loss: 3.6657e-04
# Epoch 82/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 5ms/step - accuracy: 1.0000 - loss: 5.1184e-04 - val_accuracy: 1.0000 - val_loss: 4.1560e-04
# Epoch 83/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 0.9999 - loss: 7.2943e-04 - val_accuracy: 1.0000 - val_loss: 3.3467e-04
# Epoch 84/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 0.9999 - loss: 5.2300e-04 - val_accuracy: 1.0000 - val_loss: 3.1376e-04
# Epoch 85/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 57s 5ms/step - accuracy: 0.9999 - loss: 8.3387e-04 - val_accuracy: 1.0000 - val_loss: 4.4839e-04
# Epoch 86/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - accuracy: 1.0000 - loss: 5.8019e-04 - val_accuracy: 1.0000 - val_loss: 4.3558e-04
# Epoch 87/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - accuracy: 0.9999 - loss: 6.5251e-04 - val_accuracy: 1.0000 - val_loss: 3.8403e-04
# Epoch 88/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - accuracy: 0.9998 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 4.8717e-04
# Epoch 89/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 56s 5ms/step - accuracy: 1.0000 - loss: 5.1353e-04 - val_accuracy: 1.0000 - val_loss: 4.0667e-04
# Epoch 90/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 60s 5ms/step - accuracy: 1.0000 - loss: 4.5952e-04 - val_accuracy: 1.0000 - val_loss: 5.1724e-04
# Epoch 91/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 59s 5ms/step - accuracy: 1.0000 - loss: 6.1869e-04 - val_accuracy: 1.0000 - val_loss: 4.1079e-04
# Epoch 92/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 1.0000 - loss: 5.2509e-04 - val_accuracy: 1.0000 - val_loss: 5.2297e-04
# Epoch 93/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 5.2669e-04 - val_accuracy: 1.0000 - val_loss: 4.3436e-04
# Epoch 94/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 49s 4ms/step - accuracy: 1.0000 - loss: 5.6512e-04 - val_accuracy: 1.0000 - val_loss: 4.1847e-04
# Epoch 95/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 53s 4ms/step - accuracy: 1.0000 - loss: 5.8209e-04 - val_accuracy: 1.0000 - val_loss: 3.2639e-04
# Epoch 96/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 55s 5ms/step - accuracy: 0.9999 - loss: 7.7519e-04 - val_accuracy: 1.0000 - val_loss: 4.4835e-04
# Epoch 97/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.9270e-04 - val_accuracy: 1.0000 - val_loss: 5.0779e-04
# Epoch 98/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 50s 4ms/step - accuracy: 1.0000 - loss: 4.7134e-04 - val_accuracy: 1.0000 - val_loss: 4.2426e-04
# Epoch 99/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 4.6646e-04 - val_accuracy: 1.0000 - val_loss: 3.8510e-04
# Epoch 100/100
# 11829/11829 ━━━━━━━━━━━━━━━━━━━━ 52s 4ms/step - accuracy: 1.0000 - loss: 5.0728e-04 - val_accuracy: 1.0000 - val_loss: 3.3821e-04
# Training time: 5387.26 seconds
# Memory usage: 2194.41796875 MB

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot training loss and validation/test loss over each epoch of training
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy and Training Loss')
plt.xlabel('Accuracy')
plt.ylabel('Loss')
plt.legend()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  #plt.figure(figsize=(6,5.5))
  plt.figure(figsize=(8,6.5))
  #ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='tab20c')
  ax = sns.heatmap(cm, annot=True, fmt=".0f", cmap="PuBu",
                 vmin=0, vmax=27000, center=0, square=True, linewidths=1.5)
  sns.set(font_scale=1)
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n');
  ax.xaxis.set_ticklabels(['Normal','Flooding','Blackhole','Forwarding'])
  ax.yaxis.set_ticklabels(['Normal','Flooding','Blackhole','Forwarding'])
  ##plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  ##plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.tight_layout()
  # plt.savefig("F1.eps", format = 'eps')
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model")
conf_mat(y_test, test_rf_lstm_predictions)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
# Compute TP, TN, FP, FN for each class
cm = confusion_matrix(y_test, test_rf_lstm_predictions)
FP = cm.sum(axis=0) - np.diag(cm)
FN = cm.sum(axis=1) - np.diag(cm)
TP = np.diag(cm)
TN = cm.sum() - (FP + FN + TP)

# Compute False Positive Rate (FPR) and True Positive Rate (TPR) for each class
FPR = FP / (FP + TN)
TPR = TP / (TP + FN)

# Print FPR and TPR for each class
for i in range(4):
    print(f"Class {i} - FPR: {FPR[i]}, TPR: {TPR[i]}")
# Out:
# Class 0 - FPR: 0.00011413353623739776, TPR: 0.9998858664637627
# Class 1 - FPR: 0.00010145203221102023, TPR: 0.9995054213429713
# Class 2 - FPR: 8.87705281846427e-05, TPR: 0.9998858664637627
# Class 3 - FPR: 8.87705281846427e-05, TPR: 0.9995434658550504

# %%
# prompt: Show the detection rates of the model in 8 digits numerical

# Calculate detection rates and format them to 8 digits
detection_rates = TP / (TP + FN)
detection_rates_formatted = ["{:.10f}".format(rate) for rate in detection_rates]

# Print detection rates
for i, rate in enumerate(detection_rates_formatted):
    print(f"Class {i} Detection Rate: {rate}")
# Out:
# Class 0 Detection Rate: 0.9998858665
# Class 1 Detection Rate: 0.9995054213
# Class 2 Detection Rate: 0.9998858665
# Class 3 Detection Rate: 0.9995434659

# %%
# prompt: Create Discrete distribution as horizontal bar chart of the detection rates of class 0-3

import numpy as np
import matplotlib.pyplot as plt

# Create a list of class labels
class_labels = ['Normal', 'Flooding', 'Blackhole', 'Forwarding']

# Create a list of detection rates
detection_rates = [0.9999619555, 0.9995054213, 0.9997336884, 0.9995054213]

# Set the bar width
bar_width = 0.5

# Create the horizontal bar chart
plt.figure(figsize=(10, 6))
plt.barh(class_labels, detection_rates, bar_width, align='center', color='grey')

# Set the axis labels and title
plt.xlabel('Detection Rate')
plt.ylabel('Class')
plt.title('Discrete Distribution of Detection Rates')

# Display the chart
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.preprocessing import label_binarize
from itertools import cycle

# Assuming that y_test is not one-hot encoded
# Binarize the output labels for each class
y_test_bin = label_binarize(y_test, classes=[0, 1, 2, 3])
n_classes = y_test_bin.shape[1]

# Predict class probabilities for LSTM model
test_lstm_probs = lstm_model.predict(test_rf_features)

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], test_lstm_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_bin.ravel(), test_lstm_probs.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot all ROC curves
plt.figure(figsize=(10, 8))

# Plot micro-average ROC curve
plt.plot(fpr['micro'], tpr['micro'],
         label='micro-average ROC curve (area = {0:0.10f})'.format(roc_auc["micro"]),
         color='deeppink', linestyle=':', linewidth=4)

# Plot ROC curve for each class
colors = cycle(['blue', 'red', 'green', 'orange'])
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label='ROC curve of class {0} (area = {1:0.10f})'.format(i, roc_auc[i]))

# Plot chance level
plt.plot([0, 1], [0, 1], 'k--', lw=2)

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) - Multiclass')
plt.legend(loc="lower right")
plt.show()
# Out:
# 3286/3286 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step
