# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/Hybrid%20RF-LSTM%20for%204%20class%20classifications%20based%20on%20WSNBFSF%20without%20dropout(11112023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hybrid RF-LSTM for 4 class classifications based on WSNBFSF dataset ver.2.2**

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
#from keras.utils import np_utils
from tensorflow.python.keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
# Load dataset
dataset = pd.read_csv("dataset.csv")
dataset.isnull().sum()
# Out:
# Event             0
# Time              0
# S_Node            0
# Node_id           0
# Rest_Energy       0
# Trace_Level       0
# Mac_Type_Pckt     0
# Source_IP_Port    0
# Des_IP_Port       0
# Packet_Size       0
# TTL               0
# Hop_Count         0
# Broadcast_ID      0
# Dest_Node_Num     0
# Dest_Seq_Num      0
# Src_Node_ID       0
# Src_Seq_Num       0
# Class             0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312106 entries, 0 to 312105
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Event           312106 non-null  int64
#  1   Time            312106 non-null  float64
#  2   S_Node          312106 non-null  int64
#  3   Node_id         312106 non-null  int64
#  4   Rest_Energy     312106 non-null  float64
#  5   Trace_Level     312106 non-null  int64
#  6   Mac_Type_Pckt   312106 non-null  int64
#  7   Source_IP_Port  312106 non-null  float64
#  8   Des_IP_Port     312106 non-null  float64
#  9   Packet_Size     312106 non-null  int64
#  10  TTL             312106 non-null  int64
#  11  Hop_Count       312106 non-null  int64
#  12  Broadcast_ID    312106 non-null  int64
#  13  Dest_Node_Num   312106 non-null  int64
#  14  Dest_Seq_Num    312106 non-null  int64
#  15  Src_Node_ID     312106 non-null  int64
#  16  Src_Seq_Num     312106 non-null  int64
#  17  Class           312106 non-null  int64
# dtypes: float64(4), int64(14)
# memory usage: 42.9 MB

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])
y = np_utils.to_categorical(y, num_classes=4)  # update to 4 classes
X = dataset.drop(['Class'], axis=1)
X = X.values
print(X.shape)
print(y.shape)
# Out:
# (312106, 17)
# (312106, 4)

# %% [markdown]
# **Data Preprocessing**

# %%
# Data preprocessing
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# **Hybrid RF-LSTM for 4 class Ver.2.2**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))

# %%
# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
#lstm_model.add(Dropout(0.5))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.001)))
#lstm_model.add(Dropout(0.5))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.001)))
#lstm_model.add(Dropout(0.5))
lstm_model.add(Dense(4, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = lstm_model.fit(train_rf_features, y_train, epochs=150, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)

print(confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions))
print(classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions))

# Plot training/validation loss over each epoch
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# 10515/10515 [==============================] - 105s 9ms/step - loss: 0.0518 - accuracy: 0.9956 - val_loss: 0.0069 - val_accuracy: 1.0000
# Epoch 2/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 3/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 4/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 5/150
# 10515/10515 [==============================] - 80s 8ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 6/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 7/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 8/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0010 - val_accuracy: 1.0000
# Epoch 9/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 9.9883e-04 - accuracy: 1.0000 - val_loss: 9.6736e-04 - val_accuracy: 1.0000
# Epoch 10/150
# 10515/10515 [==============================] - 89s 8ms/step - loss: 9.3858e-04 - accuracy: 1.0000 - val_loss: 9.1250e-04 - val_accuracy: 1.0000
# Epoch 11/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 8.8952e-04 - accuracy: 1.0000 - val_loss: 8.7849e-04 - val_accuracy: 1.0000
# Epoch 12/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 8.4863e-04 - accuracy: 1.0000 - val_loss: 8.3275e-04 - val_accuracy: 1.0000
# Epoch 13/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 8.1407e-04 - accuracy: 1.0000 - val_loss: 7.9920e-04 - val_accuracy: 1.0000
# Epoch 14/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 7.8436e-04 - accuracy: 1.0000 - val_loss: 7.8565e-04 - val_accuracy: 1.0000
# Epoch 15/150
# 10515/10515 [==============================] - 80s 8ms/step - loss: 7.5835e-04 - accuracy: 1.0000 - val_loss: 7.6602e-04 - val_accuracy: 1.0000
# Epoch 16/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 7.3550e-04 - accuracy: 1.0000 - val_loss: 7.2673e-04 - val_accuracy: 1.0000
# Epoch 17/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 7.1508e-04 - accuracy: 1.0000 - val_loss: 7.1667e-04 - val_accuracy: 1.0000
# Epoch 18/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 6.9691e-04 - accuracy: 1.0000 - val_loss: 6.9586e-04 - val_accuracy: 1.0000
# Epoch 19/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 6.8041e-04 - accuracy: 1.0000 - val_loss: 6.7261e-04 - val_accuracy: 1.0000
# Epoch 20/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 6.6542e-04 - accuracy: 1.0000 - val_loss: 6.6677e-04 - val_accuracy: 1.0000
# Epoch 21/150
# 10515/10515 [==============================] - 80s 8ms/step - loss: 6.5163e-04 - accuracy: 1.0000 - val_loss: 6.4582e-04 - val_accuracy: 1.0000
# Epoch 22/150
# 10515/10515 [==============================] - 80s 8ms/step - loss: 6.3901e-04 - accuracy: 1.0000 - val_loss: 6.3498e-04 - val_accuracy: 1.0000
# Epoch 23/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 6.2740e-04 - accuracy: 1.0000 - val_loss: 6.2821e-04 - val_accuracy: 1.0000
# Epoch 24/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 6.1665e-04 - accuracy: 1.0000 - val_loss: 6.1265e-04 - val_accuracy: 1.0000
# Epoch 25/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 6.0654e-04 - accuracy: 1.0000 - val_loss: 6.0081e-04 - val_accuracy: 1.0000
# Epoch 26/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 5.9715e-04 - accuracy: 1.0000 - val_loss: 5.9323e-04 - val_accuracy: 1.0000
# Epoch 27/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 5.8841e-04 - accuracy: 1.0000 - val_loss: 5.9002e-04 - val_accuracy: 1.0000
# Epoch 28/150
# 10515/10515 [==============================] - 80s 8ms/step - loss: 5.8008e-04 - accuracy: 1.0000 - val_loss: 5.8820e-04 - val_accuracy: 1.0000
# Epoch 29/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 5.7232e-04 - accuracy: 1.0000 - val_loss: 5.6897e-04 - val_accuracy: 1.0000
# Epoch 30/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 5.6506e-04 - accuracy: 1.0000 - val_loss: 5.6530e-04 - val_accuracy: 1.0000
# Epoch 31/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 5.5808e-04 - accuracy: 1.0000 - val_loss: 5.6544e-04 - val_accuracy: 1.0000
# Epoch 32/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 5.5147e-04 - accuracy: 1.0000 - val_loss: 5.5876e-04 - val_accuracy: 1.0000
# Epoch 33/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 5.4521e-04 - accuracy: 1.0000 - val_loss: 5.4744e-04 - val_accuracy: 1.0000
# Epoch 34/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 5.3928e-04 - accuracy: 1.0000 - val_loss: 5.5267e-04 - val_accuracy: 1.0000
# Epoch 35/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 5.3365e-04 - accuracy: 1.0000 - val_loss: 5.3199e-04 - val_accuracy: 1.0000
# Epoch 36/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 5.2822e-04 - accuracy: 1.0000 - val_loss: 5.4817e-04 - val_accuracy: 1.0000
# Epoch 37/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 5.2305e-04 - accuracy: 1.0000 - val_loss: 5.3612e-04 - val_accuracy: 1.0000
# Epoch 38/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 5.1806e-04 - accuracy: 1.0000 - val_loss: 5.1741e-04 - val_accuracy: 1.0000
# Epoch 39/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 5.1330e-04 - accuracy: 1.0000 - val_loss: 5.2310e-04 - val_accuracy: 1.0000
# Epoch 40/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 5.0874e-04 - accuracy: 1.0000 - val_loss: 5.1724e-04 - val_accuracy: 1.0000
# Epoch 41/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 5.0439e-04 - accuracy: 1.0000 - val_loss: 5.1381e-04 - val_accuracy: 1.0000
# Epoch 42/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 5.0018e-04 - accuracy: 1.0000 - val_loss: 4.9912e-04 - val_accuracy: 1.0000
# Epoch 43/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 4.9608e-04 - accuracy: 1.0000 - val_loss: 5.2221e-04 - val_accuracy: 1.0000
# Epoch 44/150
# 10515/10515 [==============================] - 80s 8ms/step - loss: 4.9218e-04 - accuracy: 1.0000 - val_loss: 5.1580e-04 - val_accuracy: 1.0000
# Epoch 45/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 4.8852e-04 - accuracy: 1.0000 - val_loss: 4.9130e-04 - val_accuracy: 1.0000
# Epoch 46/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 4.8484e-04 - accuracy: 1.0000 - val_loss: 5.0360e-04 - val_accuracy: 1.0000
# Epoch 47/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 4.8130e-04 - accuracy: 1.0000 - val_loss: 4.9508e-04 - val_accuracy: 1.0000
# Epoch 48/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 4.7786e-04 - accuracy: 1.0000 - val_loss: 5.0711e-04 - val_accuracy: 1.0000
# Epoch 49/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 4.7457e-04 - accuracy: 1.0000 - val_loss: 4.9369e-04 - val_accuracy: 1.0000
# Epoch 50/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 4.7137e-04 - accuracy: 1.0000 - val_loss: 4.7144e-04 - val_accuracy: 1.0000
# Epoch 51/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.6835e-04 - accuracy: 1.0000 - val_loss: 4.6569e-04 - val_accuracy: 1.0000
# Epoch 52/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 4.6536e-04 - accuracy: 1.0000 - val_loss: 4.7694e-04 - val_accuracy: 1.0000
# Epoch 53/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 4.6243e-04 - accuracy: 1.0000 - val_loss: 4.6028e-04 - val_accuracy: 1.0000
# Epoch 54/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 4.5954e-04 - accuracy: 1.0000 - val_loss: 4.5688e-04 - val_accuracy: 1.0000
# Epoch 55/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.5684e-04 - accuracy: 1.0000 - val_loss: 4.7162e-04 - val_accuracy: 1.0000
# Epoch 56/150
# 10515/10515 [==============================] - 89s 8ms/step - loss: 4.5407e-04 - accuracy: 1.0000 - val_loss: 4.5266e-04 - val_accuracy: 1.0000
# Epoch 57/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.5150e-04 - accuracy: 1.0000 - val_loss: 4.9436e-04 - val_accuracy: 1.0000
# Epoch 58/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.4898e-04 - accuracy: 1.0000 - val_loss: 4.5513e-04 - val_accuracy: 1.0000
# Epoch 59/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 4.4655e-04 - accuracy: 1.0000 - val_loss: 4.6012e-04 - val_accuracy: 1.0000
# Epoch 60/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 4.4413e-04 - accuracy: 1.0000 - val_loss: 4.4638e-04 - val_accuracy: 1.0000
# Epoch 61/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 4.4178e-04 - accuracy: 1.0000 - val_loss: 4.3985e-04 - val_accuracy: 1.0000
# Epoch 62/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 4.3944e-04 - accuracy: 1.0000 - val_loss: 4.4735e-04 - val_accuracy: 1.0000
# Epoch 63/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 4.3728e-04 - accuracy: 1.0000 - val_loss: 4.4628e-04 - val_accuracy: 1.0000
# Epoch 64/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.3507e-04 - accuracy: 1.0000 - val_loss: 4.3422e-04 - val_accuracy: 1.0000
# Epoch 65/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 4.3298e-04 - accuracy: 1.0000 - val_loss: 4.3654e-04 - val_accuracy: 1.0000
# Epoch 66/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 4.3081e-04 - accuracy: 1.0000 - val_loss: 4.2874e-04 - val_accuracy: 1.0000
# Epoch 67/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 4.2879e-04 - accuracy: 1.0000 - val_loss: 4.3634e-04 - val_accuracy: 1.0000
# Epoch 68/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.2687e-04 - accuracy: 1.0000 - val_loss: 4.3411e-04 - val_accuracy: 1.0000
# Epoch 69/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 4.2492e-04 - accuracy: 1.0000 - val_loss: 4.3955e-04 - val_accuracy: 1.0000
# Epoch 70/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 4.2297e-04 - accuracy: 1.0000 - val_loss: 4.2865e-04 - val_accuracy: 1.0000
# Epoch 71/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 4.2116e-04 - accuracy: 1.0000 - val_loss: 4.2769e-04 - val_accuracy: 1.0000
# Epoch 72/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 4.1920e-04 - accuracy: 1.0000 - val_loss: 4.5086e-04 - val_accuracy: 1.0000
# Epoch 73/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 4.1746e-04 - accuracy: 1.0000 - val_loss: 4.1970e-04 - val_accuracy: 1.0000
# Epoch 74/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 4.1574e-04 - accuracy: 1.0000 - val_loss: 4.2247e-04 - val_accuracy: 1.0000
# Epoch 75/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 4.1395e-04 - accuracy: 1.0000 - val_loss: 4.2577e-04 - val_accuracy: 1.0000
# Epoch 76/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 4.1235e-04 - accuracy: 1.0000 - val_loss: 4.1733e-04 - val_accuracy: 1.0000
# Epoch 77/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 4.1062e-04 - accuracy: 1.0000 - val_loss: 4.2130e-04 - val_accuracy: 1.0000
# Epoch 78/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 4.0903e-04 - accuracy: 1.0000 - val_loss: 4.1658e-04 - val_accuracy: 1.0000
# Epoch 79/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 4.0737e-04 - accuracy: 1.0000 - val_loss: 4.0533e-04 - val_accuracy: 1.0000
# Epoch 80/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 4.0584e-04 - accuracy: 1.0000 - val_loss: 4.0416e-04 - val_accuracy: 1.0000
# Epoch 81/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 4.0432e-04 - accuracy: 1.0000 - val_loss: 4.2184e-04 - val_accuracy: 1.0000
# Epoch 82/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 4.0279e-04 - accuracy: 1.0000 - val_loss: 4.0606e-04 - val_accuracy: 1.0000
# Epoch 83/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 4.0125e-04 - accuracy: 1.0000 - val_loss: 4.0580e-04 - val_accuracy: 1.0000
# Epoch 84/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.9981e-04 - accuracy: 1.0000 - val_loss: 4.1733e-04 - val_accuracy: 1.0000
# Epoch 85/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.9846e-04 - accuracy: 1.0000 - val_loss: 3.9696e-04 - val_accuracy: 1.0000
# Epoch 86/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.9702e-04 - accuracy: 1.0000 - val_loss: 4.0857e-04 - val_accuracy: 1.0000
# Epoch 87/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.9559e-04 - accuracy: 1.0000 - val_loss: 4.0334e-04 - val_accuracy: 1.0000
# Epoch 88/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.9422e-04 - accuracy: 1.0000 - val_loss: 3.9285e-04 - val_accuracy: 1.0000
# Epoch 89/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.9292e-04 - accuracy: 1.0000 - val_loss: 4.1003e-04 - val_accuracy: 1.0000
# Epoch 90/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.9162e-04 - accuracy: 1.0000 - val_loss: 4.1085e-04 - val_accuracy: 1.0000
# Epoch 91/150
# 10515/10515 [==============================] - 81s 8ms/step - loss: 3.9028e-04 - accuracy: 1.0000 - val_loss: 3.8921e-04 - val_accuracy: 1.0000
# Epoch 92/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 3.8898e-04 - accuracy: 1.0000 - val_loss: 3.9395e-04 - val_accuracy: 1.0000
# Epoch 93/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.8777e-04 - accuracy: 1.0000 - val_loss: 4.0057e-04 - val_accuracy: 1.0000
# Epoch 94/150
# 10515/10515 [==============================] - 89s 8ms/step - loss: 3.8651e-04 - accuracy: 1.0000 - val_loss: 3.9174e-04 - val_accuracy: 1.0000
# Epoch 95/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.8530e-04 - accuracy: 1.0000 - val_loss: 3.9551e-04 - val_accuracy: 1.0000
# Epoch 96/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.8409e-04 - accuracy: 1.0000 - val_loss: 4.1026e-04 - val_accuracy: 1.0000
# Epoch 97/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.8292e-04 - accuracy: 1.0000 - val_loss: 4.0922e-04 - val_accuracy: 1.0000
# Epoch 98/150
# 10515/10515 [==============================] - 90s 9ms/step - loss: 3.8186e-04 - accuracy: 1.0000 - val_loss: 3.8035e-04 - val_accuracy: 1.0000
# Epoch 99/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 3.8064e-04 - accuracy: 1.0000 - val_loss: 4.1724e-04 - val_accuracy: 1.0000
# Epoch 100/150
# 10515/10515 [==============================] - 92s 9ms/step - loss: 3.7948e-04 - accuracy: 1.0000 - val_loss: 3.9550e-04 - val_accuracy: 1.0000
# Epoch 101/150
# 10515/10515 [==============================] - 92s 9ms/step - loss: 3.7844e-04 - accuracy: 1.0000 - val_loss: 3.7985e-04 - val_accuracy: 1.0000
# Epoch 102/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.7733e-04 - accuracy: 1.0000 - val_loss: 3.8988e-04 - val_accuracy: 1.0000
# Epoch 103/150
# 10515/10515 [==============================] - 91s 9ms/step - loss: 3.7617e-04 - accuracy: 1.0000 - val_loss: 3.7945e-04 - val_accuracy: 1.0000
# Epoch 104/150
# 10515/10515 [==============================] - 93s 9ms/step - loss: 3.7513e-04 - accuracy: 1.0000 - val_loss: 3.9329e-04 - val_accuracy: 1.0000
# Epoch 105/150
# 10515/10515 [==============================] - 90s 9ms/step - loss: 3.7406e-04 - accuracy: 1.0000 - val_loss: 4.1890e-04 - val_accuracy: 1.0000
# Epoch 106/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.7305e-04 - accuracy: 1.0000 - val_loss: 3.7297e-04 - val_accuracy: 1.0000
# Epoch 107/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.7208e-04 - accuracy: 1.0000 - val_loss: 3.7138e-04 - val_accuracy: 1.0000
# Epoch 108/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.7103e-04 - accuracy: 1.0000 - val_loss: 3.7434e-04 - val_accuracy: 1.0000
# Epoch 109/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.7005e-04 - accuracy: 1.0000 - val_loss: 3.8674e-04 - val_accuracy: 1.0000
# Epoch 110/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.6907e-04 - accuracy: 1.0000 - val_loss: 3.9655e-04 - val_accuracy: 1.0000
# Epoch 111/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.6806e-04 - accuracy: 1.0000 - val_loss: 3.7699e-04 - val_accuracy: 1.0000
# Epoch 112/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.6711e-04 - accuracy: 1.0000 - val_loss: 3.6965e-04 - val_accuracy: 1.0000
# Epoch 113/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.6620e-04 - accuracy: 1.0000 - val_loss: 3.6564e-04 - val_accuracy: 1.0000
# Epoch 114/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.6518e-04 - accuracy: 1.0000 - val_loss: 3.8452e-04 - val_accuracy: 1.0000
# Epoch 115/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 3.6433e-04 - accuracy: 1.0000 - val_loss: 3.7246e-04 - val_accuracy: 1.0000
# Epoch 116/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.6340e-04 - accuracy: 1.0000 - val_loss: 3.6268e-04 - val_accuracy: 1.0000
# Epoch 117/150
# 10515/10515 [==============================] - 89s 8ms/step - loss: 3.6250e-04 - accuracy: 1.0000 - val_loss: 3.9158e-04 - val_accuracy: 1.0000
# Epoch 118/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.6160e-04 - accuracy: 1.0000 - val_loss: 3.7590e-04 - val_accuracy: 1.0000
# Epoch 119/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 3.6072e-04 - accuracy: 1.0000 - val_loss: 3.5834e-04 - val_accuracy: 1.0000
# Epoch 120/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 3.5986e-04 - accuracy: 1.0000 - val_loss: 3.5866e-04 - val_accuracy: 1.0000
# Epoch 121/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 3.5902e-04 - accuracy: 1.0000 - val_loss: 3.7493e-04 - val_accuracy: 1.0000
# Epoch 122/150
# 10515/10515 [==============================] - 90s 9ms/step - loss: 3.5814e-04 - accuracy: 1.0000 - val_loss: 3.7866e-04 - val_accuracy: 1.0000
# Epoch 123/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.5728e-04 - accuracy: 1.0000 - val_loss: 3.6353e-04 - val_accuracy: 1.0000
# Epoch 124/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.5643e-04 - accuracy: 1.0000 - val_loss: 3.5542e-04 - val_accuracy: 1.0000
# Epoch 125/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.5564e-04 - accuracy: 1.0000 - val_loss: 3.5745e-04 - val_accuracy: 1.0000
# Epoch 126/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.5479e-04 - accuracy: 1.0000 - val_loss: 3.6605e-04 - val_accuracy: 1.0000
# Epoch 127/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.5424e-04 - accuracy: 1.0000 - val_loss: 3.6194e-04 - val_accuracy: 1.0000
# Epoch 128/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.5318e-04 - accuracy: 1.0000 - val_loss: 3.6410e-04 - val_accuracy: 1.0000
# Epoch 129/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.5242e-04 - accuracy: 1.0000 - val_loss: 3.9154e-04 - val_accuracy: 1.0000
# Epoch 130/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.5168e-04 - accuracy: 1.0000 - val_loss: 3.7155e-04 - val_accuracy: 1.0000
# Epoch 131/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.5088e-04 - accuracy: 1.0000 - val_loss: 3.7436e-04 - val_accuracy: 1.0000
# Epoch 132/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.5018e-04 - accuracy: 1.0000 - val_loss: 3.7000e-04 - val_accuracy: 1.0000
# Epoch 133/150
# 10515/10515 [==============================] - 89s 8ms/step - loss: 3.4934e-04 - accuracy: 1.0000 - val_loss: 3.4815e-04 - val_accuracy: 1.0000
# Epoch 134/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.4855e-04 - accuracy: 1.0000 - val_loss: 3.5287e-04 - val_accuracy: 1.0000
# Epoch 135/150
# 10515/10515 [==============================] - 88s 8ms/step - loss: 3.4795e-04 - accuracy: 1.0000 - val_loss: 3.8152e-04 - val_accuracy: 1.0000
# Epoch 136/150
# 10515/10515 [==============================] - 85s 8ms/step - loss: 3.4732e-04 - accuracy: 1.0000 - val_loss: 3.6505e-04 - val_accuracy: 1.0000
# Epoch 137/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.4646e-04 - accuracy: 1.0000 - val_loss: 3.4822e-04 - val_accuracy: 1.0000
# Epoch 138/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.4569e-04 - accuracy: 1.0000 - val_loss: 3.4669e-04 - val_accuracy: 1.0000
# Epoch 139/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 3.4502e-04 - accuracy: 1.0000 - val_loss: 3.6262e-04 - val_accuracy: 1.0000
# Epoch 140/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.4434e-04 - accuracy: 1.0000 - val_loss: 3.6573e-04 - val_accuracy: 1.0000
# Epoch 141/150
# 10515/10515 [==============================] - 91s 9ms/step - loss: 3.4367e-04 - accuracy: 1.0000 - val_loss: 3.5229e-04 - val_accuracy: 1.0000
# Epoch 142/150
# 10515/10515 [==============================] - 86s 8ms/step - loss: 3.4284e-04 - accuracy: 1.0000 - val_loss: 3.4333e-04 - val_accuracy: 1.0000
# Epoch 143/150
# 10515/10515 [==============================] - 84s 8ms/step - loss: 3.4224e-04 - accuracy: 1.0000 - val_loss: 3.7781e-04 - val_accuracy: 1.0000
# Epoch 144/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.4175e-04 - accuracy: 1.0000 - val_loss: 3.4879e-04 - val_accuracy: 1.0000
# Epoch 145/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.4100e-04 - accuracy: 1.0000 - val_loss: 3.5174e-04 - val_accuracy: 1.0000
# Epoch 146/150
# 10515/10515 [==============================] - 89s 8ms/step - loss: 3.4034e-04 - accuracy: 1.0000 - val_loss: 3.7151e-04 - val_accuracy: 1.0000
# Epoch 147/150
# 10515/10515 [==============================] - 83s 8ms/step - loss: 3.3968e-04 - accuracy: 1.0000 - val_loss: 3.3764e-04 - val_accuracy: 1.0000
# Epoch 148/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.3902e-04 - accuracy: 1.0000 - val_loss: 3.4045e-04 - val_accuracy: 1.0000
# Epoch 149/150
# 10515/10515 [==============================] - 87s 8ms/step - loss: 3.3840e-04 - accuracy: 1.0000 - val_loss: 3.4426e-04 - val_accuracy: 1.0000
# Epoch 150/150
# 10515/10515 [==============================] - 82s 8ms/step - loss: 3.3780e-04 - accuracy: 1.0000 - val_loss: 3.6112e-04 - val_accuracy: 1.0000
# 6572/6572 [==============================] - 19s 3ms/step
# [[52495     2     3     0]
#  [   17 52526     0    11]
#  [    3     1 52535     6]
#  [    0    16     5 52661]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     52500
#            1       1.00      1.00      1.00     52554
#            2       1.00      1.00      1.00     52545
#            3       1.00      1.00      1.00     52682
#
#     accuracy                           1.00    210281
#    macro avg       1.00      1.00      1.00    210281
# weighted avg       1.00      1.00      1.00    210281

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report
# Calculate evaluation metrics
accuracy = accuracy_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
recall = recall_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
precision = precision_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
f1score = f1_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
classification_rep = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions)

# Print evaluation metrics
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.999695645350745
# Recall: 0.999695645350745
# Precision: 0.9996956494544261
# F1-Score: 0.9996956400266762
# Confusion Matrix:
#  [[52495     2     3     0]
#  [   17 52526     0    11]
#  [    3     1 52535     6]
#  [    0    16     5 52661]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     52500
#            1       1.00      1.00      1.00     52554
#            2       1.00      1.00      1.00     52545
#            3       1.00      1.00      1.00     52682
#
#     accuracy                           1.00    210281
#    macro avg       1.00      1.00      1.00    210281
# weighted avg       1.00      1.00      1.00    210281

# %%
# Plot training loss and validation/test loss over each epoch of training
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.title('Training Accuracy and Training Loss')
plt.xlabel('Accuracy')
plt.ylabel('Loss')
plt.legend()

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  plt.figure(figsize=(6,5.5))
  ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='CMRmap')
  sns.set(font_scale=1)
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n');
  ax.xaxis.set_ticklabels(['Normal','Flooding','Blackhole','Forwarding'])
  ax.yaxis.set_ticklabels(['Normal','Flooding','Blackhole','Forwarding'])
  ##plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  ##plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.tight_layout()
  # plt.savefig("F1.eps", format = 'eps')
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model")
conf_mat(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(4):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']
print("Detection rates of Hybrid RF-LSTM Model:", detection_rates)
# Out:
# Detection rates of Hybrid RF-LSTM Model: {0: 0.9999047619047619, 1: 0.9994672146744301, 2: 0.999809686935008, 3: 0.9996013818761627}

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(4):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']

# Extract the class labels and detection rates
labels = list(detection_rates.keys())
rates = list(detection_rates.values())

# Plot the line graph with filled area and labels
plt.figure(figsize=(8, 4))
plt.plot(labels, rates, marker='s', linestyle='-', linewidth=2.5)
plt.fill_between(labels, rates, color='mediumslateblue', alpha=0.4)

# Add labels to each data point
for i in range(len(labels)):
    plt.text(labels[i], rates[i], "{:.6f}".format(rates[i]), ha='center', va='bottom')

plt.xlabel('Class')
plt.ylabel('Detection Rate')
plt.title('Detection Rates of Hybrid RF-LSTM Model')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
#from keras.utils import np_utils
from tensorflow.python.keras.utils import np_utils

# Convert y_test and test_rf_lstm_predictions to one-hot encoded format
y_test_onehot = np_utils.to_categorical(np.argmax(y_test, axis=1))
test_rf_lstm_predictions_onehot = np_utils.to_categorical(test_rf_lstm_predictions, num_classes=4)  # Convert to one-hot encoded format with 4 classes

# Compute the AUC and ROC curves for each class
n_classes = y_test_onehot.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_onehot[:, i], test_rf_lstm_predictions_onehot[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_onehot.ravel(), test_rf_lstm_predictions_onehot.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Plot the ROC curves
plt.figure()
colors = ['blue', 'red', 'green', 'orange']  # Adjust the colors as needed
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='Class {0} (AUC = {1:0.6f})'.format(i, roc_auc[i]))

# Plot the micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='black', lw=2, linestyle='--', label='Micro-average (AUC = {0:0.6f})'.format(roc_auc["micro"]))

plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.05])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Print confusion matrix and classification report
##print(confusion_matrix(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))
##print(classification_report(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))

# %%
import matplotlib.pyplot as plt

# Extract the labels and rates from the detection rates dictionary
labels = list(detection_rates.keys())
rates = list(detection_rates.values())

# Plot the bar chart
plt.bar(labels, rates)

# Add labels and units to each bar
for i in range(len(labels)):
    plt.text(labels[i], rates[i], "{:.5f}".format(rates[i]), ha='center', va='bottom', color='black')

# Add axis labels and title
plt.xlabel('Class')
plt.ylabel('Detection Rates')
plt.title('Detection Rates of Hybrid RF-LSTM Model')

# Display the plot
plt.show()
