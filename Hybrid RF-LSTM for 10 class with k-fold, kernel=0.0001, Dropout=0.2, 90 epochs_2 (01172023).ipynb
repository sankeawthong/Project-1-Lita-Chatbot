# %% [markdown]
# <a href="https://colab.research.google.com/github/sankeawthong/Project-1-Lita-Chatbot/blob/main/Hybrid%20RF-LSTM%20for%2010%20class%20with%20k-fold%2C%20kernel%3D0.0001%2C%20Dropout%3D0.2%2C%2090%20epochs_2%20(01172023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Hybrid RF-LSTM for 10 class classifications based on with k-fold, kernel=0.0001, Dropout=0.2**

# %%
#Imports various Python libraries necessary

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.python.keras.utils import np_utils
#from keras.utils import np_utils
#from tensorflow.keras import np_utils
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix, classification_report

from imblearn.over_sampling import SMOTE
from sklearn.datasets import make_classification

# %%
# Load dataset
dataset = pd.read_csv("dataset_P2.2.csv")
dataset.isnull().sum()
# Out:
# id                   0
# dur                  0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# Class                0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175341 entries, 0 to 175340
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   id                 175341 non-null  int64
#  1   dur                175341 non-null  float64
#  2   spkts              175341 non-null  int64
#  3   dpkts              175341 non-null  int64
#  4   sbytes             175341 non-null  int64
#  5   dbytes             175341 non-null  int64
#  6   rate               175341 non-null  float64
#  7   sttl               175341 non-null  int64
#  8   dttl               175341 non-null  int64
#  9   sload              175341 non-null  float64
#  10  dload              175341 non-null  float64
#  11  sloss              175341 non-null  int64
#  12  dloss              175341 non-null  int64
#  13  sinpkt             175341 non-null  float64
#  14  dinpkt             175341 non-null  float64
#  15  sjit               175341 non-null  float64
#  16  djit               175341 non-null  float64
#  17  swin               175341 non-null  int64
#  18  stcpb              175341 non-null  int64
#  19  dtcpb              175341 non-null  int64
#  20  dwin               175341 non-null  int64
#  21  tcprtt             175341 non-null  float64
#  22  synack             175341 non-null  float64
#  23  ackdat             175341 non-null  float64
#  24  smean              175341 non-null  int64
#  25  dmean              175341 non-null  int64
#  26  trans_depth        175341 non-null  int64
#  27  response_body_len  175341 non-null  int64
#  28  ct_srv_src         175341 non-null  int64
#  29  ct_state_ttl       175341 non-null  int64
#  30  ct_dst_ltm         175341 non-null  int64
#  31  ct_src_dport_ltm   175341 non-null  int64
#  32  ct_dst_sport_ltm   175341 non-null  int64
#  33  ct_dst_src_ltm     175341 non-null  int64
#  34  is_ftp_login       175341 non-null  int64
#  35  ct_ftp_cmd         175341 non-null  int64
#  36  ct_flw_http_mthd   175341 non-null  int64
#  37  ct_src_ltm         175341 non-null  int64
#  38  ct_srv_dst         175341 non-null  int64
#  39  is_sm_ips_ports    175341 non-null  int64
#  40  Class              175341 non-null  int64
# dtypes: float64(11), int64(30)
# memory usage: 54.8 MB

# %%
#from keras.utils import np_utils
#Creates an instance of the LabelEncoder class and uses it to encode the 'Class' column of the dataset (dataset['Class']) into
#numerical labels. These labels are stored in the variable `y
encoder = LabelEncoder()
y = encoder.fit_transform(dataset['Class'])

#Converts the numerical labels in `y` to one-hot encoded vectors using the `np_utils.to_categorical` function.
#This is often done when dealing with multi-class classification problems.
y = np_utils.to_categorical(y, 10)  # update to 4 classes

#Removes the 'Class' column from the dataset, resulting in a DataFrame stored in `X`.
#Then, it converts the DataFrame to a NumPy array and stores it in `X`.
X = dataset.drop(['Class'], axis=1)
X = X.values

#Prints the shapes of the feature matrix `X` and the target variable `y`. This helps verify the dimensions of the data.
print(X.shape)
print(y.shape)
# Out:
# (175341, 40)
# (175341, 10)

# %% [markdown]
# **Data Preprocessing**

# %%
# Data preprocessing

#Imports the Synthetic Minority Over-sampling Technique (SMOTE) from the imbalanced-learn (imblearn) library.
#It is used to address class imbalance by generating synthetic samples of the minority class.
#The code initializes a SMOTE object, `oversample`, and then applies SMOTE to oversample the dataset, which is stored back in `X` and `y`.
from imblearn.over_sampling import SMOTE
oversample = SMOTE()
X, y = oversample.fit_resample(X, y)

# %%
#Splits the dataset into training and testing sets using `train_test_split`. The training data (`X_train` and `y_train`) will contain 80% the data,
#and the testing data (`X_test` and `y_test`) will contain 20%. The `random_state` parameter is set for reproducibility in random data splitting.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
#This code essentially covers data loading, preprocessing (dealing with missing values and one-hot encoding), handling class imbalance using SMOTE,
#and splitting the data into training and testing sets for a machine learning or deep learning model.

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold
# Define the number of classes
num_classes = 10

# Define the number of folds
num_folds = 10
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
# Initialize lists to store evaluation metrics for each fold
accuracies = []
recalls = []
precisions = []
f1scores = []
confusion_matrices = []
classification_reports = []

# %%
# Iterate through the folds
for fold, (train_index, test_index) in enumerate(skf.split(X, y.argmax(axis=1))):
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]

# %% [markdown]
# **Hybrid RF-LSTM for 4 class Ver.2.2**

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense, TimeDistributed
from tensorflow.keras.regularizers import l2
import numpy as np

# Train RF model
rf_model = RandomForestClassifier(n_estimators=100)
rf_model.fit(X_train, y_train)

# Extract features from RF model
train_rf_features = rf_model.predict(X_train)
test_rf_features = rf_model.predict(X_test)

# Reshape RF features for LSTM input
train_rf_features = np.reshape(train_rf_features, (train_rf_features.shape[0], 1, train_rf_features.shape[1]))
test_rf_features = np.reshape(test_rf_features, (test_rf_features.shape[0], 1, test_rf_features.shape[1]))

# %%
# Train LSTM model with RF features
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(1, train_rf_features.shape[2]), return_sequences=True, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(32, return_sequences=True, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.2))
lstm_model.add(LSTM(16, kernel_regularizer=l2(0.0001)))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(10, activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

history = lstm_model.fit(train_rf_features, y_train, epochs=90, batch_size=64, validation_split=0.2)

# Evaluate hybrid model on test set
test_lstm_features = lstm_model.predict(test_rf_features)
test_rf_lstm_predictions = np.argmax(test_lstm_features, axis=1)

#print(confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions))
#print(classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions))

# Plot training/validation loss over each epoch
#plt.plot(history.history['loss'], label='Training Loss')
#plt.plot(history.history['val_loss'], label='Validation/Test Loss')
#plt.xlabel('Epoch')
#plt.ylabel('Loss')
#plt.legend()
#plt.show()

# Calculate evaluation metrics
accuracy = accuracy_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
recall = recall_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
precision = precision_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
f1score = f1_score(np.argmax(y_test, axis=1), test_rf_lstm_predictions, average='weighted')
confusion_mat = confusion_matrix(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
classification_rep = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, digits=6)

# Append metrics to lists
accuracies.append(accuracy)
recalls.append(recall)
precisions.append(precision)
f1scores.append(f1score)
confusion_matrices.append(confusion_mat)
classification_reports.append(classification_rep)

# Print metrics for each fold
print(f"\nMetrics for Fold {fold + 1}:\n")
print("Accuracy:", accuracy)
print("Recall:", recall)
print("Precision:", precision)
print("F1-Score:", f1score)
print("Confusion Matrix:\n", confusion_mat)
print("Classification Report:\n", classification_rep)
# Out:
# Epoch 1/90
# 6300/6300 [==============================] - 47s 7ms/step - loss: 0.1202 - accuracy: 0.9824 - val_loss: 1.1543 - val_accuracy: 0.5011
# Epoch 2/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0112 - accuracy: 0.9995 - val_loss: 0.4755 - val_accuracy: 1.0000
# Epoch 3/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0070 - accuracy: 0.9997 - val_loss: 0.2235 - val_accuracy: 1.0000
# Epoch 4/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0058 - accuracy: 0.9997 - val_loss: 0.9158 - val_accuracy: 0.5011
# Epoch 5/90
# 6300/6300 [==============================] - 41s 7ms/step - loss: 0.0052 - accuracy: 0.9998 - val_loss: 0.1750 - val_accuracy: 1.0000
# Epoch 6/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0047 - accuracy: 0.9998 - val_loss: 0.0508 - val_accuracy: 1.0000
# Epoch 7/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0044 - accuracy: 0.9998 - val_loss: 0.0766 - val_accuracy: 1.0000
# Epoch 8/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0042 - accuracy: 0.9998 - val_loss: 0.0125 - val_accuracy: 1.0000
# Epoch 9/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0040 - accuracy: 0.9998 - val_loss: 0.0609 - val_accuracy: 1.0000
# Epoch 10/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0039 - accuracy: 0.9998 - val_loss: 0.0079 - val_accuracy: 1.0000
# Epoch 11/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 12/90
# 6300/6300 [==============================] - 41s 6ms/step - loss: 0.0037 - accuracy: 0.9998 - val_loss: 0.0064 - val_accuracy: 1.0000
# Epoch 13/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0082 - val_accuracy: 1.0000
# Epoch 14/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 15/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0035 - accuracy: 0.9998 - val_loss: 0.0060 - val_accuracy: 1.0000
# Epoch 16/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 17/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.0068 - val_accuracy: 1.0000
# Epoch 18/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 19/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 20/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 21/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0232 - val_accuracy: 1.0000
# Epoch 22/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0032 - accuracy: 0.9998 - val_loss: 0.0103 - val_accuracy: 1.0000
# Epoch 23/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0050 - val_accuracy: 1.0000
# Epoch 24/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0025 - val_accuracy: 1.0000
# Epoch 25/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0030 - val_accuracy: 1.0000
# Epoch 26/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 27/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 28/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0046 - val_accuracy: 1.0000
# Epoch 29/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 30/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 31/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 32/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 33/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 34/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 35/90
# 6300/6300 [==============================] - 41s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 36/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0092 - val_accuracy: 1.0000
# Epoch 37/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0030 - accuracy: 0.9998 - val_loss: 0.0033 - val_accuracy: 1.0000
# Epoch 38/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 39/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 40/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 41/90
# 6300/6300 [==============================] - 34s 5ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 42/90
# 6300/6300 [==============================] - 35s 6ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 43/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 44/90
# 6300/6300 [==============================] - 35s 5ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 45/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0312 - val_accuracy: 1.0000
# Epoch 46/90
# 6300/6300 [==============================] - 35s 6ms/step - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.0031 - val_accuracy: 1.0000
# Epoch 47/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0321 - val_accuracy: 1.0000
# Epoch 48/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 49/90
# 6300/6300 [==============================] - 35s 5ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 50/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 51/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 52/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 53/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 54/90
# 6300/6300 [==============================] - 35s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 55/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 56/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 57/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 58/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0029 - val_accuracy: 1.0000
# Epoch 59/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 60/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 61/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.0027 - val_accuracy: 1.0000
# Epoch 62/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0066 - val_accuracy: 1.0000
# Epoch 63/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 64/90
# 6300/6300 [==============================] - 42s 7ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 65/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 66/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0037 - val_accuracy: 1.0000
# Epoch 67/90
# 6300/6300 [==============================] - 41s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0048 - val_accuracy: 1.0000
# Epoch 68/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 69/90
# 6300/6300 [==============================] - 41s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 70/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 71/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 72/90
# 6300/6300 [==============================] - 42s 7ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 73/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0043 - val_accuracy: 1.0000
# Epoch 74/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 75/90
# 6300/6300 [==============================] - 37s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 76/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 77/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0018 - val_accuracy: 1.0000
# Epoch 78/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 79/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0021 - val_accuracy: 1.0000
# Epoch 80/90
# 6300/6300 [==============================] - 38s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0028 - val_accuracy: 1.0000
# Epoch 81/90
# 6300/6300 [==============================] - 35s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 82/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0022 - val_accuracy: 1.0000
# Epoch 83/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0042 - val_accuracy: 1.0000
# Epoch 84/90
# 6300/6300 [==============================] - 42s 7ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 85/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 86/90
# 6300/6300 [==============================] - 39s 6ms/step - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 87/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.0017 - val_accuracy: 1.0000
# Epoch 88/90
# 6300/6300 [==============================] - 40s 6ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0020 - val_accuracy: 1.0000
# Epoch 89/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0026 - accuracy: 0.9998 - val_loss: 0.0015 - val_accuracy: 1.0000
# Epoch 90/90
# 6300/6300 [==============================] - 36s 6ms/step - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.0029 - val_accuracy: 1.0000
# 1750/1750 [==============================] - 5s 2ms/step
#
# Metrics for Fold 10:
#
# Accuracy: 0.8469642857142857
# Recall: 0.8469642857142857
# Precision: 0.8696398213734459
# F1-Score: 0.8496182020100685
# Confusion Matrix:
#  [[5362    5   47    1    9  175    0    1    0    0]
#  [   0 4011 1317  191   55   16    0    9    1    0]
#  [   0  149 5161  143   55   15    1   63   12    1]
#  [   0  279 1700 2749  694   45    3  103   27    0]
#  [   0  102  645  667 3967   64    6  102   38    9]
#  [  13   64  362   92   45 4961    1   35   27    0]
#  [   0    3   44   25   28    5 5489    2    4    0]
#  [   0   72  655  153   80   30    1 4558   51    0]
#  [   0    0   13    2    0    3    0    2 5580    0]
#  [   0    0    7    0    1    0    0    0    0 5592]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0   0.997581  0.957500  0.977130      5600
#            1   0.856137  0.716250  0.779971      5600
#            2   0.518641  0.921607  0.663752      5600
#            3   0.683321  0.490893  0.571339      5600
#            4   0.804013  0.708393  0.753180      5600
#            5   0.933572  0.885893  0.909108      5600
#            6   0.997819  0.980179  0.988920      5600
#            7   0.934974  0.813929  0.870263      5600
#            8   0.972125  0.996429  0.984127      5600
#            9   0.998215  0.998571  0.998393      5600
#
#     accuracy                       0.846964     56000
#    macro avg   0.869640  0.846964  0.849618     56000
# weighted avg   0.869640  0.846964  0.849618     56000

# %%
# Print average metrics across all folds
print("\nAverage Metrics Across Folds:\n")
print("Average Accuracy:", np.mean(accuracies))
print("Average Recall:", np.mean(recalls))
print("Average Precision:", np.mean(precisions))
print("Average F1-Score:", np.mean(f1scores))
# Out:
# Average Metrics Across Folds:
#
# Average Accuracy: 0.8469642857142857
# Average Recall: 0.8469642857142857
# Average Precision: 0.8696398213734459
# Average F1-Score: 0.8496182020100685

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation/Test Loss')
plt.title('Training and Validation/Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import itertools
import seaborn as sns
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
def conf_mat(d1,d2):
  cm = confusion_matrix(d1, d2)
  plt.figure(figsize=(8,6.5))
  ax = sns.heatmap(cm,  fmt='2', annot=True, cmap='bone')
  sns.set(font_scale=1)
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values\n');
  ax.xaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])
  ax.yaxis.set_ticklabels(['Normal','Analysis','Backdoor','DoS','Exploits','Fuzzers','Generic','Reconnaissance','Shellcode','Worms'])
  plt.xticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.yticks(rotation=45)  # Add this line to rotate the x-axis labels by 45 degrees
  plt.tight_layout()
  # plt.savefig("F1.eps", format = 'eps')
  plt.show()

# %%
print("Confusion Matrix of Hybrid RF-LSTM Model")
conf_mat(np.argmax(y_test, axis=1), test_rf_lstm_predictions)
# Out:
# Confusion Matrix of Hybrid RF-LSTM Model

# %%
report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']
print("Detection rates of Hybrid RF-LSTM Model:", detection_rates)
# Out:
# Detection rates of Hybrid RF-LSTM Model: {0: 0.9575, 1: 0.71625, 2: 0.9216071428571428, 3: 0.49089285714285713, 4: 0.7083928571428572, 5: 0.8858928571428571, 6: 0.9801785714285715, 7: 0.8139285714285714, 8: 0.9964285714285714, 9: 0.9985714285714286}

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report

report = classification_report(np.argmax(y_test, axis=1), test_rf_lstm_predictions, output_dict=True)
detection_rates = {}
for cls in range(10):
    detection_rates[encoder.inverse_transform([cls])[0]] = report[str(cls)]['recall']

# Extract the class labels and detection rates
labels = list(detection_rates.keys())
rates = list(detection_rates.values())

# Plot the line graph with filled area and labels
plt.figure(figsize=(8, 4))
plt.plot(labels, rates, marker='s', linestyle='-', linewidth=2.5)
plt.fill_between(labels, rates, color='mediumslateblue', alpha=0.4)

# Add labels to each data point
for i in range(len(labels)):
    plt.text(labels[i], rates[i], "{:.6f}".format(rates[i]), ha='center', va='bottom')

plt.xlabel('Class')
plt.ylabel('Detection Rate')
plt.title('Detection Rates of Hybrid RF-LSTM Model')
plt.xticks(rotation=0)
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt
#from keras.utils import np_utils
from tensorflow.python.keras.utils import np_utils

# Convert y_test and test_rf_lstm_predictions to one-hot encoded format
y_test_onehot = np_utils.to_categorical(np.argmax(y_test, axis=1))
test_rf_lstm_predictions_onehot = np_utils.to_categorical(test_rf_lstm_predictions, num_classes=10)  # Convert to one-hot encoded format with 4 classes

# Compute the AUC and ROC curves for each class
n_classes = y_test_onehot.shape[1]
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_onehot[:, i], test_rf_lstm_predictions_onehot[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and AUC
fpr["micro"], tpr["micro"], _ = roc_curve(y_test_onehot.ravel(), test_rf_lstm_predictions_onehot.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Print False Positive Rate and True Positive Rate for each class
for i in range(n_classes):
    print(f"Class {i} - FPR: {fpr[i][1]:.6f}, TPR: {tpr[i][1]:.6f}")


# Plot the ROC curves
plt.figure()
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta']  # Adjust the colors as needed
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label='Class {0} (AUC = {1:0.6f})'.format(i, roc_auc[i]))

# Plot the micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], color='black', lw=2, linestyle='--', label='Micro-average (AUC = {0:0.6f})'.format(roc_auc["micro"]))

plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.05])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc='lower right')
plt.show()

# Print confusion matrix and classification report
##print(confusion_matrix(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))
##print(classification_report(np.argmax(y_test_onehot, axis=1), np.argmax(test_rf_features_onehot, axis=1)))
# Out:
# Class 0 - FPR: 0.000258, TPR: 0.957500
# Class 1 - FPR: 0.013373, TPR: 0.716250
# Class 2 - FPR: 0.095040, TPR: 0.921607
# Class 3 - FPR: 0.025278, TPR: 0.490893
# Class 4 - FPR: 0.019187, TPR: 0.708393
# Class 5 - FPR: 0.007004, TPR: 0.885893
# Class 6 - FPR: 0.000238, TPR: 0.980179
# Class 7 - FPR: 0.006290, TPR: 0.813929
# Class 8 - FPR: 0.003175, TPR: 0.996429
# Class 9 - FPR: 0.000198, TPR: 0.998571
